# %% [markdown]
# #  Исследование базы данных проката кинофильмов

# %% [markdown]
# ### Оглавление
# * [Вступление](#id_1)
#   * [Описание колонок датасетов](#id_1a)
#   * [Импорт библиотек](#id_1b)
# * [Предобработка данных](#id_2)
#   * [Объединение таблиц](#id_2a)
#     * [Изменение типов данных](#id_2b)
#   * [Проверка названий колонок](#id_2c)
#   * [Работа с пропусками](#id_2d)
#     * [Колонка box_office](#id_2d1)
#     * [Колонки refundable_support, nonrefundable_support, budget, financing_source](#id_2d2)
#     * [Колонка genres](#id_2d3)
#     * [Колонка ratings](#id_2d4)
#     * [Колонка production_country](#id_2d5)
#     * [Колонка film_studio](#id_2d6)
#     * [Колонка director](#id_2d7)
#     * [Колонка producer](#id_2d8)
#   * [Работа с дубликатами](#id_2e)
#   * [Добавление новых колонок](#id_2f)
#   * [Вывод по предобработке данных](#id_2g)
# * [Исследовательский анализ данных](#id_3)
#   * [Расчет доли фильмов с указанной информацией о сборах](#id_3a)
#   * [Диаграмма количества фильмов по годам](#id_3b)
#   * [Диаграмма средних сборов по годам](#id_3c)
#   * [Диаграмма медианных сборов по годам](#id_3d)
#   * [Диаграмма самых кассовых фильмов](#id_3e)
#   * [Диаграмма динамики кассовых сборов по годам](#id_3f)
#   * [Влияние возраста аудитории](#id_3g)
#   * [Диаграмма медианных и средних сборов по зрительским категориям за 2015-2019 годы](#id_3h)
#   * [Диаграмма кассовых сборов по категориям за 2010-2019 годы](#id_3j)
#   * [Диаграмма медианных сборов для каждой зрительской категории по годам](#id_3k)
#   * [Диаграмма средних сборов для каждой зрительской категории по годам](#id_3l)
#   * [Выводы по разделу](#id_3m)
# *  [Исследование фильмов, получивших господдержку](#id_4)
#   * [Количество выпущенных фильмов по категориям](#id_4a)
#   * [Сборы по категориям](#id_4b)
#   * [Кассовые сборы на рубль поддержки](#id_4c)
#   * [Студии, приносящие наибольший доход на рубль поддержки](#id_4d)
#   * [Количество выпущенных фильмов по виду господдержки](#id_4e)
#   * [Корреляция количественных данных](#id_4f)
#   * [Выводы по разделу](#id_4g)
# * [Выводы по проекту](#id_5)

# %% [markdown]
# ## Вступление <a class="anchor" id="id_1"></a>

# %% [markdown]
# #### Описание колонок датасетов   <a class="anchor" id="id_1a"></a>

# %% [markdown]
#
# Таблица mkrf_movies содержит информацию из реестра прокатных удостоверений. У одного фильма может быть несколько прокатных удостоверений.
# **title** — название фильма;
# **puNumber** — номер прокатного удостоверения;
# **show_start_date** — дата премьеры фильма;
# **type** — тип фильма;
# **film_studio** — студия-производитель;
# **production_country** — страна-производитель;
# **director** — режиссёр;
# **producer** — продюсер;
# **age_restriction** — возрастная категория;
# **refundable_support** — объём возвратных средств государственной поддержки;
# **nonrefundable_support** — объём невозвратных средств государственной поддержки;
# **financing_source** — источник государственного финансирования;
# **budget** — общий бюджет фильма;
# **ratings** — рейтинг фильма на КиноПоиске;
# **genres** — жанр фильма.
#
# !!!Столбец budget уже включает в себя полный объём государственной поддержки. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку.
#
# Таблица mkrf_shows содержит сведения о показах фильмов в российских кинотеатрах.
# **puNumber** — номер прокатного удостоверения;
# **box_office** — сборы в рублях.

# %% [markdown]
# #### Импорт библиотек  <a class="anchor" id="id_1b"></a>

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#Стиль чисел с запятой-разделителем тысяч
pd.options.display.float_format = '{:,}'.format

# %% [markdown]
# ## Предобработка данных <a class="anchor" id="id_2"></a>

# %% [markdown]
# ### Объединение датасетов <a class="anchor" id="id_2a"></a>

# %%
df_movies = pd.read_csv(r'E:\Unity_editor\Visual studio projects\Yandex_Practicum\Projects\Исследование базы кинофильмов\mkrf_movies.csv')
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB

# %%
df_shows = pd.read_csv(r'E:\Unity_editor\Visual studio projects\Yandex_Practicum\Projects\Исследование базы кинофильмов\mkrf_shows.csv')
df_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %%
df_shows['puNumber'].isin(df_movies['puNumber']).value_counts()
# Out:
# False    3158
# Name: puNumber, dtype: int64

# %%
# Функция для вывода пропущенных значений в датафрейме, просто вызовите ее, указав нужный датафрейм в параметрах
def missing_values_tab(df):
    #Подсчет количества пропущенных значений
    mis_val = df.isnull().sum()
    #Подсчет доли пропущенных значений в колонке в процентах
    mis_val_percent = round(100 * df.isnull().sum() / len(df),2)
    #Объединяем две созданных колонки в один датафрейм с параметром axis=1, чтобы добавить их справа-слева
    mv_table = pd.concat([mis_val, mis_val_percent], axis=1)  
    #Переименование колонок
    mv_table = mv_table.rename(columns = {0 : 'Пропущенные значения', 1 : '% от всех значений'})
    #Создаем колонку с типом данных 
    mv_table['Тип данных'] = df.dtypes
    mv_table = mv_table[mv_table.iloc[:,1]!=0].sort_values(by='Пропущенные значения',ascending=False)
    print ("Ваш датафрейм содержит " + str(df.shape[1]) + " колонок и " + str(df.shape[0]) + " строк.\n")
    print("Он имеет  " + str(mv_table.shape[0]) +" колонок с пропущенными значениями.")    
    return display(mv_table)

# %% [markdown]
# #### Изменение типов данных <a class="anchor" id="id_2b"></a>

# %% [markdown]
# Для того, чтобы осуществить слияние двух датасетов надо сначала исправить тип данных в некоторых колонках.
# Изменение типа данных в колонках df_movies:
# puNumber -->int64
# show_start_date-->datetime

# %% [markdown]
# Проверка на наличие нечисловых значений в колонке, так как тип колонки object:

# %%
df_movies[df_movies['puNumber'].str.isnumeric()==False]
# Out:
#                                   title    puNumber           show_start_date  \
# 804               Паранормальный Якутск   111004112  2012-08-24T12:00:00.000Z
# 1797  Курбан-роман. (История с жертвой)         нет  2014-05-15T12:00:00.000Z
#
#                 type       film_studio production_country    director  \
# 804   Художественный  ИП Тимофеев К.П.             Россия  К.Тимофеев
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия     С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 804          NaN  «16+» - для детей старше 16 лет                 NaN
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 804                     NaN     NaN              NaN     NaN    NaN
# 1797                    NaN     NaN              NaN     NaN    NaN

# %% [markdown]
# Проверка, есть ли нулевые удостоверения в датасете. Если нет, то неправильным значениям присвоем нуль:

# %%
display(df_movies[df_movies['puNumber']==0])
df_movies.loc[1797,'puNumber'] = 0
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres]
# Index: []

# %% [markdown]
# Изменение типов:

# %%
df_movies['puNumber'] = df_movies['puNumber'].astype('int64')
df_movies['show_start_date'] = pd.to_datetime(df_movies['show_start_date'], format='%Y-%m-%dT%H:%M:%S')
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   datetime64[ns, UTC]
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(3), int64(1), object(10)
# memory usage: 877.4+ KB

# %%
#Слияние датасетов
data = pd.merge(df_movies,df_shows,how='left',on='puNumber')
data.info()
#Вывод информации о пропусках
missing_values_tab(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   datetime64[ns, UTC]
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
#  15  box_office             3158 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(1), object(10)
# memory usage: 994.2+ KB
# Ваш датафрейм содержит 16 колонок и 7486 строк.
#
# Он имеет  11 колонок с пропущенными значениями.
#                        Пропущенные значения  % от всех значений Тип данных
# refundable_support                     7154               95.57    float64
# nonrefundable_support                  7154               95.57    float64
# budget                                 7154               95.57    float64
# financing_source                       7154               95.57     object
# box_office                             4328               57.81    float64
# genres                                  976               13.04     object
# ratings                                 967               12.92     object
# producer                                568                7.59     object
# film_studio                              18                0.24     object
# director                                  9                0.12     object
# production_country                        2                0.03     object

# %% [markdown]
# **Заключение:**
# Из данных таблицы выше можно заключить, что объединенный датасет имеет 4 колонки, где 95% всех данных являются пропусками.Вполне возможно, что это пропуски в одних и тех же строках. В колонке box_office пропуски образовались в результате объединения датасетов разных длин и они составляют 57% от всех значений. Также есть еще 5 колонок, где есть пропуски, но их количество не столь значительно.

# %%
#построение диаграмм
data.hist(figsize=(15,20))
plt.show()

# %% [markdown]
# **Заключение:**
# - puNumber в основном состоят из единичек, иногде из двоек.
# - Количество фильмов по годам примерно распределено равномерно
# - в остальных четырех диаграммах можно заметить множество аномальных значений и основная масса значений расположена у нижней границы.

# %% [markdown]
# #### Проверка названий колонок  <a class="anchor" id="id_2c"></a>

# %% [markdown]
# Просмотр заголовков таблицы на предмет корректности

# %%
print(data.columns)
# Out:
# Index(['title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %% [markdown]
# Колонки имеют корректные названия.

# %% [markdown]
# ### Работа с пропусками <a class="anchor" id="id_2d"></a>

# %% [markdown]
# #### Колонка box_office <a class="anchor" id="id_2d1"></a>

# %% [markdown]
# Пропуски в этой колонке связаны со слиянием датасетов. Они связаны с тем, что число puNumber в датасете df_movies гораздо больше, чем во втором датасете. Такие пропуски я заполню значением "-1"

# %%
data['box_office'].fillna(-1,inplace=True)

# %%
needed_cols = ['title','puNumber','director','box_office']
display(data[data['box_office'].isna()][needed_cols].head(10))
print(df_movies[df_movies['puNumber'].isin(df_shows['puNumber'])].shape[0])
# Out:
# Empty DataFrame
# Columns: [title, puNumber, director, box_office]
# Index: []
# 3158

# %% [markdown]
# #### Колонки refundable_support, nonrefundable_support, budget, financing_source. <a class="anchor" id="id_2d2"></a>

# %% [markdown]
# Проверка на наличие пропусках в одних и тех же строках

# %%
data[data['budget'].isna() & 
          data['refundable_support'].isna() &
          data['nonrefundable_support'].isna() &
          data['financing_source'].isna()].shape[0]
# Out:
# 7154

# %% [markdown]
# Количество строк с условием совпало с количеством пропущенных значений в колонках, поэтому можно заключить, что они в одних и тех же строках. Теперь проверю гипотезу, что пустые колонки связаны с тем, что пропуски в тех фильмах, которые не подлежали гос.поддержке.

# %%
display(data[data['budget'].isna() & 
          data['refundable_support'].isna() &
          data['nonrefundable_support'].isna() &
          data['financing_source'].isna() & 
          (data['production_country'].str.contains('Россия')==False)
            ].shape[0])
# Out:
# 5499

# %% [markdown]
# Подавляющее большинство таких пропусков для фильмов, сделанных без участия России.

# %% [markdown]
# Поиск уникальных значений в financing_source:

# %%
print(data['financing_source'].unique())
# Out:
# [nan 'Министерство культуры' 'Фонд кино'
#  'Министерство культуры, Фонд кино']

# %% [markdown]
# **Краткий вывод.**
# Колонки refundable_support, nonrefundable_support, budget, financing_source имеют одинаковое большое количество пропусков (95% от всех значений в соотв. колонках).Вероятными причинами на мой взгляд могут быть:
# - законодательные причины(запрет на публикацию данных органов гос.власти, на разглашение коммерческой информации);
# - данная база данных брала информацию из государственной информационной системы, обслуживающей кинобизнес в России, где эта информация не в открытом доступе;
# - можно выдвинуть гипотезу, что иностранные фильмы не подлежали господдержке, а российские фильмы в оставшихся пустых строках были коммерческими и тоже не подлежали господдержке, поэтому система не заполняла данными эти колонки.
# Удалять такое огромное количество пропусков неразумно и принял решение:
# - в колонках, где бюджет равен 0, заполню их суммой колонок ['refundable_support'] и ['nonrefundable_support']
# - заполнить их маркером в виде "-1" в колонках refundable_support, nonrefundable_support, budget
# - в колонке financing_source переименовать пропуски в "неизвестно"

# %%
def right_budget(data):
    if data['budget'] == 0:
        data['budget'] = data['refundable_support'] + data['nonrefundable_support']
        return data['budget']
    return data['budget']

# %%
display(data[data['budget']==0].head(10)[['budget','refundable_support','nonrefundable_support']])
data['budget'] = data.apply(right_budget,axis=1)
display(data.loc[[3565,5673,5806]][['budget','refundable_support','nonrefundable_support']])
# Out:
#       budget  refundable_support  nonrefundable_support
# 2053     0.0                 0.0           23,000,000.0
# 2058     0.0                 0.0           75,000,000.0
# 2472     0.0        10,000,000.0           70,000,000.0
# 2532     0.0        20,000,000.0                    0.0
# 2615     0.0        60,000,000.0          100,000,000.0
# 2684     0.0                 0.0           59,000,000.0
# 2788     0.0                 0.0           35,000,000.0
# 2874     0.0                 0.0            6,000,000.0
# 3047     0.0        19,000,000.0           51,000,000.0
# 3565     0.0                 0.0          250,000,000.0
#             budget  refundable_support  nonrefundable_support
# 3565 250,000,000.0                 0.0          250,000,000.0
# 5673  60,000,000.0        20,000,000.0           40,000,000.0
# 5806  70,000,000.0        10,000,000.0           60,000,000.0

# %% [markdown]
# Проверка на наличие значения "-1" в колонках refundable_support, nonrefundable_support, budget:

# %%
data[(data['budget']==-1) | 
     (data['refundable_support']==-1) |
     (data['nonrefundable_support']==-1)]
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %% [markdown]
# Значение "-1" нигде не встречается, поэтому заполним им:

# %%
data['budget'].fillna(-1,inplace=True)
data['refundable_support'].fillna(-1,inplace=True)
data['nonrefundable_support'].fillna(-1,inplace=True)
#Проверка
print(
    data['budget'].isna().sum(),
    data['refundable_support'].isna().sum(),
    data['nonrefundable_support'].isna().sum()
)
# Out:
# 0 0 0

# %% [markdown]
# Заполнение пропусков в financing_source:

# %%
data['financing_source'].fillna("неизвестно", inplace=True)
#Проверка
data['financing_source'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Работа с  колонкой genres <a class="anchor" id="id_2d3"></a>

# %%
print('Количество строк, где NaN в обеих колонках: ',data[(data['genres'].isna()) & (data['ratings'].isna())].shape[0])
# Out:
# Количество строк, где NaN в обеих колонках:  967

# %% [markdown]
# Так как все пропущенные значения в колонке genres совпадают с пропусками в колонке ratings, я сделаю предположение, что наиболее вероятной причиной являются ошибки в работе автоматизированной системы. Так как пропусков слишком много, их лучше заполнить значением "неизвестно".

# %%
data['genres'].fillna('неизвестно', inplace=True)

# %% [markdown]
# #### Колонка ratings <a class="anchor" id="id_2d4"></a>

# %% [markdown]
# Проверка на количество строк, содержащих нецифровые значения:

# %%
display(data[data['ratings'].str.isnumeric()==False].shape[0])
# Out:
# 6519

# %% [markdown]
# Наиболее вероятными причинами наличия пропусков в этой колонке являются, как и в случае с колонкой genres, отсутствие информации о рейтингах в базе данных, откуда эта система берет информацию; ошибки в работе самой базы данных.
# Так как значений много, лучше заполнить их цифровым значением, например нулем, если в базе данных это значение не встречается.

# %%
print(data[(data['ratings']==0) | (data['ratings']==0.0)].shape[0])
# Out:
# 0

# %% [markdown]
# Так как значения нуль в колонке ratings не встречается, то им я заполню пропуски.

# %%
data['ratings'].fillna(0,inplace=True)

# %% [markdown]
# #### Колонка production_country <a class="anchor" id="id_2d5"></a>

# %% [markdown]
# Пропуски могли образоваться из-за того, что это сборники мульфильмов, каждый из которых мог иметь свою страну производства и эти значения не могли отследиться базой данных или ее оператором.
# В этой колонке имеем два пропуска. В строке 3186 мы можем заполнить значение, найдя информацию сосдених колонках. Так как студией-производителем является ООО "Продюсерский центр ЕРАЛАШ", то можно с уверенностью предположить, что страной будет Россия.
# Во второй строке информацию о стране-производителе также можно найти в сети. С большой долей уверенности можно сказать, что это тоже Россия.

# %%
display(data[data['production_country'].isna()])
data['production_country'].fillna('Россия',inplace=True)
print('Количество пропусков после удаления: ',data['production_country'].isna().sum())
# Out:
#                                                   title   puNumber  \
# 3186  Детский юмористический киножурнал "Ералаш. Ну ...  111001216
# 4441                           Мульт личности. Выпуск 5  214000410
#
#                show_start_date            type  \
# 3186 2016-02-09 12:00:00+00:00  Художественный
# 4441 2010-01-25 12:00:00+00:00  Художественный
#
#                           film_studio production_country  \
# 3186  ООО "Продюсерский центр ЕРАЛАШ"                NaN
# 4441                              NaN                NaN
#
#                                                director  \
# 3186  Р.Светлов, И.Магитон, А.Арутюнян, Л.Мирский, А...
# 4441                                                NaN
#
#                              producer                         age_restriction  \
# 3186  ООО "Продюсерский центр ЕРАЛАШ"  «0+» - для любой зрительской аудитории
# 4441                              NaN  «0+» - для любой зрительской аудитории
#
#       refundable_support  nonrefundable_support  budget financing_source  \
# 3186                -1.0                   -1.0    -1.0       неизвестно
# 4441                -1.0                   -1.0    -1.0       неизвестно
#
#      ratings              genres  box_office
# 3186     7.2     детский,комедия   194,527.0
# 4441     4.0  мультфильм,комедия        -1.0
# Количество пропусков после удаления:  0

# %% [markdown]
# #### Работа с колонкой film_studio	 <a class="anchor" id="id_2d6"></a>

# %%
display(data[data['film_studio'].isna()])
# Out:
#                                          title   puNumber  \
# 1293                           Stars in Shorts  121011114
# 4441                  Мульт личности. Выпуск 5  214000410
# 6105                              Значит любит  111013818
# 6181                     Несейка. Младшая дочь  112007018
# 6379                              Ян Антонышев  112011818
# 6380                              Ян Антонышев  112011918
# 6399                     Доживем до каникул?..  111021918
# 6485                                До и После  112014418
# 6494            Калмыцкий геше Нгаванг Вангьял  113002018
# 6497                        Мой папа Чингисхан  112014918
# 6498                       В плену города грёз  112014818
# 6499                            Последнее фото  112014518
# 6507                              Мой селфхарм  113001918
# 6511            Обстоятельства места и времени  112015018
# 6638  Эрик Булатов. Моя Третьяковка, серии 1-2  113000319
# 6639                                     Брови  111000719
# 6662                                   Топливо  111001419
# 6722                       Путешествие в Париж  111002919
#
#                show_start_date               type film_studio  \
# 1293 2014-06-03 12:00:00+00:00     Художественный         NaN
# 4441 2010-01-25 12:00:00+00:00     Художественный         NaN
# 6105 2018-08-10 12:00:00+00:00     Художественный         NaN
# 6181 2018-09-01 12:00:00+00:00     Документальный         NaN
# 6379 2018-11-15 12:00:00+00:00     Документальный         NaN
# 6380 2018-11-15 12:00:00+00:00     Документальный         NaN
# 6399 2018-11-15 12:00:00+00:00     Художественный         NaN
# 6485 2018-12-05 12:00:00+00:00     Документальный         NaN
# 6494 2018-12-05 12:00:00+00:00  Научно-популярный         NaN
# 6497 2018-12-06 12:00:00+00:00     Документальный         NaN
# 6498 2018-12-06 12:00:00+00:00     Документальный         NaN
# 6499 2018-12-06 12:00:00+00:00     Документальный         NaN
# 6507 2018-12-06 12:00:00+00:00  Научно-популярный         NaN
# 6511 2018-12-12 12:00:00+00:00     Документальный         NaN
# 6638 2019-01-28 12:00:00+00:00  Научно-популярный         NaN
# 6639 2019-03-01 12:00:00+00:00     Художественный         NaN
# 6662 2019-02-12 12:00:00+00:00     Художественный         NaN
# 6722 2019-03-01 12:00:00+00:00     Художественный         NaN
#
#        production_country                                           director  \
# 1293  США, Великобритания  Роберт Фестингер, Руперт Френд, Джей Камен, Ни...
# 4441               Россия                                                NaN
# 6105               Россия                                        А.Краевский
# 6181               Россия                                            В.Марин
# 6379               Россия                                          Е.Окопная
# 6380               Россия                                          Е.Окопная
# 6399               Россия              Я.Хальпукова (псевдоним Яна Мартынец)
# 6485               Россия                                   А.Новокреповская
# 6494               Россия                                          И.Долгина
# 6497               Россия                                       А.Сайфуллина
# 6498               Россия                                         В.Витовцев
# 6499               Россия                                      Е.Севастьянов
# 6507               Россия                 Я.Лаптев (псевдоним Яков Раскалов)
# 6511               Россия                                          Д.Кабаков
# 6638               Россия                                        С.Гарькавый
# 6639               Россия                                            О.Штром
# 6662               Россия                                          М.Архипов
# 6722               Россия             М.Олейник (псевдоним - Мария Полякова)
#
#                                                producer  \
# 1293  Татьяна Келли, Роберта Мунро, Руперт Френд, До...
# 4441                                                NaN
# 6105                                        Е.Щербакова
# 6181                    Д.Якунин, Ф.Абрютин, О.Филонова
# 6379                                        Е.Герасимов
# 6380                                        Е.Герасимов
# 6399              Я.Хальпукова (псевдоним Яна Мартынец)
# 6485                                   А.Новокреповская
# 6494                                          И.Долгина
# 6497                                       А.Сайфуллина
# 6498                                             О.Мичи
# 6499                                      Е.Севастьянов
# 6507                 Я.Лаптев (псевдоним Яков Раскалов)
# 6511                                          Д.Кабаков
# 6638                                          Т.Пинская
# 6639       В.Максимов, В.Степанов, Г.Киракосян, О.Штром
# 6662                                          М.Архипов
# 6722                                            Н.Савко
#
#                              age_restriction  refundable_support  \
# 1293         «16+» - для детей старше 16 лет                -1.0
# 4441  «0+» - для любой зрительской аудитории                -1.0
# 6105             «18+» - запрещено для детей                -1.0
# 6181           «6+» - для детей старше 6 лет                -1.0
# 6379         «12+» - для детей старше 12 лет                -1.0
# 6380         «12+» - для детей старше 12 лет                -1.0
# 6399         «12+» - для детей старше 12 лет                -1.0
# 6485           «6+» - для детей старше 6 лет                -1.0
# 6494         «12+» - для детей старше 12 лет                -1.0
# 6497         «12+» - для детей старше 12 лет                -1.0
# 6498             «18+» - запрещено для детей                -1.0
# 6499             «18+» - запрещено для детей                -1.0
# 6507             «18+» - запрещено для детей                -1.0
# 6511         «12+» - для детей старше 12 лет                -1.0
# 6638           «6+» - для детей старше 6 лет                -1.0
# 6639         «16+» - для детей старше 16 лет                -1.0
# 6662         «12+» - для детей старше 12 лет                -1.0
# 6722         «16+» - для детей старше 16 лет                -1.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 1293                   -1.0    -1.0       неизвестно     7.3
# 4441                   -1.0    -1.0       неизвестно     4.0
# 6105                   -1.0    -1.0       неизвестно       0
# 6181                   -1.0    -1.0       неизвестно       0
# 6379                   -1.0    -1.0       неизвестно       0
# 6380                   -1.0    -1.0       неизвестно       0
# 6399                   -1.0    -1.0       неизвестно       0
# 6485                   -1.0    -1.0       неизвестно     6.9
# 6494                   -1.0    -1.0       неизвестно       0
# 6497                   -1.0    -1.0       неизвестно       0
# 6498                   -1.0    -1.0       неизвестно     7.9
# 6499                   -1.0    -1.0       неизвестно       0
# 6507                   -1.0    -1.0       неизвестно       0
# 6511                   -1.0    -1.0       неизвестно       0
# 6638                   -1.0    -1.0       неизвестно       0
# 6639                   -1.0    -1.0       неизвестно       0
# 6662                   -1.0    -1.0       неизвестно     6.1
# 6722                   -1.0    -1.0       неизвестно       0
#
#                           genres  box_office
# 1293                     комедия        -1.0
# 4441          мультфильм,комедия        -1.0
# 6105                  неизвестно        -1.0
# 6181                  неизвестно        -1.0
# 6379                  неизвестно        -1.0
# 6380                  неизвестно        -1.0
# 6399                  неизвестно    41,225.0
# 6485     драма,криминал,детектив        -1.0
# 6494                  неизвестно        -1.0
# 6497                  неизвестно        -1.0
# 6498   фантастика,боевик,триллер        -1.0
# 6499                  неизвестно        -1.0
# 6507                  неизвестно        -1.0
# 6511                  неизвестно        -1.0
# 6638                  неизвестно        -1.0
# 6639                  неизвестно        -1.0
# 6662  короткометражка,фантастика        -1.0
# 6722                  неизвестно        -1.0

# %% [markdown]
# Так как пропусков всего 18, на мой взгляд, они  вызваны или незанесением этой информации в базу данных ее оператором, или сбоем самой системы, или ее как таковой не было. Пропущенные значения можно заполнить значением "неизвестно"

# %%
data['film_studio'].fillna('неизвестно',inplace=True)

# %% [markdown]
# #### Работа с колонкой director <a class="anchor" id="id_2d7"></a>

# %% [markdown]
# Эта колонка имеет  9 пропусков.Выводу информацию, где в колонке director пропуски, а в колонке producer нет пропусков:

# %%
display(data[(data['director'].isna()) & (data['producer'].notna())])
# Out:
#                                                   title   puNumber  \
# 764   Три звезды. Концерт в Waldbuhne Theater, Берли...  126003512
# 1735                           Помпеи. Британский музей  126003413
# 4415                          Bon Jovi. The Circle Tour  126001710
# 4923  Георг Фридрих Гендель. Мессия. Оратория. Корол...  126001111
# 4942             Питер Гэбриэл и New Blood Orchestra 3D  126002711
#
#                show_start_date    type                   film_studio  \
# 764  2012-12-04 12:00:00+00:00  Прочие            Райзинг Алтернатив
# 1735 2013-09-11 12:00:00+00:00  Прочие  МортуСкрин, Британский музей
# 4415 2010-11-11 12:00:00+00:00  Прочие     Эншутц Интертейнмент Груп
# 4923 2011-04-25 12:00:00+00:00  Прочие                      Опус Арт
# 4942 2011-11-11 12:00:00+00:00  Прочие               Омниверс Визион
#
#      production_country director                      producer  \
# 764      Великобритания      NaN               Вальдбюне Театр
# 1735     Великобритания      NaN              Британский музей
# 4415                США      NaN     Эншутц Интертейнмент Груп
# 4923     Великобритания      NaN  Короевский колледж Кембриджа
# 4942     Великобритания      NaN               Омниверс Визион
#
#                              age_restriction  refundable_support  \
# 764   «0+» - для любой зрительской аудитории                -1.0
# 1735  «0+» - для любой зрительской аудитории                -1.0
# 4415  «0+» - для любой зрительской аудитории                -1.0
# 4923  «0+» - для любой зрительской аудитории                -1.0
# 4942  «0+» - для любой зрительской аудитории                -1.0
#
#       nonrefundable_support  budget financing_source ratings          genres  \
# 764                    -1.0    -1.0       неизвестно       0      неизвестно
# 1735                   -1.0    -1.0       неизвестно       0      неизвестно
# 4415                   -1.0    -1.0       неизвестно     7.9  концерт,музыка
# 4923                   -1.0    -1.0       неизвестно       0      неизвестно
# 4942                   -1.0    -1.0       неизвестно     6.7  концерт,музыка
#
#       box_office
# 764     44,350.0
# 1735        -1.0
# 4415        -1.0
# 4923        -1.0
# 4942        -1.0

# %% [markdown]
# Оставшиеся 4 пропуска в колонке director приходятся на строки, где колонка producer содержит NaN. Так как строк всего 5, пропуски можно заполнить, найдя недостающую информацию в сети.
# Для строки 1735 - режиссер Джон Руни.
# Для строки 4942 - режиссер Блу Лич.
# Для остальных строк информации найти не удалось и пропускам присвою значение "неизвестно".

# %%
data.loc[1735,'director'] = 'Джон Руни'
data.loc[4942,'director'] = 'Блу Лич'
data['director'].fillna('неизвестно',inplace=True)

# %% [markdown]
# #### Работа с колонкой producer. <a class="anchor" id="id_2d8"></a>

# %% [markdown]
# Эта колонка имеет  568 пропусков.Так какв киноиндустрии часто режиссеры фильмов выступают в качестве продюссеров и наоборот, пропуски в этой колонке можно попытаться заполнить значениями из другой.Также может пригодиться колонка film_studio.

# %%
print('Количество строк, где директор есть, а продюсер неизвестен: ',data[(data['director'].notna()) & (data['producer'].isna())].shape[0])
print('Количество строк, где страна-производитель - CCCР и продюсер неизвестен: ', data[(data['production_country'].str.contains("СССР"))  & (data['producer'].isna())].shape[0])
print('Количество строк, где директор и продюсер совпадают: ',(data[data['director']==data['producer']].shape[0]))
print('Количество строк, где страна-производитель - CCCР, а продюсер и директор совпадают : ', data[(data['production_country'].str.contains("СССР"))  & (data['producer']==data['director'])].shape[0])
display(data.query('production_country.str.contains("СССР") and producer.notna()')[['production_country','film_studio','director','producer']])
print(data.query('production_country.str.contains("СССР")')['producer'].value_counts())
# Out:
# Количество строк, где директор есть, а продюсер неизвестен:  568
# Количество строк, где страна-производитель - CCCР и продюсер неизвестен:  394
# Количество строк, где директор и продюсер совпадают:  329
# Количество строк, где страна-производитель - CCCР, а продюсер и директор совпадают :  1
#                 production_country  \
# 3093                  СССР, Россия
# 3193                  СССР, Россия
# 3926                          СССР
# 3931                          СССР
# 3962                  СССР, Россия
# 4008                 СССР - Италия
# 4009                 СССР - Италия
# 4010  СССР - ГДР - Польша - Италия
# 4011  СССР - ГДР - Польша - Италия
# 4012  СССР - ГДР - Польша - Италия
# 4381                          СССР
# 4382                          СССР
# 4383                          СССР
#
#                                             film_studio  \
# 3093  Киностудия "Мосфильм", ФГУП "Киноконцерн "Мосф...
# 3193  Киностудия "Мосфильм", ЗАО "Киновидеообъединен...
# 3926                                      ИП Аболс А.Р.
# 3931                                      ИП Аболс А.Р.
# 3962  Киностудия "Ленфильм", ЗАО "Киновидеообъединен...
# 4008  Киностудия "Мосфильм" при участии "ДИНО ДЕ ЛАУ...
# 4009  Киностудия "Мосфильм" при участии "ДИНО ДЕ ЛАУ...
# 4010  Киностудия "Мосфильм" при участии "ДЕФА", кино...
# 4011  Киностудия "Мосфильм" при участии "ДЕФА", кино...
# 4012  Киностудия "Мосфильм" при участии "ДЕФА", кино...
# 4381                              Киностудия "Мосфильм"
# 4382                              Киностудия "Мосфильм"
# 4383                              Киностудия "Мосфильм"
#
#                                           director  \
# 3093                      С.Эйзенштейн, Д.Васильев
# 3193                                     Э.Рязанов
# 3926                                       А.Аболс
# 3931                        К.Котельников, А.Аболс
# 3962  И.Цветов (режиссер ч/б фильма - С.Тимошенко)
# 4008                                      Ю.Озеров
# 4009                                      Ю.Озеров
# 4010                          Ю.Озеров, Ю.Бондарев
# 4011                          Ю.Озеров, Ю.Бондарев
# 4012                          Ю.Озеров, Ю.Бондарев
# 4381                              А.Алов, В.Наумов
# 4382                        Л.Трауберг, А.Тутышкин
# 4383                                    С.Алексеев
#
#                                                producer
# 3093                       ФГУП "Киноконцерн "Мосфильм"
# 3193  ЗАО "Киновидеообъединение "Крупный план", ООО ...
# 3926                                            А.Аболс
# 3931                                            А.Аболс
# 3962           ЗАО "Киновидеообъединение "Крупный план"
# 4008                       ФГУП "Киноконцерн "Мосфильм"
# 4009                       ФГУП "Киноконцерн "Мосфильм"
# 4010                       ФГУП "Киноконцерн "Мосфильм"
# 4011                       ФГУП "Киноконцерн "Мосфильм"
# 4012                       ФГУП "Киноконцерн "Мосфильм"
# 4381                       ФГУП "Киноконцерн "Мосфильм"
# 4382                       ФГУП "Киноконцерн "Мосфильм"
# 4383                       ФГУП "Киноконцерн "Мосфильм"
# ФГУП "Киноконцерн "Мосфильм"                                      8
# А.Аболс                                                           2
#  ФГУП "Киноконцерн "Мосфильм"                                     1
# ЗАО "Киновидеообъединение "Крупный план"                          1
# ЗАО "Киновидеообъединение "Крупный план", ООО "Формула цвета"     1
# Name: producer, dtype: int64

# %% [markdown]
# Из таблички выше можно предположить, что там, где в film_studio указан "Мосфильм", в колонке producer будет фигурировать ФГУП "Киноконцерн "Мосфильм". Также следует отметить наличие неявного дубликата в ФГУП "Киноконцерн "Мосфильм" (пробел спереди).

# %%
print(data[(data['film_studio'].str.contains('Мосфильм'))
           & (data['producer'].isna()) 
           & (data['production_country'].str.contains("СССР"))].shape[0])
# Out:
# 371

# %% [markdown]
# Таких строк набралось 371, поэтому я предположу. что если фильм выпущен в СССР, известно, на какой студии его снимали, то пропуски в колонке producer можно заполнить значением в колонке film_studio.

# %%
data.loc[(data['film_studio'].notna())
           & (data['producer'].isna()) 
           & (data['production_country'].str.contains("СССР")),'producer'] = data['film_studio']

# %%
display(data[data['producer'].isna()].shape[0])
# Out:
# 174

# %% [markdown]
# Оставшиеся 174 пропуска я заполню значением "неизвестно", так как я не могу с уверенностью предположить, для фильмов, не выпущенных в СССР, действует та же самая гипотеза, что я применил выше.

# %%
data['producer'].fillna("неизвестно",inplace=True)

# %% [markdown]
# ### Работа с дубликатами <a class="anchor" id="id_2e"></a>

# %% [markdown]
# Проверка на количество одинаковых строк:

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #### Колонка puNumber

# %%
#Проверка на повторения
df_tmp = data.groupby('puNumber')['puNumber'].count()
print(df_tmp.sort_values(ascending=False))
display(data[(data['puNumber']==221054410) | (data['puNumber']==221154310)])
# Out:
# puNumber
# 221054410    2
# 221154310    2
# 0            1
# 121029214    1
# 121029319    1
#             ..
# 121002912    1
# 121002911    1
# 121002910    1
# 121002819    1
# 231001111    1
# Name: puNumber, Length: 7484, dtype: int64
#                                                   title   puNumber  \
# 4638                   Как жениться и остаться холостым  221154310
# 4639  Иоанна - женщина на папском престоле /По роман...  221154310
# 5067                                    Анализируй это!  221054410
# 5068                                     Анализируй то!  221054410
#
#                show_start_date            type  \
# 4638 2010-12-17 12:00:00+00:00  Художественный
# 4639 2010-12-17 12:00:00+00:00  Художественный
# 5067 2010-05-25 12:00:00+00:00  Художественный
# 5068 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4638  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4639   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
# 5067          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 5068  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#                                 production_country        director  \
# 4638                                       Франция    Эрик Лартиго
# 4639  Германия - Великобритания - Италия - Испания  Зенке Вортманн
# 5067                                 США-Австралия   ХЭрольд Рэмис
# 5068                                           США  Гарольд Реймис
#
#                                         producer  \
# 4638                     Амандин Било, Алан Шаба
# 4639  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
# 5067             Джейн Розенталь, Пола Уейнстейн
# 5068             Джейн Розенталь, Паул Уэйнстейн
#
#                       age_restriction  refundable_support  \
# 4638  «16+» - для детей старше 16 лет                -1.0
# 4639  «16+» - для детей старше 16 лет                -1.0
# 5067  «16+» - для детей старше 16 лет                -1.0
# 5068  «12+» - для детей старше 12 лет                -1.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 4638                   -1.0    -1.0       неизвестно     7.0
# 4639                   -1.0    -1.0       неизвестно     7.6
# 5067                   -1.0    -1.0       неизвестно     7.4
# 5068                   -1.0    -1.0       неизвестно     6.8
#
#                        genres  box_office
# 4638        мелодрама,комедия        -1.0
# 4639  драма,мелодрама,история        -1.0
# 5067         комедия,криминал        -1.0
# 5068         комедия,криминал        -1.0

# %% [markdown]
# **Краткий вывод.**
# Изучение этих строк, а также базы данных кинопоиска, дает основание полагать, что это все разные фильмы. Причиной этих дубликатов является, мне кажется, человеческий фактор.
# Так как по условию проекта,  фильм может иметь несколько прокатных удостоверений, но последнее не может распространяться на несколько фильмов, я принял решение присвоить им разные значения в рамках проекта. Так как нуль означает отсутствие удостоверения, то присвою им уникальные значения.

# %%
display(data.query('puNumber==-222222222 or puNumber==-333333333'))
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %% [markdown]
# Так как таких значений нет в базе данных, присвою их:

# %%
data.loc[4639,'puNumber'] = (-222222222)
df_movies.loc[5068,'puNumber'] = (-333333333)

# %% [markdown]
# #### Колонка type

# %% [markdown]
# Нахождение уникальных значений

# %%
print(data['type'].unique())
# Out:
# ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
#  'Научно-популярный' ' Художественный' ' Анимационный'
#  'Музыкально-развлекательный']

# %% [markdown]
# Удаление левого пробела:

# %%
data['type'] = data['type'].apply(lambda x:x.lstrip())
print(data['type'].unique())
# Out:
# ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
#  'Научно-популярный' 'Музыкально-развлекательный']

# %% [markdown]
# #### Колонка title

# %%
#Функция для вывода  списков более 1000 элементов в юпитере без многоточий
def print_long_lists(lst):
    count=0
    n=1
    while count<len(lst):
        print(lst[count:n*1000],end=' ')        
        count+=1000
        n+=1
        if count==len(lst):
            print(lst[-1])
    else:
        print('\nКонец списка, количество элементов: ',len(lst))

# %% [markdown]
# Поиск уникальных имен:

# %%
title_unique = data['title'].sort_values().unique()
print('Длина списка уникальных имен',len(title_unique))
# Out:
# Длина списка уникальных имен 6772

# %% [markdown]
# Подсчет дубликатов:

# %%
print('Количество дубликатов в колонке: ',data['title'].duplicated().sum())
print(data.groupby('title')['title'].count().sort_values(ascending=False))
# Out:
# Количество дубликатов в колонке:  714
# title
# День святого Валентина_          5
# Там, где живут чудовища          4
# Рапунцель: Запутанная история    4
# Дом грёз                         4
# Белоснежка и охотник             4
#                                 ..
# Исправленному верить             1
# Исполнительный лист              1
# Исполнение желаний.              1
# Исповедь содержанки              1
# сНежное шоу                      1
# Name: title, Length: 6772, dtype: int64

# %% [markdown]
# Более внимательный осмотр:

# %%
display(data[data['title'].str.contains('Гарри Поттер')].sort_values('title'))
display(data[data['title'].isin(['Волшебная страна','Хаббл 3D','Прощание','Багровый пик','Остров лемуров'])].sort_values('title')[['title','box_office','show_start_date','film_studio','director','ratings']])
# Out:
#                                                   title   puNumber  \
# 5057  Гарри Поттер и Дары Смерти - Часть 1/По роману...  221068911
# 4526  Гарри Поттер и Дары Смерти - Часть 1/По роману...  221144910
# 110   «16+» - для детей старше 16 лет                -1.0
# 109   «16+» - для детей старше 16 лет                -1.0
# 111   «12+» - для детей старше 12 лет                -1.0
# 4429  «12+» - для детей старше 12 лет                -1.0
# 113   «12+» - для детей старше 12 лет                -1.0
# 112   «12+» - для детей старше 12 лет                -1.0
# 4192  «12+» - для детей старше 12 лет                -1.0
# 4193  «12+» - для детей старше 12 лет                -1.0
# 114   «12+» - для детей старше 12 лет                -1.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 5057                   -1.0    -1.0       неизвестно     8.1
# 4526                   -1.0    -1.0       неизвестно     8.1
# 4198                   -1.0    -1.0       неизвестно     8.1
# 371                    -1.0    -1.0       неизвестно     8.1
# 4872                   -1.0    -1.0       неизвестно     8.1
# 395                    -1.0    -1.0       неизвестно     8.1
# 337                    -1.0    -1.0       неизвестно     7.7
# 4428                   -1.0    -1.0       неизвестно     7.7
# 121                    -1.0    -1.0       неизвестно     7.9
# 122                    -1.0    -1.0       неизвестно     7.9
# 4426                   -1.0    -1.0       неизвестно     7.9
# 4427                   -1.0    -1.0       неизвестно     7.7
# 110                    -1.0    -1.0       неизвестно     7.7
# 109                    -1.0    -1.0       неизвестно     7.7
# 111                    -1.0    -1.0       неизвестно     8.0
# 4429                   -1.0    -1.0       неизвестно     8.0
# 113                    -1.0    -1.0       неизвестно     8.2
# 112                    -1.0    -1.0       неизвестно     8.2
# 4192                   -1.0    -1.0       неизвестно     8.2
# 4193                   -1.0    -1.0       неизвестно     8.2
# 114                    -1.0    -1.0       неизвестно     8.2
#
#                             genres  box_office
# 5057        фэнтези,драма,детектив        -1.0
# 4526        фэнтези,драма,детектив        -1.0
# 4198        фэнтези,драма,детектив     1,700.0
# 371         фэнтези,драма,детектив   745,510.0
# 4872        фэнтези,драма,детектив     9,000.0
# 395         фэнтези,драма,детектив 1,017,220.0
# 337   фэнтези,приключения,семейный   883,640.0
# 4428  фэнтези,приключения,семейный        -1.0
# 121   фэнтези,приключения,семейный        -1.0
# 122   фэнтези,приключения,семейный   843,310.0
# 4426  фэнтези,приключения,семейный        -1.0
# 4427  фэнтези,приключения,семейный        -1.0
# 110   фэнтези,приключения,семейный   759,526.0
# 109   фэнтези,приключения,семейный        -1.0
# 111   фэнтези,приключения,семейный 1,093,810.0
# 4429  фэнтези,приключения,семейный        -1.0
# 113   фэнтези,приключения,семейный 1,125,302.0
# 112   фэнтези,приключения,семейный        -1.0
# 4192  фэнтези,приключения,семейный        -1.0
# 4193  фэнтези,приключения,семейный        -1.0
# 114   фэнтези,приключения,семейный 1,948,760.0
#                  title    box_office           show_start_date  \
# 2608      Багровый пик       1,200.0 2016-06-10 12:00:00+00:00
# 2609      Багровый пик          -1.0 2016-02-19 12:00:00+00:00
# 2610      Багровый пик 294,842,966.0 2015-07-23 12:00:00+00:00
# 107   Волшебная страна          -1.0 2016-02-09 12:00:00+00:00
# 4653  Волшебная страна          -1.0 2010-12-17 12:00:00+00:00
# 266           Прощание          -1.0 2014-12-24 12:00:00+00:00
# 5514          Прощание          -1.0 2017-09-07 12:00:00+00:00
# 6909          Прощание          -1.0 2019-05-01 12:00:00+00:00
# 7281          Прощание   2,617,932.5 2019-10-07 12:00:00+00:00
# 4301          Хаббл 3D     245,630.0 2010-09-23 12:00:00+00:00
# 5220          Хаббл 3D      52,115.0 2011-09-15 12:00:00+00:00
#
#                                             film_studio            director  \
# 2608                                 Леджендари Пикчерз  Гильермо дель Торо
# 2609                                 Леджендари Пикчерз  Гильермо дель Торо
# 2610                                 Леджендари Пикчерз  Гильермо дель Торо
# 107                                         Филм Колони        Марк Форстер
# 4653                                        Филм Колони        Марк Форстер
# 266                               Киностудия "Мосфильм"            Э.Климов
# 5514  Всероссийский государственный институт кинемат...        А.Петровская
# 6909                      ИП Киселев Алексей Евгеньевич            М.Фомина
# 7281        Биг Бич Филмз, Депз оф Филд, Киндред Спирит           Лулу Ванг
# 4301                       Аймакс Спейс, Уорнер Бразерс         Тони Майерс
# 5220                       Аймакс Спейс, Уорнер Бразерс         Тони Майерс
#
#      ratings
# 2608     6.6
# 2609     6.6
# 2610     6.6
# 107      7.9
# 4653     7.9
# 266      7.2
# 5514     7.2
# 6909     7.2
# 7281     7.2
# 4301     7.6
# 5220     7.6

# %%
display(data.loc[data['title'].isin(
    ['День святого Валентина','Там, где живут чудовища','Рапунцель: Запутанная история','Дом грёз','Белоснежка и охотник']
)].sort_values('title').sort_values('box_office',ascending=False)[['title','box_office','show_start_date','director','ratings']])
# Out:
#                               title  box_office           show_start_date  \
# 446            Белоснежка и охотник   470,427.0 2012-05-25 12:00:00+00:00
# 4378  Рапунцель: Запутанная история    17,055.0 2010-11-23 12:00:00+00:00
# 445            Белоснежка и охотник        -1.0 2016-06-29 12:00:00+00:00
# 447            Белоснежка и охотник        -1.0 2012-07-17 12:00:00+00:00
# 448            Белоснежка и охотник        -1.0 2012-12-11 12:00:00+00:00
# 385                        Дом грёз        -1.0 2015-02-25 12:00:00+00:00
# 386                        Дом грёз        -1.0 2012-04-26 12:00:00+00:00
# 5085                       Дом грёз        -1.0 2011-09-21 12:00:00+00:00
# 5340                       Дом грёз        -1.0 2011-11-11 12:00:00+00:00
# 378   Рапунцель: Запутанная история        -1.0 2014-10-10 12:00:00+00:00
# 379   Рапунцель: Запутанная история        -1.0 2012-10-23 12:00:00+00:00
# 4761  Рапунцель: Запутанная история        -1.0 2010-12-31 12:00:00+00:00
# 3855        Там, где живут чудовища        -1.0 2010-03-29 12:00:00+00:00
# 4717        Там, где живут чудовища        -1.0 2010-04-14 12:00:00+00:00
# 4807        Там, где живут чудовища        -1.0 2011-01-20 12:00:00+00:00
# 7143        Там, где живут чудовища        -1.0 2019-08-16 12:00:00+00:00
#
#                         director ratings
# 446               Руперт Сандерс     6.0
# 4378  Натан Грино, Байрон Ховард     7.9
# 445               Руперт Сандерс     6.0
# 447               Руперт Сандерс     6.0
# 448               Руперт Сандерс     6.0
# 385                 Джим Шеридан     7.6
# 386                 Джим Шеридан     7.6
# 5085                Джим Шеридан     7.6
# 5340                Джим Шеридан     7.6
# 378   Натан Грино, Байрон Ховард     7.9
# 379   Натан Грино, Байрон Ховард     7.9
# 4761  Натан Грино, Байрон Ховард     7.9
# 3855                 Спайк Джонз     6.9
# 4717                 Спайк Джонз     6.9
# 4807                 Спайк Джонз     6.9
# 7143                 Спайк Джонз     6.9

# %% [markdown]
# **Краткий вывод.**
# Причиной образования дубликатов в этой колонке является возможность того, что фильм может иметь несколько прокатных удостоверений. Соответственно. когда одна база данных брала информацию от другой базы данных, они не делали проверку на совпадение названий. Также возможно, что фильмы имели несколько премьер в России, отсюда и их разные кассовые сборы. Причиной также могут быть критерии, по каким кассовые сборы попадают в базу данных.
# Рассмотрев вышеприведенные таблички, я пришел заключению, что способом удаления дубликатов будет следующий порядок:
# - сначала сортировка датафрейма по именам в возрастающем порядке;
# - сортировка по кассовым сборам в убывающем порядке;
# - применение drop_duplicates c проверкой по колонкам title, box_office,рейтинг, директор, с оставлением первого значения;
# - применение drop() для удаления строк с условием, что они дубликаты по имени и box_office меньше нуля

# %% [markdown]
# Удаление пробелов и других знаков:

# %%
data['title'] = data['title'].str.strip().str.strip(',').str.strip('_').str.strip('.').str.strip('  ').str.replace('#',' ')
title_unique = data['title'].sort_values().unique()
print(len(title_unique))
print(data['title'].duplicated().sum())
# Out:
# 6681
# 805

# %% [markdown]
# Удаление дубликатов имен:

# %%
data = data.sort_values('title').sort_values('box_office',ascending=False).drop_duplicates(
    subset=['title','ratings','box_office','director'])
data = data[(data['title'].duplicated()==False) & data['box_office']!=(-1.0)]
print(data['title'].duplicated().sum())
# Out:
# 295

# %% [markdown]
# Проверочная информация:

# %%
print(data.groupby('title')['title'].count().sort_values(ascending=False))
display(data.loc[data['title'].isin(
    ['День святого Валентина','Там, где живут чудовища','Рапунцель: Запутанная история',
     'Дом грёз','Белоснежка и охотник','Хаббл 3D','Прощание','Волшебная страна']
)].sort_values('title')[['title','box_office','show_start_date','director','ratings']])
display(data[data['title'].str.contains('Гарри Поттер')].sort_values('title')[['title','box_office','show_start_date','director','ratings']])
display(data[data['title'].isin(['Волшебная страна','Прощание','Багровый пик','Остров лемуров','Успех','Вторжение','Гадкий Я'])].sort_values('title')[['title','box_office','show_start_date','director','ratings']])
# Out:
# title
# Хаббл 3D                                                       4
# Прощание                                                       4
# Волшебная страна                                               4
# Гарри Поттер и Дары Смерти - Часть 1/По роману Дж.К.Ролинг/    3
# Лесной патруль                                                 3
#                                                               ..
# Интимный дневник                                               1
# Интимные места                                                 1
# Интерстеллар                                                   1
# Интердевочка                                                   1
# сНежное шоу                                                    1
# Name: title, Length: 6681, dtype: int64
#                               title  box_office           show_start_date  \
# 447            Белоснежка и охотник        -1.0 2012-07-17 12:00:00+00:00
# 446            Белоснежка и охотник   470,427.0 2012-05-25 12:00:00+00:00
# 2120               Волшебная страна 1,171,085.6 2015-02-05 12:00:00+00:00
# 937                Волшебная страна    20,260.0 2013-04-15 12:00:00+00:00
# 936                Волшебная страна     3,750.0 2016-06-07 12:00:00+00:00
# 4550          Оливер Хиршбигель, Джеймс  МакТиг     5.7
# 7474                                Ф.Бондарчук     5.7
# 5430                               Эрик Дарнелл     5.7
# 4236                     Пьер Коффин, Крис Рено     7.7
# 4748                     Пьер Коффин, Крис Рено     7.7
# 4488                     Пьер Коффин, Крис Рено     7.7
# 7281                                  Лулу Ванг     7.2
# 6909                                   М.Фомина     7.2
# 266                                    Э.Климов     7.2
# 5514                               А.Петровская     7.2
# 7322                                  П.Руминов     7.8
# 309                                   К.Худяков     7.8
# 5937                                   В.Сунцов     7.8

# %% [markdown]
# Выборочное удаление строк:

# %%
data = data.loc[data.index.drop([2609,4526,4770,4761,447,4429,4427,121,4428,4193,4192,4488])]
print(data['title'].duplicated().sum())
# Out:
# 283

# %% [markdown]
# #### Колонка genres

# %% [markdown]
# Поиск уникальных имен, подсчет дубликатов:

# %%
genres_unique = data['genres'].sort_values().unique()
print('Длина списка уникальных имен',len(genres_unique))
print('Количество дубликатов в колонке: ', data['genres'].duplicated().sum())
# Out:
# Длина списка уникальных имен 743
# Количество дубликатов в колонке:  6221

# %% [markdown]
# Дубликаты в этой колонке вызваны тем, что фильмов очень много. а жанров относительно мало, отсюда множество повторений.

# %% [markdown]
# Удаление пробелов и прочих знаков, приведение к нижнему регистру:

# %%
data['genres'] = data['genres'].str.strip().str.lower().str.strip(',').str.strip('_').str.strip('.').str.strip('  ')
print(data['genres'].duplicated().sum())
# Out:
# 6221

# %%
#Функция для обработки дубликатов
def find_duplicates_base(lst):
    sorted_tmp1 = [] # список уникальных строк
    sorted_tmp2 = [] #список строк-дубликатов
    filtered_genres = [] #список слов в каждой строке-дубликате
    for element in lst:
        #Приведение строк в отсортированный вид
        sorted_string = sorted(element)
        #Строки считаются идентичными, если равны их отсортированные версии
        if sorted_string not in sorted_tmp1:
            sorted_tmp1.append(sorted_string)
        else:
            sorted_tmp2.append(element)    
    for ele in sorted_tmp2:               
        words = [word.lower() for word in ele.split(',')]
        #сортировка слов в списке по алфавиту
        sorted_order = sorted(words)
        if sorted_order not in filtered_genres:
            filtered_genres.append(sorted_order)    
    res = [','.join (_ele) for _ele in filtered_genres]
    return res

# %% [markdown]
# Вывод строк-дубликатов, отcортированных по алфавиту:

# %%
duplicated_genres = find_duplicates_base(genres_unique)
print(duplicated_genres,len(duplicated_genres))
# Out:
# ['биография,военный,драма', 'биография,драма,история', 'биография,драма,криминал', 'боевик,военный,драма', 'боевик,драма,история', 'боевик,драма,криминал', 'боевик,драма,триллер', 'боевик,криминал,триллер', 'боевик,приключения,триллер', 'боевик,вестерн,драма', 'боевик,вестерн,приключения', 'боевик,военный,история', 'военный,драма,история', 'боевик,детектив,криминал', 'детектив,драма,криминал', 'боевик,детектив,триллер', 'детектив,драма,триллер', 'детектив,криминал,триллер', 'биография,документальный', 'биография,документальный,музыка', 'биография,документальный,спорт', 'биография,драма', 'биография,драма,музыка', 'биография,драма,спорт', 'боевик,драма', 'боевик,драма,приключения', 'военный,драма', 'военный,драма,приключения', 'детектив,драма,история', 'детектив
# %%
display(data[data['genres'].str.contains('биография') 
             & data['genres'].str.contains('драма') 
             & data['genres'].str.contains('военный') ]['genres'].head(5))
# Out:
# 2132    биография,военный,драма
# 3265    драма,военный,биография
# 3503    драма,военный,биография
# 7192    биография,драма,военный
# 6761    драма,военный,биография
# Name: genres, dtype: object

# %% [markdown]
# Так как потом будет задание на главный жанр, я не стал приводить их в отсортированный вид.

# %%
print(len(genres_unique))
# Out:
# 743

# %% [markdown]
# #### Колонка film_studio

# %% [markdown]
# Поиск уникальных имен, подсчет дубликатов:

# %%
studio_unique = data['film_studio'].sort_values().unique()
print('Длина списка уникальных имен',len(studio_unique))
print('Количество дубликатов в колонке: ',data['film_studio'].duplicated().sum())
#print_long_lists(studio_unique)
# Out:
# Длина списка уникальных имен 5478
# Количество дубликатов в колонке:  1486

# %%
display(data[data['film_studio'].duplicated() & data['production_country'].str.contains('СССР')].shape[0])
# Out:
# 359

# %% [markdown]
# Наличие дубликатов в этой колонке связано с наличием крупных киностудий, которые выпускают фильмы в массовом порядке, также четверть  дубликатов приходится на СССР, где существовало несколько крупных студий, которые выпускали фильмы.

# %% [markdown]
# Удаление пробелов и прочих знаков:

# %%
data['film_studio'] = data['film_studio'].str.strip().str.strip(',').str.strip('_').str.strip('.').str.strip('  ')
print(data['film_studio'].duplicated().sum())
# Out:
# 1516

# %% [markdown]
# #### Колонка production_country

# %% [markdown]
# Поиск уникальных имен, подсчет дубликатов:

# %%
country_unique = data['production_country'].sort_values().unique()
print('Длина списка уникальных имен',len(country_unique))
print('Количество дубликатов в колонке: ',data['production_country'].duplicated().sum())
print_long_lists(country_unique)
# Out:
# Длина списка уникальных имен 948
# Количество дубликатов в колонке:  6016
# [' СССР' ' СССР ' ' СССР   ' '2019' 'CША' 'Австралия'
#  'Австралия - Великобритания - Бельгия - Индия' 'Австралия - Германия'
#  'Австралия - Ирландия' 'Австралия - Колумбия' 'Австралия - США'
#  'Австралия, Канада' 'Австралия, США' 'Австралия-Великобритания'
#  'Австралия-Ирландия' 'Австралия-США' 'Австралия-Турция-США' 'Австрия'
#  'Австрия - Германия' 'Австрия - Германия - Франция'
#  'Австрия - Люксембург' 'Австрия, Великобритания, Германия'
#  'Австрия-Германия-Франция' 'Австрия-Франция-Германия'
#  'Азербайджан-Россия' 'Аргентина' 'Аргентина - Бразилия'
#  'Аргентина - Испания' 'Аргентина - Испания - Уругвай'
#  'Аргентина - Мексика - Бразилия - Франция - США'
#  'Аргентина - Уругвай - Россия - Германия - Франция - Нидерланды'
#  'Аргентина - Франция - Испания' 'Аргентина, Испания' 'Аргентина-Испания'
#  'Армения' 'Армения - Германия' 'Армения - Казахстан' 'Армения-Россия'
#  'Бельгия' 'Бельгия - Германия - Люксембург'
#  'Бельгия - Германия - Люксембург - Франция'
#  'Россия, Австрия' 'Россия, Армения' 'Россия, Бельгия, Финляндия'
#  'Россия, Германия' 'Россия, Германия, Великобритания'
#  'Россия, Германия, Казахстан, Польша, Китай'
#  'Россия, Германия, Франция, Бельгия' 'Россия, Грузия, Испания'
#  'Россия, Грузия, Хорватия, Испания' 'Россия, Испания' 'Россия, Италия'
#  'Россия, Казахстан, США' 'Россия, Латвия, Чешская Республика'
#  'Россия, Нидерланды, Финляндия' 'Россия, Польша, Финляндия'
#  'Россия, Республика Беларусь' 'Россия, Республика Кипр' 'Россия, Румыния'
#  'Россия, Сербия' 'Россия, Таджикистан' 'Россия, Украина'
#  'Россия, Украина, Польша' 'Россия, Украина, Республика Беларусь, Литва'
#  'Россия, Франция, Германия, Бельгия' 'Россия, Франция, Латвия'
#  'Россия-Азербайджан' 'Россия-Беларусь' 'Россия-Белоруссия'
#  'Россия-Германия' 'Россия-Ирландия' 'Россия-Италия' 'Россия-Казахстан'
#  'Россия-Кипр' 'Россия-Китай' 'Россия-Польша'
#  'Россия-Польша-Голландия-Словакия' 'Россия-США'
#  'Россия-США-Канада-Люксембург' 'Россия-Словакия-Чехия' 'Россия-Украина'
#  'Россия-Украина-Германия' 'Россия-Франция' 'Румыния'
#  'Румыния - Франция - Бельгия'
#  'Румыния, ЮАР, Иран, Франция, Канада, Великобритания' 'Румыния-США'
#  'СССР' 'СССР ' 'СССР  ' 'СССР   ' 'СССР    ' 'СССР     '
#  'СССР - ГДР - Польша - Италия' 'СССР - Италия'
#  'СССР - Швейцария - Франция' 'СССР, Албания' 'СССР, Афганистан'
#  'СССР, ВНР' 'СССР, Венгрия' 'СССР, Венгрия, ЧССР, ГДР' 'СССР, ГДР'
#  'СССР, Италия' 'СССР, Монголия' 'СССР, Польша' 'СССР, Россия'
#  'СССР, Румыния, Франция' 'СССР, ФРГ' 'СССР, ФРГ, Западный Берлин'
#  'СССР, Финляндия' 'СССР, Франция, Англия, Куба, ГДР'
#  'СССР, ЧССР, Западный Берлин, ПНР' 'СССР, Швеция' 'США' 'США '
#  'США - Австралия' 'США - Австралия - Дания' 'США - Австралия - Индия'
#  'США - Австралия - Мексика'
#  'США - Австралия - Новая Зеландия - Великобритания'
#  'США - Австралия - Франция' 'США - Бельгия'
#  'США - Бельгия - Великобритания' 'США - Болгария - Мексика'
#  'США - Бразилия - Великобритания - Канада'
#  'США - Бразилия - Франция - Австралия - Великобритания - Германия'
#  'США - Великобритания' 'США - Великобритания '
#  'США - Великобритания - Австралия' 'США - Великобритания - Болгария'
#  'США - Великобритания - Германия'
#  'США - Великобритания - Германия - - Швеция - Канада'
#  'США - Великобритания - Германия - Бельгия - Дания'
#  'США - Великобритания - Германия - Новая Зеландия - Бельгия - Франция'
#  'США - Великобритания - Ирландия' 'США - Великобритания - Исландия'
#  'США - Великобритания - Испания'
#  'США - Великобритания - Италия - Израиль - Сербия - Индия'
#  'США - Великобритания - КНР' 'США - Великобритания - Канада'
#  'США - Великобритания - Канада - КНР'
#  'США - Великобритания - Канада - Швеция'
#  'Чехия - Словакия - Хорватия' 'Чехия-Великобритания-США' 'Чехословакия'
#  'Чили' 'Чили - Испания' 'Чили - Франция - США' 'Швейцария'
#  'Швейцария - Австрия' 'Швейцария - Великобритания'
#  'Швейцария - Израиль - Франция - Великобритания'
#  'Швейцария - КНР - США - Россия - Республика Корея - Великобритания'
#  'Швейцария - Люксембург' 'Швейцария - Франция'
#  'Швейцария, Великобритания, Франция, США, Ирландия' 'Швейцария-Австрия'
#  'Швейцария-Германия-ЮАР' 'Швейцария-Франция' 'Швеция' 'Швеция - Германия'
#  'Швеция - Германия - Дания - Норвегия'
#  'Швеция - Германия - Франция - Дания'
#  'Швеция - Германия - Франция - Норвегия' 'Швеция - Дания'
#  'Швеция - Дания - Финляндия' 'Швеция - Норвегия' 'Швеция - США'
#  'Швеция - Франция - Норвегия - Дания'
#  'Швеция, Норвегия, Финляндия, Франция' 'Швеция, Франция, Великобритания'
#  'Швеция-Куба' 'Швеция-Финляндия-Франция-Норвегия' 'Швеция-Франция'
#  'Швеция-Франция-Дания' 'Эстония' 'Эстония - Россия' 'ЮАР' 'ЮАР - США'
#  'Южная Корея' 'Южная Корея - КНР' 'Южная Корея - США'
#  'Южная Корея - США - Канада' 'Япония' 'Япония - Великобритания - Франция'
#  'Япония - Великобритания - Швейцария - Ирландия - Дания - Франция - Польша - Австралия - Канада  '
#  'Япония - КНР - Южная Корея' 'Япония - Канада' 'Япония - США'
#  'Япония - Франция - США - Южная Корея - Турция' 'Япония, Великобритания'
#  'Япония, Великобритания, Австрия, Германия, Ю.Корея' 'Япония, США'
#  'Япония-Великобритания' 'Япония-США-Франция']
# Конец списка, количество элементов:  948

# %% [markdown]
# Осмотр особых случаев:

# %%
display(data[data['production_country'].str.contains('Ю.Корея')]['production_country'])
# Out:
# 2141                                         США- Ю.Корея
# 7045                          США - КНР - Индия - Ю.Корея
# 2334    Япония, Великобритания, Австрия, Германия, Ю.К...
# Name: production_country, dtype: object

# %% [markdown]
# Дубликаты в этой колонке связаны с тем, что стран на Земле всего 166, а фильмов много.

# %%
##Удаление пробелов и прочих знаков
data['production_country'] = data['production_country'].str.strip().str.strip(',').str.strip('_').str.strip('.').str.strip('  ')  
print(data['production_country'].duplicated().sum())
# Out:
# 6032

# %%
# Функция для приведения строк к единообразному виду слов, разделенных запятой.
def country_names(name):    
    name = str(name) # приведение передаваемого функции объекта в строку, чтобы метод split() работал
    #удаление пробелов в начале и конце строки
    name.strip()
    #Если вы залили пропущенные значения чем-то другим, можно здесь поменять
    #Если у вас в колонке были NaN, то на месте новых имен будут пропуски
    if 'неизвестно' in name:
        return 'неизвестно'    
    elif name.isupper():   # случаи аббревиатур типа СССР, США
        if '-' in name:    # на случай вроде США-ЮАР
            temp = name.split('-')   #  разбиваем строку на элементы, разделенные дефисом и собираем в список
            new_name = ",".join([ele for ele in temp] ) # собираем новую строку. присоединяя элементы списка через запятую
            return new_name
        else:
            return name
    elif '-' in name:    # на случай если слова разделены дефисом           
        temp = name.split('-')   
        new_name = ",".join([ele for ele in temp] ) 
        return new_name
        
    elif ',' in name: # если трока содержит запятую
        if '.' in name:  # а также точки
            temp = name.split('.')    # сначала разбиваем по точкам и собираем в список
            temp = name.split(',')    # затем разбиваем по запятым и переназначаем переменную ссылаться на новый лист
            new_name = ",".join([ele for ele in temp] )  
            return new_name
        else:             # если слова разделены запятой, то это нас устраивает 
            return name
    else:        #случаи если слова просто через пробел
        temp = name.split()
        new_name = ",".join([ele for ele in temp] )
        return new_name

# %% [markdown]
# Создание новой колонки с отформатированными строчками и вывод проверочной информации:

# %%
data['country'] = data['production_country'].apply(country_names)
data['country'] = data['country'].replace('СЩА','США')
display(data[data['country'].isna()][['production_country','country']])
display(data[['production_country','country']])
print(data.loc[6333,'production_country'])
display(data[data['country'].str.contains('Ю.Корея')][['production_country','country']])
# Out:
# Empty DataFrame
# Columns: [production_country, country]
# Index: []
#      production_country           country
# 7456             Россия            Россия
# 5653             Россия            Россия
# 6820                США               США
# 6549             Россия            Россия
# 3488                США               США
# ...                 ...               ...
# 1797             Россия            Россия
# 7009    Россия - Грузия   Россия , Грузия
# 5074                США               США
# 5037                США               США
# 1080   Франция - Россия  Франция , Россия
#
# [6964 rows x 2 columns]
# Дания, Швеция, Великобритания, Франция, Германия, Норвегия, Финляндия, Нидерланды, Италия
#                                      production_country  \
# 2141                                       США- Ю.Корея
# 7045                        США - КНР - Индия - Ю.Корея
# 2334  Япония, Великобритания, Австрия, Германия, Ю.К...
#
#                                                 country
# 2141                                       США, Ю.Корея
# 7045                        США , КНР , Индия , Ю.Корея
# 2334  Япония, Великобритания, Австрия, Германия, Ю.К...

# %%
new = data['country'].sort_values().unique()
print_long_lists(new)
# Out:
# ['2019' 'CША' 'Австралия' 'Австралия , Великобритания , Бельгия , Индия'
#  'Австралия , Германия' 'Австралия , Ирландия' 'Австралия , Колумбия'
#  'Австралия , США' 'Австралия, Канада' 'Австралия, США'
#  'Австралия,Великобритания' 'Австралия,Ирландия' 'Австралия,США'
#  'Австралия,Турция,США' 'Австрия' 'Австрия , Германия'
#  'Австрия , Германия , Франция' 'Австрия , Люксембург'
#  'Австрия, Великобритания, Германия' 'Австрия,Германия,Франция'
#  'Австрия,Франция,Германия' 'Азербайджан,Россия' 'Аргентина'
#  'Аргентина , Бразилия' 'Аргентина , Испания'
#  'Аргентина , Испания , Уругвай'
#  'Аргентина , Мексика , Бразилия , Франция , США'
#  'Аргентина , Уругвай , Россия , Германия , Франция , Нидерланды'
#  'Аргентина , Франция , Испания' 'Аргентина, Испания' 'Аргентина,Испания'
#  'Армения' 'Армения , Германия' 'Армения , Казахстан' 'Армения,Россия'
#  'Бельгия' 'Бельгия , Германия , Люксембург'
#  'Бельгия , Германия , Люксембург , Франция'
#  'Бельгия , Испания , Канада , Нидерланды' 'Бельгия , Италия , Франция'
#  'Бельгия , Люксембург' 'Бельгия , Люксембург , Франция , Швейцария'
#  'Бельгия , Нидерланды , Франция' 'Бельгия , США' 'Бельгия , Франция'
#  'Бельгия , Франция , Люксембург' 'Бельгия, Великобритания, США'
#  'Бельгия, Канада' 'Бельгия,Германия,Канада,Франция,США,Великобритания'
#  'Бельгия,Нидерланды' 'Бельгия,Франция' 'Бельгия,Франция,Италия'
#  'Болгария' 'Болгария , США' 'Болгария , Франция , Изриль'
#  'Босния и Герцеговина , Франция , Великобритания , Германия , Словения , Бельгия , Сербия'
#  'Бразилия' 'Бразилия , Германия , Порртугалия , Франция'
#  'Бразилия , Испания' 'Бразилия , К;анада' 'Бразилия , Канада , США'
#  'Бразилия , Португалия , Франция' 'Бразилия , США' 'Бразилия , США , КНР'
#  'Бразилия, Уругвай, Дания, Норвегия, Чили, Швеция' 'Великобритания'
#  'Великобритания , Австралия , США' 'Великобритания , Австрия , Германия'
#  'Великобритания , Австрия , Франция , США'
#  'Великобритания , Аргентина , США , Франция , Россия , Испания'
#  'Великобритания , Германия'
#  'Великобритания , Германия , Нидерланды , Дания'
#  'Великобритания , Германия , США'
#  'Великобритания , Германия , Франция , Кипр , США'
#  'Великобритания , Гонконг , Венгрия , США , Ирландия'
#  'Великобритания , Дания' 'Великобритания , Израиль'
#  'Великобритания , Израиль , Франция , Япония , США'
#  'Великобритания , Ирландия' 'Великобритания , Ирландия , США'
#  'Великобритания , Исландия , Испания , Швейцария , США'
#  'Великобритания , Испания' 'Великобритания , Испания , Германия'
#  'Великобритания , Испания , Италия , Латвия , Франция , Эстония'
#  'Великобритания , Испания , Непал , Индия , Венгрия , Гонконг , Германия , Дания , Бахрейн'
#  'Великобритания , Италия' 'Великобритания , Италия , Испания'
#  'Великобритания , Италия , Швейцария' 'Великобритания , КНР'
#  'Великобритания , Канада' 'Великобритания , Канада , США'
#  'Великобритания , Люксембург' 'Великобритания , Мексика , США'
#  'Великобритания , Нидерланды , Германия , Франция , Бельгия , Австрия'
#  'Великобритания , Нидерланды , Франция , США'
#  'Великобритания , Нидерланды , Франция , Хорватия'
#  'Великобритания , Новая Зеландия'
#  'Великобритания , Норвегия , Дания , Германия'
#  'Великобритания , Норвегия , Кения , Хорватия' 'Великобритания , Польша'
#  'Великобритания , Польша , КНР , Индия , Норвегия'
#  'Великобритания , Пуэрто,Рико' 'Великобритания , Россия , КНР'
#  'Великобритания , Россия , Украина , США' 'Великобритания , Румыния'
#  'Великобритания , США'
#  'Великобритания , США , Австралия , Ирландия , Германия , Куба , Канада'
#  'Великобритания , США , Германия'
#  'Великобритания , США , Германия , Бельгия'
#  'Великобритания , США , Германия , Канада , Австралия'
#  'Великобритания , США , Индия' 'Великобритания , США , Канада'
#  'Великобритания , США , Канада , Бельгия , Нидерланды , Австрия , Германия'
#  'Великобритания , США , Канада , Нидерланды , Франция'
#  'Великобритания , США , Россия' 'Великобритания , США , Франция'
#  'Великобритания , США , Швейцария' 'Великобритания , Франция'
#  'Великобритания , Франция , Австрия , Швеция'
#  'Великобритания , Франция , Бельгия'
#  'Великобритания , Франция , Бельгия , Италия'
#  'Великобритания , Франция , Бельгия , США'
#  'Великобритания , Франция , Венгрия'
#  'Германия, Франция, США' 'Германия,Австрия'
#  'Германия,Австрия,Франция,Италия' 'Германия,Великобритания'
#  'Германия,Израиль' 'Германия,Италия, Шри,Ланка'
#  'Германия,Италия,Швейцария'
#  'Германия,Канада,Великобритания,Швейцария,Франция'
#  'Германия,Канада,Франция,Бельгия' 'Германия,Кения' 'Германия,США'
#  'Германия,Украина,Нидерланды' 'Германия,Франция,Великобритания'
#  'Германия,Франция,Великобритания,США' 'Германия,Франция,Польша'
#  'Германия,Швеция' 'Голландия' 'Гонконг' 'Гонконг , КНР'
#  'Гонконг , Сингапур , Таиланд , Великобритания' 'Гонконг, КНР' 'Греция'
#  'Греция , Германия , Франция' 'Греция , Россия' 'Грузия'
#  'Грузия , Россия , Украина , Хорватия , Германия' 'Грузия , Украина'
#  'Грузия , Франция , Люксембург' 'Грузия,Россия' 'Грузия,Франция' 'Дания'
#  'Дания , Австрия , Ирландия , Финляндия , Норвегия , Швеция , Нидерланды'
#  'Дания , Великобритания , ЮАР' 'Дания , Германия'
#  'Дания , Германия , Швеция' 'Дания , Исландия'
#  'Дания , Канада , Швеция , Франция , Германия , Великобритания , США'
#  'Дания , Латвия , Россия , США' 'Дания , Норвегия , Великобритания'
#  'Дания , США' 'Дания , Франция , Германия , Швеция'
#  'Дания , Франция , Италия , Бельгия , Нидерланды'
#  'Дания , Швейцария , Бельгия , Франция' 'Дания , Швеция'
#  'Дания , Швеция , Италия , Франция , Германия'
#  'Дания, Канада, Норвегия, Австралия, США'
#  'Дания, Норвегия, Венгрия, Чехия' 'Дания, Норвегия, Швеция, Исландия'
#  'Дания, Швеция, Великобритания, Франция, Германия, Норвегия, Финляндия, Нидерланды, Италия'
#  'Дания,Франция,Бельгия,Германия,Великобритания'
#  'Дания,Швеция,Франция,Германия' 'Израиль'
#  'Израиль , Германия , Польша , Бельгия , Франция , Люксембург'
#  'Израиль , Германия , Франция , Швейцария' 'Израиль , Франция'
#  'Израиль , Франция , Великобритания , Германия'
#  'Израиль , Франция , Германия , Палестина , США , Австрия , Великобритания'
#  'Израиль, Украина' 'Израиль,США,Франция' 'Индия' 'Индия , Великобритания'
#  'Индия , КНР' 'Индия , Мексика' 'Индия , США' 'Индонезия' 'Иран'
#  'Иран, Франция' 'Ирландия' 'Ирландия , Великобритания , Канада'
#  'Ирландия , Великобритания , США'
#  'Ирландия , Великобритания , Франция , США'
#  'Ирландия , Великобритания , Франция , США , Германия , Нидерланды'
#  'Ирландия , Дания , Бельгия , Люксембург , Франция' 'Ирландия , США'
#  'Ирландия , Финляндия , Бельгия , Великобритания , США , Швейцария'
#  'Ирландия, Великобритания' 'Ирландия, Канада' 'Ирландия,Великобритания'
#  'Ирландия,Великобритания,Германия'
#  'Ирландия,Нидерланды,Франция,США,Великобритания' 'Исландия'
#  'Исландия , Финляндия' 'Исландия, Бельгия' 'Исландия,Ирландия,Германия'
#  'Испания' 'Испания , Аргентина' 'Испания , Аргентина , Индия , США'
#  'Испания , Бельгия , Франция , Португалия , Великобритания'
#  'Испания , Болгария , США' 'Испания , Великобритания , Франция'
#  'Испания , Германия , Нидерланды' 'Испания , Италия , Франция'
#  'Испания , Канада' 'Испания , Канада , Япония' 'Испания , Куба'
#  'Испания , Мальта' 'Испания , Мексика' 'Испания , США'
#  'Испания , США , Великобритания , Канада' 'Испания , США , Колумбия'
#  'Испания , Уругвай , Аргентина' 'Испания , Франция'
#  'Испания , Франция , Нидерланды , Германия , Бельгия , Великобритания , Канада'
#  'Испания , Франция , США , Великобритания , Бельгия'
#  'Испания , Швейцария , Великобритания , Германия , Новая Зеландия , Нидерланды , Канада'
#  'Испания, Ирландия, Бельгия, Франция'
#  'Испания, Франция, Великобритания, Дания, Бельгия, Германия'
#  'Испания, Франция, Италия' 'Испания,Аргентина' 'Испания,Канада'
#  'Испания,Колумбия' 'Испания,Мексика'
#  'Испания,Франция,Греция,Индия,США,Россия,Великобритания' 'Италия'
#  'Италия , Аргентина , Словения' 'Италия , Бельгия , Франция'
#  'Италия , Канада' 'Италия , Россия' 'Италия , США' 'Италия , Франция'
#  'Италия , Франция , Германия' 'Италия , Франция , Швейцария'
#  'Италия , Франция , Швейцария , Великобритания'
#  'Италия , Фрация , Бразилия , Германия' 'Италия , Швейцария , Германия'
#  'Италия, Германия' 'Италия, Испания' 'Италия, Франция'
#  'Италия, Франция, Германия' 'Италия,Великобритания' 'Италия,США'
#  'Италия,Франция' 'Италия,Франция,Великобритания' 'Италия,Швейцария'
#  'Италия,Швейцария,Франция,Германия' 'КНР' 'КНР , Гонконг'
#  'КНР , Гонконг , США' 'КНР , Канада , США' 'КНР , США' 'КНР , Сингапур'
#  'КНР , Франция' 'КНР, Индия, Гонконг, США' 'КНР, США' 'КНР,США'
#  'Казахстан' 'Канада' 'Канада , Германия' 'Канада , Испания'
#  'Канада , Италия' 'Канада , КНР' 'Канада , Мексика' 'Канада , Норвегия'
#  'Канада , США' 'Канада , США , Германия , Франция'
#  'Канада , США , Нидерланды , Великобритания , Аргентина'
#  'Канада , Франция' 'Канада , Франция , Великобритания'
#  'Канада , Франция , Испания'
#  'Канада , Франция , США , ОАЭ , Великобритания' 'Канада , Южная Корея'
#  'Канада, Великобритания' 'Канада, Испания' 'Канада, США'
#  'Канада, США, Каймановы острова' 'Канада, США, Норвегия'
#  'Канада, Франция, Италия, Швейцария, США' 'Канада,Бразилия,Япония'
#  'Канада,Великобритания' 'Канада,Германия' 'Канада,США' 'Канада,Франция'
#  'Канада,ЮАР' 'Канада,Южная Корея,США' 'Кения, Германия' 'Киргизия'
#  'Киргизия,Россия' 'Китай' 'Китай , Гонконг' 'Китай, Канада, США'
#  'Китай, США' 'Китай,Гонконг' 'Китай,Гонконг,США'
#  'Княжество Андорра , Украина' 'Колумбия' 'Колумбия , США' 'Корея'
#  'Латвия , Россия' 'Латвия , Франция' 'Ливан,США' 'Литва , Венгрия'
#  'Литва,Россия,Украина' 'Люксембург , Бельгия , Франция'
#  'Люксембург , Нидерланды , Испания , Великобритания , США , Италия'
#  'Македония , Франция , Великобритания' 'Малайзия' 'Малайзия , США'
#  'Мексика' 'Мексика , Аргентина , Великобритания' 'Мексика , Испания'
#  'Мексика , Испания , Дания , США'
#  'Мексика , Нидерланды , Германия , Франция' 'Мексика , США'
#  'Мексика , Тайвань , США' 'Мексика , Франция'
#  'Мексика , Франция , Нидерланды , Германия' 'Мексика , Чили'
#  'Мексика , Эквадор , Канада , США , Франция , Малайзия , Италия , Аргентина , Германия , Индия'
#  'Мексика, Франция, Германия, Дания, Швеция' 'Мексика,Аргентина'
#  'Монголия' 'Нидерланды' 'Нидерланды , Бельгия , Болгария'
#  'Нидерланды , Бельгия , Германия , Ирландия'
#  'Нидерланды , Бельгия , Люксембург'
#  'Нидерланды , Великобритания , Бельгия' 'Нидерланды , Россия'
#  'Нидерланды , Россия , Германия'
#  'Нидерланды , США , Германия , Канада , Франция , Ирландия , Великобритания'
#  'Нидерланды , Франция , Германия , Бельгия , Швеция , Великобритания'
#  'Нидерланды, Бельгия' 'Нидерланды, Бельгия, Люксембург'
#  'Нидерланды,Великобритания,Франция,Италия,Япония' 'Новая Зеландия , КНР'
#  'Новая Зеландия , США' 'Новая,Зеландия' 'Норвегия'
#  'Норвегия , Азербайджан , Россия , Колумбия , Великобритания , Венгрия , Румыния , Франция , Грузия'
#  'Норвегия , Дания , Швеция' 'Норвегия , Исландия , США , Великобритания'
#  'Норвегия , Нидерланды' 'Норвегия , США' 'Норвегия , Швеция'
#  'Норвегия , Швеция , Дания , Германия' 'Норвегия , Швеция , Россия'
#  'Норвегия, Швеция, Дания' 'Норвения' 'ОАЭ , США' 'Пакистан' 'Парагвай'
#  'Перу' 'Польша' 'Польша , Ирландия' 'Польша , Италия , Россия'
#  'Польша , Португалия , Франция , Великобритания' 'Польша , Франция'
#  'Польша , Франция , Великобритания'
#  'Польша , Франция , Испания , Бразилия , Швеция' 'Португалия'
#  'Португалия , Франция' 'Португалия, Франция, Польша, США'
#  'Пуэрто,Рико, Великобритания, США'
#  'Республика Беларусь, Германия, США, Россия' 'Республика Кипр , Россия'
#  'Республика Кипр, Россия' 'Республика Кипр, США, Россия'
#  'Республика Кипр,Россия' 'Республика,Армения' 'Республика,Беларусь'
#  'Республика,Казахстан' 'Республика,Кипр' 'Республика,Корея'
#  'Республика,Узбекистан' 'Россия' 'Россия , Азербайджан'
#  'Россия , Болгария' 'Россия , Германия' 'Россия , Германия , Украина'
#  'Россия , Германия , Швейцария' 'Россия , Грузия' 'Россия , Италия'
#  'Россия , Казахстан' 'Россия , Польша' 'Россия , Республика Кипр'
#  'Россия , США' 'Россия , Франция , Великобритания , Латвия'
#  'Россия , Эстония , Финляндия , Беларусь' 'Россия,  Испания'
#  'Россия, Австрия' 'Россия, Армения' 'Россия, Бельгия, Финляндия'
#  'Россия, Германия' 'Россия, Германия, Великобритания'
#  'Россия, Германия, Казахстан, Польша, Китай'
#  'Россия, Германия, Франция, Бельгия' 'Россия, Грузия, Испания'
#  'Россия, Грузия, Хорватия, Испания' 'Россия, Испания' 'Россия, Италия'
#  'Россия, Казахстан, США' 'Россия, Латвия, Чешская Республика'
#  'Россия, Нидерланды, Финляндия' 'Россия, Польша, Финляндия'
#  'Россия, Республика Беларусь' 'Россия, Республика Кипр' 'Россия, Румыния'
#  'Россия, Сербия' 'Россия, Таджикистан' 'Россия, Украина'
#  'Россия, Украина, Польша' 'Россия, Украина, Республика Беларусь, Литва'
#  'Россия, Франция, Германия, Бельгия' 'Россия, Франция, Латвия'
#  'Россия,Азербайджан' 'Россия,Беларусь' 'Россия,Белоруссия'
#  'Россия,Германия' 'Россия,Ирландия' 'Россия,Италия' 'Россия,Казахстан'
#  'Россия,Кипр' 'Россия,Китай' 'Россия,Польша'
#  'Россия,Польша,Голландия,Словакия' 'Россия,США'
#  'Россия,США,Канада,Люксембург' 'Россия,Словакия,Чехия' 'Россия,Украина'
#  'Россия,Украина,Германия' 'Россия,Франция' 'Румыния'
#  'Румыния , Франция , Бельгия'
#  'Румыния, ЮАР, Иран, Франция, Канада, Великобритания' 'Румыния,США'
#  'СССР' 'СССР , ГДР , Польша , Италия' 'СССР , Италия'
#  'СССР , Швейцария , Франция' 'СССР, Албания' 'СССР, Афганистан'
#  'СССР, ВНР' 'СССР, Венгрия' 'СССР, Венгрия, ЧССР, ГДР' 'СССР, ГДР'
#  'СССР, Италия' 'СССР, Монголия' 'СССР, Польша' 'СССР, Россия'
#  'СССР, Румыния, Франция' 'СССР, ФРГ' 'СССР, ФРГ, Западный Берлин'
#  'СССР, Финляндия' 'СССР, Франция, Англия, Куба, ГДР'
#  'СССР, ЧССР, Западный Берлин, ПНР' 'СССР, Швеция' 'США' 'США , Австралия'
#  'США , Австралия , Дания' 'США , Австралия , Индия'
#  'США , Австралия , Мексика'
#  'США , Австралия , Новая Зеландия , Великобритания'
#  'США , Австралия , Франция' 'США , Бельгия'
#  'США , Бельгия , Великобритания' 'США , Болгария , Мексика'
#  'США , Бразилия , Великобритания , Канада'
#  'США , Бразилия , Франция , Австралия , Великобритания , Германия'
#  'США , Великобритания' 'США , Великобритания , Австралия'
#  'США , Великобритания , Болгария' 'США , Великобритания , Германия'
#  'США , Великобритания , Германия , , Швеция , Канада'
#  'США , Великобритания , Германия , Бельгия , Дания'
#  'США , Великобритания , Германия , Новая Зеландия , Бельгия , Франция'
#  'США , Великобритания , Ирландия' 'США , Великобритания , Исландия'
#  'США , Великобритания , Испания'
#  'США , Великобритания , Италия , Израиль , Сербия , Индия'
#  'США , Великобритания , КНР' 'США , Великобритания , Канада'
#  'США , Великобритания , Канада , КНР'
#  'США , Великобритания , Канада , Швеция'
#  'США , Великобритания , Новая Зеландия' 'США , Великобритания , Франция'
#  'США , Великобритания , Франция , Гонконг' 'США , Великобритания , Чехия'
#  'США , Великобритания , Швейцария , Франция'
#  'США , Великобритания , Швеция' 'США , Великобритания , Япония'
#  'США , Великобритания, Франция , Швеция' 'США , Венгрия , Великобритания'
#  'США , Вьетнам' 'США , Германия' 'США , Германия , Великобритания'
#  'США , Германия , Гонконг , Сингапур' 'США , Германия , КНР'
#  'США , Германия , Канада' 'США , Германия , Нидерланды'
#  'США , Германия , Франция'
#  'США , Германия , Франция , Великобритания , Канада'
#  'США , Германия , Япония' 'США , Гонконг' 'США , Гонконг , КНР'
#  'США , Дания' 'США , Индия' 'США , Индия , ОАЭ'
#  'США , Ирландия , Великобритания'
#  'США , Ирландия , Великобритания , Франция' 'США , Испания'
#  'США , Испания , Болгария' 'США , Испания , Франция'
#  'США , Испания , Франция , Великобритания' 'США , Италия' 'США , КНР'
#  'США , КНР , Индия , Ю.Корея' 'США , Канада' 'США , Канада , Аргентина'
#  'США , Канада , Афганистан , Бельгия , Франция'
#  'США , Канада , Великобритания' 'США , Канада , Германия'
#  'США , Канада , Германия , Франция' 'США , Канада , Индонезия'
#  'США , Канада , КНР' 'США , Канада , Россия , Франция , Чили , Ирландия'
#  'США , Канада , Франция , Индия' 'США , Канада , Япония , КНР'
#  'США , Китай' 'США , Колумбия' 'США , Колумбия , Испания' 'США , Мальта'
#  'США , Мексика' 'США , Нидерланды , Бельгия , Венгрия , Греция , Канада'
#  'США , Нидерланды , Финляндия , Великобритания , Италия'
#  'США , Новая Зеландия' 'США , Новая Зеландия , Япония' 'США , Норвегия'
#  'США , ОАЭ' 'США , Объединенные Арабские Эмираты' 'США , Пуэрто Рико'
#  'США , Пуэрто,Рико , Франция' 'США , Россия'
#  'США , Россия , Польша , Германия , Пуэрто Рико' 'США , Россия , Франция'
#  'США , Румыния , Великобритания' 'США , Сингапур , Малайзия , Индонезия'
#  'США , Украина' 'США , Финляндия'
#  'США , Финляндия , Испания , Великобритания , Франция' 'США , Франция'
#  'США , Франция , Бельгия , Италия' 'США , Франция , Великобритания'
#  'США , Франция , Великобритания , Бразилия' 'США , Франция , Германия'
#  'США , Франция , Германия , Канада , Австралия'
#  'США , Франция , Испания , Великобритания'
#  'США , Франция , Канада , Великобритания'
#  'США , Франция , Канада , Германия , Австралия , Индия'
#  'США , Франция , Турция' 'США , Франция , ЮАР'
#  'США , Хорватия , Босния,Герцеговина' 'США , Чехия , Франция'
#  'США , Чили' 'США , Швейцария , Франция' 'США , Швеция' 'США , ЮАР'
#  'США , ЮАР , Гонконг' 'США , Южная Корея' 'США , Япония'
#  'США , Япония , Германия'
#  'США , Япония , Канада , Великобритания , Германия , Франция'
#  'США , Япония , Франция , Великобритания'
#  'США ,Великобритания , Австралия' 'США ,Германия' 'США, Великобритания'
#  'США, Великобритания, Ирландия, Люксембург'
#  'США, Великобритания, Люксембург' 'США, Великобритания, Франция'
#  'США, Гонконг' 'США, Индия' 'США, Канада' 'США, Россия' 'США, Украина'
#  'США, Франция' 'США, Франция, Япония' 'США, Ю.Корея' 'США, Япония'
#  'США,Австралия' 'США,Аргентина' 'США,Бельгия' 'США,Великобритания'
#  'США,Великобритания,Австралия' 'США,Великобритания,Индия'
#  'США,Великобритания,Ирландия' 'США,Великобритания,Новая Зеландия'
#  'США,Великобритания,Франция' 'США,Великобритания,Чехия,Румыния'
#  'США,Венгрия' 'США,Германия' 'США,Германия,Австралия'
#  'США,Германия,Великобритания' 'США,Германия,Канада' 'США,Гонконг,Китай'
#  'США,Индия' 'США,Индонезия' 'США,Ирландия' 'США,Испания'
#  'США,Италия,Греция' 'США,Италия,Испания' 'США,Италия,Испания,Аргентина'
#  'США,КНР' 'США,Канада' 'США,Канада,Австралия' 'США,Канада,Бельгия'
#  'США,Канада,Италия' 'США,Канада,Франция' 'США,Китай' 'США,Колумбия'
#  'США,Мальта' 'США,Мексика' 'США,Нидерланды' 'США,ОАЭ' 'США,Россия'
#  'США,ФРГ,Россия' 'США,Франция' 'США,Франция,Великобритания,Австрия'
#  'США,Франция,Ирландия' 'США,Франция,Испания' 'США,Франция,Канада'
#  'США,ЮАР' 'США,Южная Корея,Новая Зеландия' 'США,Япония'
#  'США,Япония,Германия,Великобритания'
#  'США,Япония,Германия,Великобритания,Нидерланды'
#  'Сербия , Великобритания , США' 'Сербия , Германия , Венгрия'
#  'Сербия , Словения , Хорватия , Черногория , Македония'
#  'Сингапур , Великобритания , Индонезия , Канада , США' 'Сша, Канада'
#  'Таиланд' 'Таиланд , КНР , США' 'Таиланд , США'
#  'Таиланд,Великобритания,Франция,Германия,Испания,Нидерланды' 'Турция'
#  'Турция , Германя , Франция' 'Турция , США' 'Украина'
#  'Украина , Германия , Латвия , Эстония' 'Украина , Нидерланды'
#  'Уругвай , Аргентина , Испания' 'Уругвай , Колумбия'
#  'Уругвай,Мексика,Германия' 'Финляндия' 'Финляндия , Австрия , Россия'
#  'Финляндия , Великобритания , Германия' 'Финляндия , Германия'
#  'Финляндия , Дания , Германия , Ирландия' 'Финляндия , Исландия , Швеция'
#  'Финляндия , Канада' 'Финляндия , Польша'
#  'Финляндия , Франция , Германия' 'Финляндия , Швеция , Германия'
#  'Финляндия , Швеция , Норвегия' 'Финляндия, Латвия'
#  'Финляндия,Дания,Германия,Ирландия' 'Франция' 'Франция ,  Бельгия'
#  'Франция , Австрия' 'Франция , Австрия , Германия , Италия , США'
#  'Франция , Бельгия'
#  'Франция , Бельгия , Великобритания , Испания , Германия , США'
#  'Франция , Бельгия , Великобритания , США , Нидерланды , Канада'
#  'Франция , Бельгия , Испания' 'Франция , Бельгия , Канада'
#  'Франция , Бельгия , Люксембург' 'Франция , Бельгия , Чехия'
#  'Франция , Бельгия , Япония' 'Франция , Бенльгия' 'Франция , Бразилия'
#  'Франция , Бразилия , Италия' 'Франция , Великобритания'
#  'Франция , Великобритания , Багамские острова , США'
#  'Франция , Великобритания , Камбоджа , США , КНР'
#  'Франция , Великобритания , Нидерланды , Люксембург' 'Франция , Германия'
#  'Франция , Германия , Австрия' 'Франция , Германия , Бельгия'
#  'Франция , Германия , Италия'
#  'Франция , Германия , Литва , Нидерланды , Россия'
#  'Франция , Германия , Нидерланды' 'Франция , Германия , США'
#  'Франция , Германия , Турция , Катар'
#  'Франция , Германия , Швеция , США , Чехия , Словакия , Великобритания , Нидерланды'
#  'Франция , Греция' 'Франция , Дания' 'Франция , Дания , США'
#  'Франция , Дания , Швеция , КНР' 'Франция , Израиль , Германия'
#  'Франция , Ирландия , Швеция' 'Франция , Испания'
#  'Франция , Испания , Дания , Венгрия , Швейцария'
#  'Франция , Испания , Румыния , США , Бельгия'
#  'Франция , Испания , Тайвань' 'Франция , Италия'
#  'Франция , Италия , Бельгия , КНР'
#  'Франция , Италия , Бельгия , Люксембург'
#  'Франция , Италия , Великобритания , США' 'Франция , Италия , Иран'
#  'Франция , Италия , Швейцария' 'Франция , КНР' 'Франция , Канада'
#  'Франция , Канада , Бельгия'
#  'Франция , Канада , Н.Зеландия , США , Нидерланды , Германия , Швеция , Россия'
#  'Франция , Люксембург' 'Франция , Люксембург , Бельгия'
#  'Франция , Люксембург , Германия , Бельгия , Швейцария , Великобритания'
#  'Франция , Македония' 'Франция , Мексика , США' 'Франция , Монако'
#  'Франция , Нидерланды' 'Франция , Польша , Бельгия'
#  'Франция , Португалия' 'Франция , Россия'
#  'Франция , Россия , Швейцария , Румыния , Венгрия' 'Франция , США'
#  'Франция , США , Бельгия'
#  'Франция , США , Великобритания , Колумбия , Бельгия , Россия'
#  'Франция , США , Норвегия , Дания' 'Франция , Сенегал , Бельгия'
#  'Франция , Украина , Грузия , Армения' 'Франция , Финляндия'
#  'Франция , Чехия , Бельгия' 'Франция , Чехия , Великобритания'
#  'Франция , Чили' 'Франция , Швейцария' 'Франция , Швейцария , Германия'
#  'Франция , Швеция , Дания , Норвегия' 'Франция ,Бельгия'
#  'Франция, Бельгия' 'Франция, Бельгия, Люксембург' 'Франция, Германия'
#  'Франция, Канада' 'Франция, Люксембург, Бельгия'
#  'Франция, Новая Зеландия' 'Франция, Норвегия' 'Франция,Австралия'
#  'Франция,Аргентина' 'Франция,Бельгия' 'Франция,Бельгия,Канада'
#  'Франция,Великобритания' 'Франция,Великобритания , Германия'
#  'Франция,Великобритания,Чехия' 'Франция,Германия'
#  'Франция,Германия,Австрия' 'Франция,Германия,Великобритания'
#  'Франция,Германия,Италия' 'Франция,Гонконг,Ирландия'
#  'Франция,Грузия,Германия,Россия,Украина,Бельгия' 'Франция,Индия'
#  'Франция,Испания' 'Франция,Испания,Бельгия,Панама'
#  'Франция,Испания,Германия' 'Франция,Испания,Швейцария' 'Франция,Италия'
#  'Франция,Италия,Испания,Венгрия' 'Франция,КНР' 'Франция,Канада'
#  'Франция,Китай' 'Франция,Перу' 'Франция,Польша' 'Франция,Россия'
#  'Франция,Россия,Румыния,Италия,Бельгия' 'Франция,США' 'Франция,Украина'
#  'Хорватия' 'Чехия' 'Чехия , Германия' 'Чехия , Испания , США'
#  'Чехия , Словакия , Хорватия' 'Чехия,Великобритания,США' 'Чехословакия'
#  'Чили' 'Чили , Испания' 'Чили , Франция , США' 'Швейцария'
#  'Швейцария , Австрия' 'Швейцария , Великобритания'
#  'Швейцария , Израиль , Франция , Великобритания'
#  'Швейцария , КНР , США , Россия , Республика Корея , Великобритания'
#  'Швейцария , Люксембург' 'Швейцария , Франция'
#  'Швейцария, Великобритания, Франция, США, Ирландия' 'Швейцария,Австрия'
#  'Швейцария,Германия,ЮАР' 'Швейцария,Франция' 'Швеция' 'Швеция , Германия'
#  'Швеция , Германия , Дания , Норвегия'
#  'Швеция , Германия , Франция , Дания'
#  'Швеция , Германия , Франция , Норвегия' 'Швеция , Дания'
#  'Швеция , Дания , Финляндия' 'Швеция , Норвегия' 'Швеция , США'
#  'Швеция , Франция , Норвегия , Дания'
#  'Швеция, Норвегия, Финляндия, Франция' 'Швеция, Франция, Великобритания'
#  'Швеция,Куба' 'Швеция,Финляндия,Франция,Норвегия' 'Швеция,Франция'
#  'Швеция,Франция,Дания' 'Эстония' 'Эстония , Россия' 'ЮАР' 'ЮАР , США'
#  'Южная Корея , КНР' 'Южная Корея , США' 'Южная Корея , США , Канада'
#  'Южная,Корея' 'Япония' 'Япония , Великобритания , Франция'
#  'Япония , Великобритания , Швейцария , Ирландия , Дания , Франция , Польша , Австралия , Канада'
#  'Япония , КНР , Южная Корея' 'Япония , Канада' 'Япония , США'
#  'Япония , Франция , США , Южная Корея , Турция' 'Япония, Великобритания'
#  'Япония, Великобритания, Австрия, Германия, Ю.Корея' 'Япония, США'
#  'Япония,Великобритания' 'Япония,США,Франция']
# Конец списка, количество элементов:  931

# %% [markdown]
# #### Колонка director

# %% [markdown]
# Поиск уникальных имен, подсчет дубликатов:

# %%
director_unique = data['director'].sort_values().unique()
print('Длина списка уникальных имен',len(director_unique))
print('Количество дубликатов в колонке: ',data['production_country'].duplicated().sum())
print_long_lists(director_unique)
display(data[data['director'].duplicated()])
display(data[(data['director'].str.contains('Азаров') | data['director'].str.contains('Маршалл'))
            & data['director'].duplicated()])
# Out:
# Длина списка уникальных имен 4814
# Количество дубликатов в колонке:  6032
# [' Йохан Нийенхейс' ' Н.Орлов, Р.Быков' ' Р.Асхаев' ' Т.Саакян'
#  ' Ф.Бондарчук' 'Ёлкин Туйчиев' 'Ён Сан-хо' 'А Андрющенко' 'А. Калюжный'
#  'А. Кутерье' 'А.А.Эшпай' 'А.Аббасов' 'А.Абидова (псевдоним Аниса Сабири)'
#  'А.Аболс' 'А.Агаджанян' 'А.Адилханян' 'А.Адраникян' 'А.Аксененко'
#  'А.Аксененко, Э.Никогосян, Д.Дюжев, А.Вакулов (А.Кульбицкий)'
#  'А.Алов, В.Наумов' 'А.Аманшаев, Г.Шенгелия' 'А.Амбросьев' 'А.Амиров'
#  'А.Ананикян, В.Рейнгеверц' 'А.Андрианов'
#  'А.Андризани, А.Бардани, В.Карнелутти, Ф.Коста,  Г.С.Нардис, В.Пальмьери, В.Чеа, А.Юлиано '
#  'А.Анненский' 'А.Аравин' 'А.Аравин, А.Прошкин'
#  'А.Арпеньтеньер, А.Бариларо, М.Бланчес, Р.Валлей, Л.Гранд, Ф.Дион, А.Жасина, Э.Коэтс,  Лу Хаму-Лхад, П.Осборн, Т.Ушев'
#  'А.Артамонова' 'А.Арутюнов' 'А.Арутюнян, А.Коршунов' 'А.Атанесян'
#  'А.Бадягина' 'А.Бажанов' 'А.Балабанов' 'А.Балахонов' 'А.Бальчев'
#  'А.Черномазов (псевдоним Алексей Нужный)' 'А.Черняев, Е.Рустембеков'
#  'А.Чижиков, И.Чижиков' 'А.Чукарев'
#  'А.Шабаров, Д.Булин, Н.Михалкова-Кончаловская, Г.Пирогова, Е.Вещева, Т.Федоровская, Е.Абызов'
#  'А.Шадрина' 'А.Шадров' 'А.Шархун' 'А.Шейн'
#  'А.Шелехов (псевдоним Александр Шелл)' 'А.Шемес'
#  'А.Шемятовский, И.Оганесов, К.Гогленкова, А.Смирнов, А. Евсеев (псевдоним - Хант), С.Королева'
#  'А.Шустикова' 'А.Щербинин' 'А.Щербович-Вечер' 'А.Эфрос' 'А.Эшпай'
#  'А.Южаков' 'А.Юмагулов' 'А.Ягубец' 'А.Якимчук' 'А.Якимчук, В.Лагунов'
#  'А.Яхнис, М.Кричман' 'А.фон Боррис' 'Аарон Вудли'
#  'Аарон Зельцер, Джейсон Фридберг' 'Аарон Кауфман'
#  'Аарон Кешалес, Навот Папушадо' 'Аарон Соркин'
#  'Аасне Ваа Грейброкк, Тор Бренн, Исаак Гёртсен, Мария Лойтер, Патрик Эклунд'
#  'Аббадо Даниэле' 'Аббас Киаростами' 'Абделатиф Кешиш' 'Абделлатиф Кешиш'
#  'Абе Форсайт' 'Абель Феррара' 'Ава ДюВерней' 'Агнес Мерле'
#  'Агнешка Войтович-Восло' 'Агустин Диас Янес' 'Адам Вингард' 'Адам Гираш'
#  'Адам Грин' 'Адам Кук' 'Адам Леон' 'Адам МакКей' 'Адам Макдональд'
#  'Адам Робител' 'Адам Рэндолл' 'Адам Смит' 'Адам Шенкман' 'Адам Шиндлер'
#  'Адриан Биньес' 'Адриан Грюнберг' 'Адриан Молина, Ли Ункрич'
#  'Азиз Джиндани' 'Азиф Кападиа' 'Азия Ардженто'
#  'Айан Бонхот, Питер Эттедги' 'Айбек Дайырбеков' 'Айван Райтман'
#  'Айвен Райтман' 'Айзек Флорентайн' 'Айк Кбеян' 'Айке Грамс' 'Айрис Заки'
#  'Айрон Блейз, Роберт Уокер' 'Акан Сатаев' 'Аки Каурисмяки'
#  'Акива Голдсман' 'Акива Шаффер' 'Акош Барноцкий' 'Аку Лоухимис'
#  'Алан Линдсэй' 'Алан Пол' 'Алан Тейлор' 'Алан Тэйлор'
#  'Алберт Хьюз, Эллен Хьюз' 'Алекс Ван Вармердам' 'Алекс Гибни'
#  'Алекс Грегори, Питер Хайк' 'Алекс Замм' 'Алекс Колл' 'Алекс Коллс'
#  'Алекс Куртцман' 'Алекс Олье' 'Алекс Оррель, Эдуардо Шульдт'
#  'Алекс Оруэлл' 'Алекс Пастор, Давид Пастор' 'Алекс Пастор, Дэвид Пастор'
#  'Алекс Пройас' 'Алекс Стадерманн' 'Алекс ван Вармердам'
#  'Алекс де ла Иглесиа' 'Александр Абатуров' 'Александр Ажа'
#  'Александр Алешечкин, Вячеслав Алешечкин' 'Александр Астье, Луис Клиши'
#  'Александр Бах' 'Александр Бустильо, Жюльен Мори' 'Александр Высоковский'
#  'Александр Клименко' 'Александр Коффре' 'Александр Потехин'
#  'Берр Стирс' 'Бертран Банелло' 'Бертран Блие' 'Бертран Бонелло'
#  'Бертран Тавернье' 'Бетти Томас' 'Бибо Бержерон' 'Бигас Луна'
#  'Билл Беннетт'
#  'Билл Джирхарт, Роэль Рейн, Дэвид Стрейтон, Кевин Танчароэн, Крис Фишер, Неаса Хардиман'
#  'Билл Джонс, Джефф Симпсон, Бен Тимлетт' 'Билл Кондон' 'Билл Кондон '
#  'Билл Оливер' 'Билл Плимптон' 'Билл Плимтон' 'Билл Холдермэн'
#  'Билле Аугуст' 'Билли Боб Торнтон' 'Билли Рэй' 'Бинг Лю' 'Биргер Ларсен'
#  'Биргитте Стэмозе' 'Бландин Ленуар' 'Блу Лич' 'Блэр Эриксон' 'Бо Дзенга'
#  'Боаз Якин' 'Боб Персичетти, Питер Рамси, Родни Ротман'
#  'Боб Фишер, Роб Гринберг' 'Бобби Фаррелли, Питер Фаррелли'
#  'Бобкэт Голдтуэйт' 'Бобо Бёрманс' 'Бора Дагтекин' 'Боривой Земан'
#  'Борис Альинович, Харальд Зиперманн' 'Брайан А.Миллер' 'Брайан Гудман'
#  'Брайан Де Пальма' 'Брайан ДеКьюбелис' 'Брайан Кирк'
#  'Брайан Клагман, Ли Стернтал' 'Брайан Лардж' 'Брайан Ли' 'Брайан О.Мэлли'
#  'Брайан Персиваль' 'Брайан Пойсер' 'Брайан Сингер' 'Брайан Смрз'
#  'Брайан Томсон, Гейл Эдвардс' 'Брайан Фи' 'Брайан Фогель'
#  'Брайан Хелгеленд' 'Брайан Хенсон' 'Брайан Хориути' 'Браян Левант'
#  'Брек Айзнер' 'Брек Эйзнер' 'Брек Эйснер' 'Бренда Чапмен, Марк Эндрюс'
#  'Бретт Ратнер' 'Бретт Рэтнер' 'Бретт Симмонс'
#  'Бронвин Деннисон, Мигель Мартинез-Хоффре, Пол Браун' 'Бруно Халлин'
#  'Бруно Шиш' 'Брэд Андерсон' 'Брэд Берд' 'Брэд Бёрд' 'Брэд Пейтон'
#  'Брэд Силберлинг' 'Брэд Фурман' 'Брэдли Кинг' 'Брэдли Купер'
#  'Брэдли Паркер' 'Брэйден Кинг' 'Брэйди Корбет' 'Брэндон Кристенсен'
#  'Брюно Дюмон' 'Брюно Подалидес' 'Брюс Бересфорд' 'Брюс Робинсон'
#  'Брюс Э.Эванс' 'Бьёрн Рунге' 'Бэз Лурман' 'Бэн Палмер' 'Бэнкси'
#  'Бёрр Стирс' 'В.Абдрашитов' 'В.Азаров' 'В.Азаров, Н.Досталь' 'В.Азеев'
#  'В.Акобян' 'В.Алеников' 'В.Алфёров' 'В.Аравин' 'В.Арясов' 'В.Барбэ'
#  'В.Барбэ, М.Свешников' 'В.Бархатов' 'В.Басов'
#  'В.Бедошвили, О.Ужинов, И.Пшонкин, Д.Цыбулькин' 'В.Бек'
#  'В.Бек, И.Оганесов, А.Симакова, П.Сеплярский' 'В.Белов' 'В.Битоков'
#  'В.Бортко' 'В.Бродский' 'В.Виноградов' 'В.Витовцев'
#  'В.Пономарёв, А.Миронов, Е.Салабай, В.Бедошвили и др.'
#  'В.Пономарёв, А.Миронов, Е.Салабай, И.Пшонкин'
#  'В.Пономарёв, А.Миронов, Е.Салабай, Н.Мальгина' 'В.Потапов, А.Карелин'
#  'В.Потапов, Ю.Бердников' 'В.Потемкин' 'В.Потёмкин' 'В.Приходько'
#  'В.Пронин' 'В.Пудовкин' 'В.Пудовкин, Д.Васильев' 'В.Пудовкин, М.Доллер'
#  'В.Ракша' 'В.Ровенский' 'В.Ровенский, Н.Лопато, В.Азеев' 'В.Рощин'
#  'В.Рудак' 'В.Саков' 'В.Салтыков' 'В.Семёновых' 'В.Сериков' 'В.Сигарев'
#  'В.Сидоренко' 'В.Скуйбин' 'В.Смолина' 'В.Соколовский' 'В.Сторожева'
#  'В.Сунцов' 'В.Суслин' 'В.Татарский' 'В.Тертышный' 'В.Тимощенко' 'В.Титов'
#  'В.Тодоровский' 'В.Толкачиков' 'В.Торопчин' 'В.Тумаев' 'В.Угличин'
#  'В.Фанасютина' 'В.Фатьянов' 'В.Федоров' 'В.Фекленко' 'В.Фурманов'
#  'В.Харченко' 'В.Харченко, А.Волков' 'В.Харьков' 'В.Хотиненко'
#  'В.Хохлов, К.Ляшенко' 'В.Чеботарев' 'В.Чигинский' 'В.Чичайкин'
#  'В.Чубриков' 'В.Шамиров' 'В.Шамиров, Д.Балинова, Р.Хачмамук' 'В.Шамшурин'
#  'В.Шевельков' 'В.Шепелев' 'В.Штерянов при участии Е.Немых' 'В.Шукшин'
#  'В.Щегольков' 'В.Эйснер' 'В.Юркус' 'В.Яковлев' 'В.Янковский' 'Ваге Саян'
#  'Вадим Перельман' 'Вадих Эль Хайек'
#  'Валентино Пиконе, Сальваторе Фикарра' 'Валери Донзелли'
#  'Валерио Аттаназио' 'Валерио Мьели' 'Валерия Бруни-Тедески'
#  'Валерия Гай Германика' 'Валерия Паризи' 'Ван Сылинь, Чжен Линьна'
#  'Ванесса Фильо' 'Вано Бурдули' 'Вари Ом, Джорджия Уайсс' 'Вейн Тонли'
#  'Вернер Херцог' 'Виджай Кришна Ачария' 'Вик Армстронг' 'Викрам Батт'
#  'Виктор Гарсия' 'Виктор Косаковский' 'Виктор Левин' 'Виктор Сальва'
#  'Виктор Сейнт Макари' 'Виктор Флеминг' 'Вильгельм Домке-Шульц'
#  'Вильям Де Витал' 'Вим Вендерс' 'Вим Вендерс, Джулиано Рибейру Сальгаду'
#  'Винко Брешан' "Винсент Д'Онофрио" 'Винсент Кестелут, Бен Стассен'
#  'Винсент Паронно, Маржан Сатрапи' 'Винсент Патерсон' 'Винсент Чжоу'
#  'Винченцо Натали'
#  'Виола Байер, Стефан Берман, Мэрайке Блау, Йорис Опринс, Пол Плобергер, Жан-Батист Пуйю, Йюст Раймерс, Йоб Роггевен, Эрик Шмит, Бен Эстон'
#  'Виталий Манский' 'Витторио Тавиани, Паоло Тавиани' 'Вич Каосаянанда'
#  'Гарет Эванс' 'Гарет Эдвардс' 'Гари Виник' 'Гари Вонг' 'Гари Доберман'
#  'Гари Шор' 'Гарольд Беккер' 'Гарольд Реймис' 'Гаррет Прайс'
#  'Гарри Клевен' 'Гарри Маршалл' 'Гарт Дженнингс'
#  'Гарт Дженнингс, Кристоф Лоурделет ' 'Гарт Дэвис' 'Гас Ван Сент'
#  'Гаспар Ноэ' 'Гастон Дюпра' 'Гастон Дюпра, Мариано Кон' 'Гейб Ибаньес'
#  'Гейб Клингер' 'Гейб Польски' 'Гейбор Ксапо' 'Гейл Манкусо' 'Гейл Эвардс'
#  'Гектор Эрнандес' 'Гела Баблуани' 'Геннадий Тартаковский' 'Генри Бедуэлл'
#  'Генри Бин' 'Генри Джейкобсон' 'Генри Джуст, Ариэль Шульман'
#  'Генри Джуст, Эриель Шульман' 'Генри Селик' 'Генрик Рубен Генц'
#  'Георгий Варсимашвили' 'Георгий Орлов'
#  'Герард Квинто, Эстеве Солер, Дэвид Торрас' 'Герард МакМюррей'
#  'Герберт фон Караян. Постановка  Жоржа Вакевича' 'Герман Васке'
#  'Гермина Хунтгебурт' 'Гийом Винсент' 'Гийом Гальенн' 'Гийом Кане'
#  'Гийом Медачевски' 'Гил Кинан' 'Гилберт Кинг' 'Гильермо Амоедо'
#  'Гильермо Арриага' 'Гильермо Иван' 'Гильермо дель Торо'
#  'Гиоргос Лантимос' 'Гленио Бондер' 'Гленн Фикарра, Джон Рекуа'
#  'Го Аун Хое' 'Говард Холл' 'Гонсало Лопес-Гальего' 'Гор Вербински'
#  'Гор Киракосян' 'Грант Спьютор' 'Грач Кешишян' 'Грачья Кешишян'
#  'Грег Гарт' 'Грег Кос' 'Грег МакГилливрэй' 'Грег МакЛин' 'Грег Моттола'
#  'Грег Тирнан, Конрад Вернон' 'Грег Уайтели' 'Грегор Джордан'
#  'Грегори Джейкобс' 'Грегори Левассер' 'Грегори Плоткин' 'Грегори Хоблит'
#  'Грен Уэллс' 'Грета Гервиг' 'Грэг Берланти ' 'Грэг МакГиливрэй'
#  'Грэг МакГилливрэй' 'Грэг Мэнваринг' 'Грэм Мерфи'
#  'Губерт Вайланд, Нина Вельс' 'Гунилла Валлин. Хореограф Матс Эк'
#  'Густаво Кова' 'Густаво Эрнандес' 'Гуэндалина Дзампаньи'
#  'Гэбриел Маскаро' 'Гэвин Вьесен' 'Гэвин Грейзер' "Гэвин О'Коннор"
#  'Гэвин Худ' 'Гэри Ван' 'Гэри Дэйвид Голдберг' 'Гэри МакКендри'
#  'Гэри Маршалл' 'Гэри Росс' 'Гэри Траусдейл, Кирк Уайз'
#  'Гэри Трусдейл, Кирк Уайз' 'Гэри Фледер' 'Гэрри Маршалл'
#  'Гюстав де Керверн, Бенуа Делепин' 'Д. Абель, Ф. Гордон' 'Д. Кэмерон'
#  'Д.Адар, П.Антохин, М.Биасин, А.Бурунова, К.Колинз, К.Россет, Д.Эверет'
#  'Д.Алейников' 'Д.Алексеев' 'Д.Астрахан' 'Д.Банников' 'Д.Белоусов'
#  'Д.Боголепов' 'Д.Былинушкина' 'Д.Васильев' 'Д.Васильев, Ю.Райзман'
#  'Д.Великовская, Н.Лопато (псевдоним Нилова)' 'Д.Вершинин' 'Д.Вологдин'
#  'Д.Вятич-Бережных'
#  'Д.Глисон, Л.Дэвис, П.Жобер,  Б.Саузкомби, О.Уильямс, М.Д..Хелфгот, Д.Хилман, С.Чэн'
#  'Д.Грачев' 'Д.Григорьев' 'Д.Гринькин' 'Д.Гусельников' 'Д.Давыдов'
#  'Д.Даниелян' 'Д.Дваджиев' 'Д.Демура' 'Д.Дж.Карузо' 'Д.Додсон, А.Юрчиков'
#  'Д.Дунаев' 'Д.Дьяченко' 'Д.Елеонский' 'Д.Ефремович, А.Каторженко'
#  'Д.Ж.Карузо' 'Д.Зинченко' 'Д.Золототрубов' 'Д.Иванкова' 'Д.Изместьев'
#  'Д.Кабаков' 'Д.Карро, В.Абдрашитов' 'Д.Киселев' 'Д.Киселев, А.Баранов'
#  'Д.Киселев, А.Котт, А.Баранов, Л.Габриадзе'
#  'Д.Киселев, А.Першин (Ж.Крыжовников), А.Карпиловский, А.Черномазов (А.Нужный)'
#  'Д.Киселев, Е.Телегина, А.Котт, А.Карпиловский, А.Мегердичев, Л.Габриадзе'
#  'Д.Козловский' 'Д.Колонтай, И.Качалин, Д.Глазовский' 'Д.Коробкин'
#  'Д.Коробкин, Л.Гурченко' 'Д.Крылов' 'Д.Кубасов' 'Д.Кудрявцев'
#  'Д.Кузнецов (псевдоним - Хаски), Д.Найшуллер (псевдоним - Даша Чаруша), С.Поварницын, А.Золотарев, И.Плечёв'
#  'Д.Кузьмин' 'Д.Курочка (псевдоним Денис Бродский)' 'Д.Лазарев, С.Антонов'
#  'Д.Мамулия' 'Д.Мастеров, Н.Попова' 'Д.Месхиев' 'Д.Наумов' 'Д.Нейдманд'
#  "Д.О'Рейли" 'Д.Павлов' 'Д.Панченко' 'Д.Поволоцкий, М.Другой' 'Д.Прима'
#  'Д.Резванов, О.Хружков, И.Вейштагин' 'Д.Родимин' 'Д.Рудаков'
#  'Д.Светозаров' 'Д.Семибратов' 'Д.Сергин' 'Д.Силяков' 'Д.Степанов'
#  'Д.Суворов' 'Д.Сулейманов' 'Д.Сулейманов, О.Мусин' 'Д.Таран' 'Д.Туприн'
#  'Д.Тюрин' 'Д.Фадеев' 'Д.Файзиев' 'Д.Федоров' 'Д.Филюков'
#  'Д.Фирсова, И.Туманян, И.Селезнева' 'Д.Хананов' 'Д.Цветков, А.Петрова'
#  'Д.Цибаускайте (псевдоним - Дали Руст)' 'Д.Червяцов' 'Д.Чернов'
#  'Д.Шабаев' 'Д.Шмидт' 'Д.Шмидт, К.Феоктистов'
#  'Д.Шмидт, Ф.Дмитриев, В.Торопчин' 'Д.Штурманова'
#  'Д.Штурманова (псевдоним: Дуня Лисова)' 'Д.Шумакова' 'Д.Юзбашев'
#  'Давид Ало' 'Давид Алонсо, Энрике Гато' 'Давид Бисбано' 'Давид Гриеко'
#  'Давид Лево' 'Давид Манули' 'Давид Моро' 'Давид Феррарио'
#  'Давид Фонкинос, Стефан Фонкинос' 'Давид Шарон' 'Давиде Феррарио'
#  'Даг Лайман' 'Дайна Рейд' 'Дамиан Шифрон' 'Дамон Гамо' 'Дана Браун'
#  'Дани Бон' 'Дани де ла Орден' 'Даниель Отой' 'Данис Танович'
#  'Даниэл Аугусту' 'Даниэле Лукетти' 'Даниэль Альфредсон' 'Даниэль Бенмаур'
#  'Даниэль Бурман' 'Даниэль Кальпарсоро' 'Даниэль Рагуссис'
#  'Даниэль Робишо' 'Даниэль Санчес Аревало' 'Даниэль Фергюсон'
#  'Даниэль Штамм' 'Даниэль Эспиноса' 'Данте Лам' 'Дарен Линн Босман'
#  'Дарио Ардженто' 'Даррен Аронофски' 'Даррен Линн Баусмэн'
#  'Даррен Линн Боусман' 'Даррен Лион Бойсман' 'Даррин Линн Боусман'
#  'Дарья Жук'
#  'Дастин Гай Дэфа, Бенуа де Клерк, Александр Мермаз, Симон Меза Сото, Лоран Фироде, Леонид Шмельков'
#  'Дастин Хоффман'
#  'Даэ Джонг, Томек Дуки, Поль Кабон, Нино Кристен, Грег Маклеод, Энди Мартин, Николас Менар, Жанетт Перльман, Мики Плиз, Руне и Эсбен Фискер, Масанобу Хираока, Алан Холли'
#  'Дебора Андерсон' 'Дебра Граник' 'Дейв Филони' 'Дейвид Добкин'
#  'Дейвид МакНэлли' 'Дейвид Р.Эллис' 'Дейвид Тоухи'
#  'Деклан Доннеллан, Ник Ормерод' 'Деклан Дэйл' 'Декстер Флетчер'
#  'Демиан Рунья' 'Ден Мазер' 'Дени Аркан' 'Дени Вильнев' 'Дени Вильнёв'
#  'Дени Деркур' 'Дени Криеф' 'Дени де ла Орден' 'Дениз Гамзе Эргювен'
#  'Дениз Ди Нови' 'Денис Червяцов' 'Дениэл Эспиноза' 'Деннис Ботс'
#  'Деннис Виллануэве' 'Деннис Ганзель' 'Деннис Дуган' 'Деннис Хоппер'
#  'Деннисон Рамальо' 'Деон Тейлор' 'Дерек Сиенфрэнс' 'Дерек Сьянфранс'
#  'Дермот Малруни' 'Деррик Борте' 'Дестин Креттон' 'Детлеф Бук'
#  'Дж.П. Сниадецки' 'Дж.Т.Петти' 'Джадд Апатов' 'Джакомо Гатти'
#  'Джалиль Леспер' 'Джанкарло дель Монако' 'Джанлука Ансанелли'
#  'Джанфранко Рози' 'Джаред Хесс' 'Джастин Бальдони'
#  'Джастин Бенсон, Аарон Мурхед'
#  'Джастин Бенсон, Грегг Бишоп, Начо Вигалондо, Тодд Линкольн, Аарон Мурхед, Марсель Сармиенто'
#  'Джастин Дек' 'Джастин Закэм' 'Джастин Курзель' 'Джастин Лин'
#  'Джастин МакМиллан, Кристофер Нелиус' 'Джастин Пембертон' 'Джастин Стил'
#  'Джастин Типпинг' 'Джастин Чадвик' 'Джафар Панахи' 'Джей Ананья'
#  'Джей Барушель' 'Джей Блейксон' 'Джей Джей Абрамс'
#  'Джей Дюплис, Марк Дюплис' 'Джей Расселл' 'Джей Роач' 'Джей Роуч'
#  'Дидерик Ван Ружен' 'Диего Каплан' 'Дик Каррутерс' 'Дик Маас'
#  'Димитри Логотетис' 'Дин ДеБлуа' 'Дин Деблуа, Крис Сендерс' 'Дин Девлин'
#  'Дин Израэлайт' 'Дин Паризо' 'Дин Тейлор, Ноэль Клири и др.'
#  'Дин Хэмилтон' 'Дин Ши' 'Динг Лианг' 'Динг Лианг, Фуюан Лиу'
#  'Динг Лианг, Фуюань Лью' 'Дитер Бернер' 'Дито Монтиель'
#  'Дмитрий Черняков' 'Доме Карукоски'
#  'Доминик Абель, Фиона Гордон, Брюно Роми' 'Доминик Молль' 'Доминик Роше'
#  'Доминик Сена' 'Доминик Тьелль' 'Доминик Фарруджия' 'Дон МакКеллар'
#  'Дон Рус' 'Дон Харди, Дэна Начман' 'Дональд Петри' 'Дональд Шебиб'
#  'Донато Карризи' 'Донован Марш' 'Дорон Пас, Йоав Пас' 'Дороти Себба'
#  'Дрейк Доремус' 'Дрейк Доримус' 'Дрор Мор' 'Дрю Бэрримор' 'Дрю Годдар'
#  'Дрю Годдард' 'Дрю Дэйуолт, Дэвид Шнейдер' 'Дрю Пирс' 'Дуг Эллин'
#  'Дуглас Амиокоски' 'Дуглас Арниокоски' 'Дуглас МакГрат' 'Дункан Джонс'
#  'Дункан МакНили' 'Дункан МакФарланд' 'Дункан Уорд' 'Дуэйн Адлер'
#  'Дэвид Аттенборо' 'Дэвид Аубурн' 'Дэвид Баррет' 'Дэвид Бикерстафф'
#  'Дэвид Боуэрс, Сэм Фелл' 'Дэвид Брукс' 'Дэвид Бэтти' 'Дэвид Вустер'
#  'Дэвид Гелб' 'Дэвид Гордон Грин' 'Дэвид Дитль' 'Дэвид Добкин'
#  'Дэвид Дуглас' 'Дэвид Дуглас, Дрю Фелмэн' 'Дэвид Зеллнер, Нейтан Зеллнер'
#  'Дэвид Йейтс' 'Дэвид Йетс' 'Дэвид Кепп' 'Дэвид Керр' 'Дэвид Кин'
#  'Дэвид Кларк' 'Дэвид Кроненберг' 'Дэвид Кэмпбэлл' 'Дэвид Ликли'
#  'Дэвид Линч' 'Дэвид Листер' 'Дэвид Литч' 'Дэвид Лоуэри' 'Дэвид МакВикар'
#  'Дэвид МакКензи' 'Дэвид МакНелли' 'Дэвид Маквикар' 'Дэвид Маккензи'
#  'Дэвид Маллет' 'Дэвид Махмуди' 'Дэвид Мерфи' 'Дэвид Миркин' 'Дэвид Мишо'
#  'Дэвид Моро, Хавьер Палю'
#  'Дэвид Мур, Джереми Вебб, Метин Хусейн, Элис Тротон' "Дэвид О'Расселл"
#  'Дэвид О.Рассел' 'Дэвид О.Расселл' 'Дэвид Олден'
#  'Дэвид Палмер, Дэкс Шепард' 'Дэвид Р.Эллис' 'Дэвид Роберт Митчелл'
#  'Дэвид Рэймонд' 'Дэвид С.Гойер' 'Дэвид Сильверман' 'Дэвид Слейд'
#  'Дэвид Слэйд' 'Дэвид Сорен' 'Дэвид Туи' 'Дэвид Ф. Сандберг'
#  'Дэвид Ф.Сэндберг' 'Дэвид Фейсс' 'Дэвид Финчер' 'Дэвид Фрейн'
#  'Дэвид Френкель' 'Дэвид Фрэнкел' 'Дэвид Хакл' 'Дэвид Холройд'
#  'Дэвид Хорн' 'Дэвид Хэйтер' 'Дэвид Цукер' 'Дэвид Эйр' 'Дэвид Юнг'
#  'Дэвид Яровецки' 'Дэвин ДиХэйвен' 'Дэйв Бортвик' 'Дэйв Грин'
#  'Дэйвид Р.Эллис' 'Дэмиан Чапа' 'Дэмьен Шазелл' 'Дэн Бирс' 'Дэн Брэдли'
#  'Дэн Буш' 'Дэн Вэйфэн' 'Дэн Гилрой' 'Дэн Израэлит'
#  'Дэн Кван, Дэниэл Шайнерт' 'Дэн Креч' 'Дэн Сан Пьер, Уилл Финн'
#  'Дэн Скэнлон' 'Дэн Трактенберг' 'Дэн Фогельман' 'Дэни Бун' 'Дэни Вильнёв'
#  'Дэни Леви' 'Дэниел Альфредсон' 'Дэниел Барнц' 'Дэниэл Роби'
#  'Дэниэл Фаррандс' 'Дэниэл Фриделль' 'Дэниэл Шехтер' 'Дэниэл Эспиноза'
#  'Дэниэль Монзон' 'Дэниэль Нетхейм' 'Дэниэль Стамм' 'Дэниэль Эспиноса'
#  'Дэнни Бойл' 'Дэнни Гордон' 'Дэнни ДеВито' 'Дэнни Кэннон' 'Дэнни Лернер'
#  'Дэнни Муни' 'Дэнни Панг, Оксид Панг' 'Дэнни Стронг' 'Дэннис Барток'
#  'Дэннис Дуган' 'Дэннис Илиадис' 'Дэрил Вейн' 'Дяо Инань'
#  'Е. Махнутин (псевдоним - Евгений Юматов)' 'Е.Абраменко' 'Е.Абызов'
#  'Е.Алексеев, А.Алексеев' 'Е.Анашкин' 'Е.Андриканис'
#  'Е.Антимоний (псевдоним - Иван Курский)' 'Е.Антимоний, В.Вакуленко'
#  'Е.Астрецова'
#  'Е.Астрецова, Е.Фадеев, В.Карнавалова, Е.Филиппова, А.Веселов, И.Максимов и др.'
#  'Е.Баранов' 'Е.Баранов.  ' 'Е.Барханов' 'Е.Бедарев' 'Е.Безбородов'
#  'Е.Белова' 'Е.Болычева' 'Е.Борисова' 'Е.Борисова при участии В.Фатьянова'
#  'Е.Бронникова' 'Е.Бычкова' 'Е.Гинзбург' 'Е.Грамматиков' 'Е.Грибов'
#  'Е.Гроховская' 'Е.Гусева' 'Е.Данченко'
#  'Е.Дворецкая (псевдоним - Елена Лобачева-Дворецкая)' 'Е.Дорофеева'
#  'Е.Дубкова' 'Е.Егоров' 'Е.Ермолина' 'Е.Живайкина, А.Костогарова'
#  'Е.Жигаева' 'Е.Жиркова, А.Кузина, М.Солошенко'
#  'Е.Жиркова, А.Кузина, М.Солошенко, С.Кравцова' 'Е.Захаров, А.Соснов'
#  'Е.Звездаков' 'Е.Зильберштейн, А.Дудоров' 'Е.Карелов' 'Е.Кашинцева'
#  'Е.Киреева, Т.Кисилева, Е.Нестерова, А.Панкратов, О.Сивакова-Васина, А.Романова и др.'
#  'Е.Клейнот (псевдоним Любовь Андреева)' 'Е.Кожокин'
#  'Е.Константинова (псевдоним Алена Званцева)' 'Е.Кончаловский'
#  'Е.Королева' 'Е.Кравченко' 'Е.Кривцов, В.Кленин' 'Е.Логунцова'
#  'Е.Матвеев' 'Е.Милых' 'Е.Миндадзе (псевдоним Катя Шагалова)'
#  'Е.Михайлова' 'Е.Михайлова, И.Максимов' 'Е.Михалков-Кончаловский'
#  'Е.Морозов' 'Е.Невский' 'Е.Невский (псевдоним Е.Торрес)'
#  'Е.Никитин, А.Королёв, К.Плетнев'
#  'Е.Обермаер (псевдоним Е.Шапиро-Обермаер)' 'Е.Окопная'
#  'Е.Останина, С.Родкевич' 'Е.Паршина-Штайн (псевдоним Елена Штайн)'
#  'Е.Перволовичи' 'Е.Резников' 'Е.Савин'
#  'Е.Салабай, А.Миронов, Е.Головин, А.Борисова и др.'
#  'Е.Салабай, А.Рубецкой, В.Воля, Е.Головин, А.Соколов, В.Бедошвили, Д.Червяцов'
#  'Е.Салабай, В.Пономарёв, А.Миронов, Е.Головин, А.Бахурин'
#  'Е.Салабай, В.Пономарёв, А.Миронов, И.Пшонкин, А.Рубецкой, Н.Харина, Е.Чернова, А.Бахурин, О.Ужинов'
#  'Е.Салабай, Е.Шабанова  И.Пшонкин и др.'
#  'Е.Салабай, Е.Шабанова, А.Миронов, А.Толстобров, В.Мухаметзянов'
#  'Е.Салабай, Е.Шабанова, А.Соколов, И.Пшонкин и др.'
#  'Е.Салабай, Р.Верещак, Е.Головин, А.Миронов, Е.Савчук, Р.Газизов, Е.Шабанова'
#  'Е.Севастьянов' 'Е.Семенов' 'Е.Сергеев' 'Е.Соколов'
#  'Е.Соколов, В.Панжев, Г.Курлаев, С.Морозов, М.Сулейманова и др.'
#  'Е.Соколов, Е.Морозова, В.Панжев, Г.Курлаев и др.' 'Е.Сокуров'
#  'Е.Соломина, А.Баршак, К.Статский' 'Е.Стишова' 'Е.Сысоева (С.Лысенко)'
#  'Е.Татаров' 'Е.Ташков' 'Е.Ташков, А.Ташков' 'Е.Телегина'
#  'Е.Телегина, М.Полинский' 'Е.Тетерин, А.Бобровский' 'Е.Тирдатова'
#  'Е.Трапезникова' 'Е.Трусевич' 'Е.Туркова' 'Е.Хазанова' 'Е.Хломова'
#  'Е.Цымбал' 'Е.Цыплакова' 'Е.Чернова' 'Е.Чичканов' 'Е.Шелякин'
#  'Е.Шереметьева' 'Е.Шиляева' 'Е.Шин' 'Е.Яцкина, А.Рубинштейн'
#  'Ева Ионеско' 'Евгений Голынкин, Николя Милетич' 'Евгений Дербез'
#  'Евгений Пашкевич' 'Ежи Сколимовский' 'Екатерина Еременко'
#  'Елена Аршакян' 'Елена Коссон Кизилова'
#  'Елена Тихонова, Доминик Шпритцендорфер'
#  'Ж.Альберт, К.Грижевски, С.Зморк, И.Кранковски, Д.Милейро, Э.Романс,, Н.Тайберг, Х.Фариас '
#  'Ж.Альберт, М.Кунерт, М.Митник,  Д.Рейниш, М.Ричмонд, Д.Соскин,  В.Стотер, Д.Ходжсон'
#  'Ж.Бадмацыренов' 'Ж.Бадмацыренов, А.Кузьминов, Е.Замалиев'
#  'Ж.Бекмамбетова' 'Ж.Романова' 'Жак Дере' 'Жак Дуайон' 'Жак Клюгер'
#  'Жак Одиар' 'Жак Перрен, Жак Клюзо' 'Жак Уаниш' 'Жаклин Шеффер'
#  'Жако Ван Дормель' 'Жако ван Дормель' 'Жалиль Леспере' 'Жалмари Хеландер'
#  'Жамель Деббуз' 'Жан Боден' 'Жан Кристоф Дюссант' 'Жан Рабек'
#  'Жан Франсуа Рише' 'Жан-Батист Леонетти ' 'Жан-Жак Анно'
#  'Жан-Жак Мантелло' 'Жан-Люк Годар' 'Жан-Мари Пуаре' 'Жан-Марк Валле'
#  'Жан-Марк Валли' 'Жан-Марк Рудницкий' 'Жан-Поль Лилиенфельд'
#  'Жан-Поль Раппно' 'Жан-Пьер Амери' 'Жан-Пьер Дарденн, Люк Дарденн'
#  'Жан-Пьер Жене' 'Жан-Пьер Жёне' 'Жан-Стефан Брон' 'Жан-Стефан Совер'
#  'Жан-Франсуа Пуле' 'Жан-Франсуа Рише' 'Жанна Лабрюн' 'Жанна Эри'
#  'Жаргалсаихан Баатар' 'Жаума Кольет-Серра' 'Жауме Балагуэро'] ['Жеральд Юсташ-Матьё' 'Жерар Кравчик' 'Жером Салль' 'Жером Энрико'
#  'Жилль Бурдо' 'Жиль Бурдо' 'Жиль Де Местр' 'Жиль Леллуш'
#  'Жиль Паке-Бреннер' 'Жильбер Дефло' 'Жоан Фонт' 'Жоанн Сфар'
#  'Жозе Антонио Негрет' 'Жозе Падилья' 'Жослин ДеБоэр, Доун Люббе'
#  'Жослин Таун, Саймон Хелберг' 'Жофрей Энтховен' 'Жуанра Фернандез'
#  'Жюли Бертучелли' 'Жюли Дельпи' 'Жюльен Леклерк'
#  'Жюльен Лякомб, Паскаль Сид' 'Жюстин Трие' 'З.Аграненко'
#  'З.Болотаев, К.Смирнов' 'З.Гапиенко' 'З.Трофимова' 'Зак Брафф'
#  'Зак Липовски, Адам Б.Стейн' 'Зак Снайдер' 'Зак Уэдон' 'Зак Хилдитч'
#  'Закари Адлер' 'Зандор Йессе, Уте фон Мюнхов-Поль' 'Захари Донохью'
#  'Зенке Вортманн' 'Зигфрид' 'Зося (София) Родкевич' 'Зоя Ахтар'
#  'Зэк Снайдер' 'Зёнке Вортманн' 'И Гэ, Сун Юэфэн' 'И.Анненский' 'И.Бабич'
#  'И.Басенко (псевдоним - Ирина Бас)' 'И.Бахтина' 'И.Белов' 'И.Белостоцкий'
#  'И.Белостоцкий, В.Панжев, А.Щеглов, Н.Хлопецкая, С.Морозов, Е.Соколов, М.Сулейманов  и др.'
#  'И.Белостоцкий, Р.Фрунтов, А.Зеленков, Е.Юликов, С.Морозов, А.Щеглов, Г.Курлаев и др.'
#  'И.Блохина' 'И.Болотников' 'И.Волкова' 'И.Волосецкий' 'И.Волошин'
#  'И.Вырыпаев' 'И.Гостев' 'И.Дамаскин, Р.Рашитов' 'И.Джендубаев'
#  'И.Долгина' 'И.Евланникова' 'И.Евланникова, Д.Моллер, М.Котик'
#  'И.Евланов' 'И.Евтеева'
#  'И.Ермолов, И.Каграманов, Э.Барсегян, Н.Искандарова' 'И.Зайцев'
#  'И.Зайцев, О.Урушев' 'И.Замалиев (псевдоним Э.Бартенев)' 'И.Затевахин'
#  'И.Иванов' 'И.Каграманов'
#  'И.Каграманов, А.Наумов, С.Осипьян, В.Валиуллин, Е.Бродач, К.Васильев'
#  'И.Казанков' 'И.Каленов' 'И.Калядин' 'И.Квирикадзе' 'И.Киасашвили'
#  'И.Ковалев' 'И.Комладзе' 'И.Копылов' 'И.Копылов, С.Щербин' 'И.Кордзаия'
#  'И.Кордзаия, В.Лисневский' 'И.Корнеев' 'И.Коробейников'
#  'И.Короткий, А.Маслов, С.Буров, Е.Устюгова, А.Шульев' 'И.Котельников'
#  'И.Красников, Вахтанги Хубутия' 'И.Куликов' 'И.Кунилов' 'И.Максимов'
#  'И.Малкин, И.Бессарабова' 'И.Мардарь' 'И.Маслюков' 'И.Мережко'
#  'И.Найтшуллер' 'И.Осипов' 'И.Пелинский' 'И.Перекатов' 'И.Перин'
#  'И.Петухов'
#  'И.Пшонкин, Е.Салабай, А.Миронов, А.Толстобров, В.Мухаметзянов'
#  'И.Пшонкин, М.Ершов, А.Миронов и др.' 'И.Пырьев'
#  'И.Пырьев, М.Ульянов, К.Лавров' 'И.Рожков' 'И.Ромащенко' 'И.Савельев'
#  'И.Савченко, Т.Лукашевич, М.Ромм' 'И.Сарахатунова' 'И.Сафаров'
#  'И.Северов' 'И.Семашко' 'И.Сколков' 'И.Слабневич' 'И.Соловьев'
#  'И.Соловьева, Д.Шмидт, О.Ужинов, Д.Червяцов, М.Нефедова, О.Кузовков'
#  'И.Соснин, П.Андреева, М.Местецкий, Е.Стишова, М.Архипов' 'И.Стам'
#  'И.Стороженко' 'И.Таланкин' 'И.Твердовский' 'И.Тойонов' 'И.Триф'
#  'И.Трусов' 'И.Угольников' 'И.Учитель' 'И.Фирсова' 'И.Фрэз'
#  'И.Цветов (режиссер ч/б фильма - С.Тимошенко)' 'И.Черницкий'
#  'И.Чижиков, А.Чижиков' 'И.Шахназаров' 'И.Шерстобитов' 'И.Шурховецкий'
#  'И.Щербань' 'И.Ягафаров' 'Иван Атталь' 'Иван Джерголет' 'Иван Кальберак'
#  'Игор Биддау' 'Игорь Тувери' 'Иджинио Страффи' 'Ижинио Страффи'
#  'Изабель Койшет' 'Изуру Нарушима' 'Илай Рот' 'Илмар Рааг'
#  'Ильдико Эньеди' 'Илья Трусов' 'Илья Хржановский' 'Инджинио Страффи'
#  'Инжинио Страффи' 'Иоахим Реннинг, Эспен Сандберг' 'Исаак Федер'
#  'Исида Хироясу' 'Иссара Нади, Кирати Нак-Интанон, Патчанон Тумджира'
#  'Иссара Нади, Кирати Нак-Интанон, Путипонг Сайсрикаев' 'Итан Коэн'
#  'Итэн Коэн, Джоэл Коэн' 'Йен Де Бонт' 'Йен Софтли' 'Йен Фитцгиббон'
#  'Йеспер Гансландт' 'Йоаким Реннинг, Эспен Сандберг' 'Йоаким Роннинг'
#  'Йоаким Триер' 'Йоахим Лафосс' 'Йоахим Масаннек'
#  'Йоахим Роуннинг, Эспен Сандберг'
#  'Йоганнес Вайланд, Макс Ланг, Уве Хайдшёттер, Якоб Шух' 'Йорген Лердам'
#  'Йорген Лет, Ларс Фон Триер' 'Йоргос Лантимос' 'Йорма Такконе'
#  'Йорханнес Вейланд, Лео Верьер, Джон Карс, Минью Ли, Ричард Манс, Тимати Рекарт, Дэвид Сильверман, Уве Хайдесшоттеи'
#  'Йос Стеллинг' 'Йоханнес Нюхольм' 'Йоханнес Робертс'
#  'Йошихиро Нишимура, Наюки Томомацу' 'Йуис Килес' 'Йэн Софтли'
#  'К. Шелепов' 'К.Ангелина' 'К.Балагов' 'К.Баскакова' 'К.Белевич'
#  'К.Белевич (псевдоним - Кирилл Астахов), Г.Ильин' 'К.Бронзит' 'К.Буслов'
#  'К.Васильев' 'К.Воинов' 'К.Геворкян' 'К.Герасимов'
#  'К.Денё, Х.Дюмулайн, А.Кардона, Т.Мекинс, Д.Фини, М.Фонтан-РОсси, Л.Хадсон'
#  'К.Дружинин' 'К.Дружинин, А.Шальопа' 'К.Кемниц' 'К.Коваленко' 'К.Козлов'
#  'К.Козлова' 'К.Кокорев' 'К.Котельников, А.Аболс' 'К.Красноперов'
#  'К.Кузин' 'К.Лопушанский' 'К.Максимов' 'К.Малкин-Фам'
#  'К.Мирзоян, А.Петрухин' 'К.Муратова' 'К.Мурзенко' 'К.Оганесян'
#  'К.Оганисян' 'К.Одегов' 'К.Папакуль' 'К.Плетнёв' 'К.Поплавский'
#  'К.Попович' 'К.Ратушная' 'К.Румак'
#  'К.Сафина, А.Першин, Г.Добрыгин, О.Михеева, К.Плетнев' 'К.Серебренников'
#  'К.Серебряков' 'К.Соколов' 'К.Сухарьков' 'К.Тимофеев' 'К.Трофимова'
#  'К.Феоктистов' 'К.Хабенский, А.Малюков' 'К.Хрестинин' 'К.Худяков'
#  'К.Чувикова' 'К.Шахназаров' 'К.Шахназаров, А.Бородянский' 'К.Шипенко'
#  'К.Юдин' 'К.Юдин, Б.Барнет' 'Кабир Кхан' 'Казуаки Кирия' 'Кайжайр Акопян'
#  'Кайл Балда, Пьер Соффин' 'Кайл Балда, Эрик Гуильон, Пьер Коффан'
#  'Кайл Ньюман' 'Кайл Райдаут' 'Кали Коури' 'Каллен Брункер'
#  'Каллэн Брункер' 'Камаль Бансаль' 'Камиль Деламарр' 'Кан Евренол'
#  'Кан Чжэ Гю' 'Кандида Бреди' 'Карадог В. Джеймс' 'Каран Джохар'
#  'Карел Смычек' 'Карен Ли Хопкинс' 'Карим Дриди' 'Карин Кусама'
#  'Карин Пройя' 'Карл Кох, Лотти Рейнигер' 'Карл Кристиан Раабе'
#  'Карл Мендес' 'Карл Ринш' 'Карл Тордж' 'Карла Лиа Монти'
#  'Карла фон Бенгтсон' 'Карлес Торренс' 'Карло Карлей'
#  'Карлос Гутиеррез Медрано' 'Карлос Каррера' 'Карлос Маркус-Марсет'
#  'Карлос Рейгадас' 'Карлос Саладна' 'Карлос Салдана' 'Карлос Саура'
#  'Карлус Диегос' 'Карстен Килерих' 'Карстен Килерих, Рихард Клаус'
#  'Каспар Мунк' 'Каспер Барфоэд' 'Каспер Хольтен'
#  'Катарина Оуэн, Марк Пеллингтон' 'Катерина Кароне' 'Катрин Корсини'
#  'Катрин Филип' 'Кацуси Сакураби' 'Квентин Дюпье' 'Квентин Дюпьё'
#  'Квентин Тарантино' 'Кевин Гетц, Майкл Гетц' 'Кевин Гройтерт'
#  'Кевин Гротерт' 'Кевин Джонсон' 'Кевин Колш, Деннис Уидмайер'
#  'Кевин Коннолли' 'Кевин Костнер' 'Кевин МакДональд' 'Кевин Монро'
#  'Кевин Мунро' 'Кевин О.Хара. Хореография Кристофера Уилдона '
#  'Кевин Рейнолдс' 'Кевин Смит' 'Кевин Танчароэн' 'Кеер Ху ' 'Кейси Аффлек'
#  'Кейси Патрик Тебо' 'Кейт Шортланд' 'Келли Эсбери' 'Келли Эсбёрн'
#  'Кен Коупис' 'Кен Куопис' 'Кен Лоуч' 'Кен Скотт' 'Кен Сэнзел'
#  'Кеннет Брана' 'Кеннет Брэна' 'Кеннет Лонерган' 'Кенни Ортега'
#  'Кенни Янг' 'Кент Джонс' 'Керк Де Микко, Крис Сандерс'
#  'Керн Конвайзер, Дэвид Рен' 'Керн Секстон' 'Кертис Хэнсон, Майкл Эптид'
#  'Кике Майло' 'Ким Ки Дук' 'Ким Ки-Дук' 'Ким Ки-Дук ' 'Ким Ки-дук'
#  'Ким Нгуйен' 'Ким Фаррант' 'Ким Чжи Ун' 'Кимберли Пирс' 'Кимбл Рендалл'
#  'Кимо Стамбол, Тимо Тьяджанто' 'Кинен Айвори Уэйанс' 'Кира Муратова'
#  'Киран Дарси-Смит' 'Киран Фой' 'Кирби Аткинс' 'Кирилл Михановский'
#  'Кирк Джонс' 'Кирстен Шеридан' 'Кит Уорнер' 'Кия Роуч-Тернер'
#  'Клайв Тонг' 'Клаудиа Майерс' 'Клаудио Джованнези' 'Клаудио Ноче'
#  'Клаудио Поли' 'Клаудио Уберти' 'Клаудио Фах' 'Клер Дени' 'Клинт Иствуд'
#  'Кловис Корнийяк' 'Клод Баррас' 'Клод Берри, Франсуа Дюпейрон'
#  'Клод Лелуш' 'Клод Миллер, Натан Миллер' 'Клод Нуридзани, Мари Перену'
#  'Клэй Кейтис, Фергал Рейли' 'Клэй Холл' 'Клэр МакКарти' 'Кодзи Вакамацу'
#  'Кодзи Шираиши' 'Коди Кэмерон' 'Коди Кэмерон, Крис Пири'
#  'Колин Треворроу' 'Колин Фей' 'Колин Штраус, Грэг Штраус' 'Колм МакКарти'
#  'Компин Кемгумнирд' 'Конор Эллин' 'Конрад Вернон, Грег Тирнан'
#  'Кори Пирсон' 'Корин Харди' 'Корнелиу Порумбойю' 'Корнель Мундруцо'
#  'Крейг Зобель'
#  'Ю.Казачков' 'Ю.Калинина' 'Ю.Кара' 'Ю.Карасик'
#  'Ю.Королев (псевдоним Ю.Стааль)' 'Ю.Кулаков' 'Ю.Курочка' 'Ю.Кушнерев'
#  'Ю.Лейдерман, А.Сильвестров' 'Ю.Мазурова' 'Ю.Малюгин' 'Ю.Мамин'
#  'Ю.Матросова, А.Миронов, С.Ромашкин, Дм. Высоцкий, И.Фаве, А.Алексеев, П.Минченок и др.'
#  'Ю.Мерзляков, Р.Магомадов, А.Ольков' 'Ю.Миронова' 'Ю.Мороз' 'Ю.Морская'
#  'Ю.Озеров' 'Ю.Озеров, С.Гуров' 'Ю.Озеров, Ю.Бондарев'
#  'Ю.Перкуль, А.Богатырев, А.Камачо' 'Ю.Попович' 'Ю.Разыков' 'Ю.Райзман'
#  'Ю.Рыбакова' 'Ю.Сапонова' 'Ю.Сизов' 'Ю.Солнцева' 'Ю.Суходольский'
#  'Ю.Сысоев, В.Мистюков, К.Тищенко' 'Ю.Фетинг' 'Ю.Чулюкин' 'Ю.Шамилов'
#  'Ю.Шиллер' 'Юго Желен' 'Юкка-Пекка Валькеапяя' 'Юлиан Радльмайер'
#  'Юнг Куюн Парк' 'Юрген Лердам, Кари Юуусонен' 'Юфенг Сонг'
#  'Юхо Куосманен' 'Юхэй Сакураги' 'Юэн МакГрегор' 'Юэнь Ву-Пин'
#  'Я.Варлашкина' 'Я.Войтова, И.Черджиева'
#  'Я.Лаптев (псевдоним Яков Раскалов)' 'Я.Лапшин' 'Я.Лебедев'
#  'Я.Поляруш, Т.Цоцория, К.Кутуев при участии М.Алиева' 'Я.Трофимова'
#  'Я.Хальпукова (псевдоним Яна Мартынец)' 'Якоб Розенберг'
#  'Якуб Вронски, Ира Карпелан' 'Ялмари Хеландер' 'Ян Бергер' 'Ян Гэ'
#  'Ян Хафт' 'Яне Магнуссон' 'Янн Деманж' 'Яннике Систад Якобсен'
#  'Яннис Смарагдис' 'Янус Мец Педерсен' 'Януш Жомболай' 'Ярослав Губченко'
#  'Ясухиро Есиура' 'Яш Чопра' 'неизвестно' 'хореограф Кеннет Макмиллан'
#  'хореограф Матс Эк' 'хореография Василия Вайнонена. Андреас Морелл'
#  'хореография Джорджа Баланчина'
#  'хореография Карлоса Акосты по Мариусу Петипа'
#  'хореография Кеннета МакМиллана' 'хореография Кристофера Уилдона'
#  'хореография Мариуса Петипа'
#  'хореография Мариуса Петипа в редакции Наталии Макаровой'
#  'хореография Питера Райта, Льва Иванова по разработке Мариуса Петипа'
#  'хореография Питера Райта, Льва Иванова по разработке Мариуса Петипа в режиссуре Кристофера Карра'
#  'хореография Пьера Лакотта по Филиппу Тальони'
#  'хореография Фредерика Аштона' 'хореография Фредерика Эштона']
# Конец списка, количество элементов:  4814
#                                                title   puNumber  \
# 6957                Тайная жизнь домашних животных 2  124003519
# 3334          Фантастические твари и где они обитают  121029216
# 6501                                         Аквамен  121028518
# 7110                             Форсаж: Хоббс и Шоу  121021319
# 7388  Полицейский с Рублевки. Новогодний Беспредел 2  111019519
# ...                                              ...        ...
# 1348                                 Курьер из "Рая"  111014313
# 7291                                         Курьезы  111017619
# 1797               Курбан-роман. (История с жертвой)          0
# 5074                                          Кундун  221053710
# 5037                                 Кунг-фу Панда 2  224021511
#
#                show_start_date            type  \
# 6957 2019-05-25 12:00:00+00:00    Анимационный
# 3334 2016-10-31 12:00:00+00:00  Художественный
# 6501 2018-12-13 12:00:00+00:00  Художественный
# 7110 2019-08-01 12:00:00+00:00  Художественный
# 7388 2019-12-12 12:00:00+00:00  Художественный
# ...                        ...             ...
# 1348 2013-12-18 12:00:00+00:00  Художественный
# 7291 2019-10-18 12:00:00+00:00  Художественный
# 1797 2014-05-15 12:00:00+00:00  Художественный
# 5074 2010-05-12 12:00:00+00:00  Художественный
# 5037 2011-11-16 12:00:00+00:00    Анимационный
#
#                                             film_studio    production_country  \
# 6957       Иллюминейшн Интертейнмент, Юниверсал Пикчерз  США, Франция, Япония
# 3334                       Уорнер Бразерс, Хэйдэй Филмз  США - Великобритания
# 6501  Ди Си Комикс, Панорамик Пикчерз, Сафран Компан...       США - Австралия
# 7110                                  Юниверсал Пикчерз  Великобритания - США
# 7388  АО "ТНТ-Телесеть", ООО "ЛЕГИО ФЕЛИКС", ООО "1-...                Россия
# ...                                                 ...                   ...
# 1348     ЗАО "Дирекция Кино", ООО "ПРО-СИНЕМА продакшн"                Россия
# 7291                                    АНО "Кинофорум"                Россия
# 1797                                   ФОНД "ИННОВАЦИЯ"                Россия
# 5074                                   Тачстоун Пикчерз                   США
# 5037                                 ДримУоркс Анимэйшн                   США
#
#              director                                           producer  \
# 6957        Крис Рено                                      Лиз-Мари Амар
# 3334      Дэвид Йейтс         Стивен Кловз, Дж. К. Роулинг, Дэвид Хэйман
# 6501       Джеймс Ван                            Роб Кауэн, Питер Сафран
# 7110       Дэвид Литч                        Хирам Гарсиа, Дуэйн Джонсон
# 7388        И.Куликов  В.Федорович, Е.Никишов, И.Куликов, ООО "1-2-3 ...
# ...               ...                                                ...
# 1348     М.Хлебородов                                А.Максимов, Н.Попов
# 7291         А.Мышкин                                        С.Новожилов
# 1797          С.Юзеев                                         М.Галицкая
# 5074  Мартин Скорсезе                                         неизвестно
# 5037      Дженнифер Ю         Мелисса Кобб, Джонатан Айбел, Гленн Бергер
#
#                              age_restriction  refundable_support  \
# 6957           «6+» - для детей старше 6 лет                -1.0
# 3334         «12+» - для детей старше 12 лет                -1.0
# 6501         «12+» - для детей старше 12 лет                -1.0
# 7110         «12+» - для детей старше 12 лет                -1.0
# 7388         «12+» - для детей старше 12 лет                -1.0
# ...                                      ...                 ...
# 1348         «12+» - для детей старше 12 лет                -1.0
# 7291         «16+» - для детей старше 16 лет                -1.0
# 1797         «12+» - для детей старше 12 лет                -1.0
# 5074         «12+» - для детей старше 12 лет                -1.0
# 5037  «0+» - для любой зрительской аудитории                -1.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 6957                   -1.0    -1.0       неизвестно     6.8
# 3334                   -1.0    -1.0       неизвестно     7.6
# 6501                   -1.0    -1.0       неизвестно     6.8
# 7110                   -1.0    -1.0       неизвестно     6.3
# 7388                   -1.0    -1.0       неизвестно     5.8
# ...                     ...     ...              ...     ...
# 1348                   -1.0    -1.0       неизвестно     5.7
# 7291                   -1.0    -1.0       неизвестно     5.0
# 1797                   -1.0    -1.0       неизвестно       0
# 5074                   -1.0    -1.0       неизвестно     7.4
# 5037                   -1.0    -1.0       неизвестно     7.4
#
#                               genres       box_office               country
# 6957  мультфильм,комедия,приключения 1,478,921,168.46  США, Франция, Япония
# 3334    фэнтези,приключения,семейный  1,398,264,684.0  США , Великобритания
# 6501       фантастика,фэнтези,боевик 1,278,044,179.16       США , Австралия
# 7110      боевик,триллер,приключения 1,065,210,005.03  Великобритания , США
# 7388             комедия,приключения 1,039,706,431.83                Россия
# ...                              ...              ...                   ...
# 1348             комедия,приключения             -1.0                Россия
# 7291                      неизвестно             -1.0                Россия
# 1797                      неизвестно             -1.0                Россия
# 5074         драма,военный,биография             -1.0                   США
# 5037       мультфильм,фэнтези,боевик             -1.0                   США
#
# [2150 rows x 17 columns]
#                                             title   puNumber  \
# 3460                               Полтора шпиона  121019516
# 2394                             Чем дальше в лес  121029214
# 5197  Пираты Карибского моря: На странных берегах  121005611
# 3459                               Полтора шпиона  221037416
# 6832                                        Спуск  121006319
# 2393                             Чем дальше в лес  221000415
# 4398                                    Центурион  121011910
# 3902                       День святого Валентина  221083810
# 5303                           "Старый" Новый год  121024911
# 87                                  Взрослые дети  111013013
# 70                               Бой после победы  111011813
# 43       Мемуары гейши (по роману Артура Голдена)  121000606
# 24                              Неисправимый лгун  111003516
#
#                show_start_date            type  \
# 3460 2016-06-27 12:00:00+00:00  Художественный
# 2394 2014-12-23 12:00:00+00:00  Художественный
# 5197 2011-05-16 12:00:00+00:00  Художественный
# 3459 2016-10-03 12:00:00+00:00  Художественный
# 6832 2019-03-29 12:00:00+00:00  Художественный
# 2393 2015-02-10 12:00:00+00:00  Художественный
# 4398 2010-06-24 12:00:00+00:00  Художественный
# 3902 2010-07-15 12:00:00+00:00  Художественный
# 5303 2011-12-27 12:00:00+00:00  Художественный
# 87   2013-12-19 12:00:00+00:00  Художественный
# 70   2013-12-19 12:00:00+00:00  Художественный
# 43   2012-12-14 12:00:00+00:00  Художественный
# 24   2016-02-12 12:00:00+00:00  Художественный
#
#                                             film_studio production_country  \
# 3460                   Нью Лайн Синема, Блю Грасс Филмз                США
# 2394  Лукамар Продакшнз, Марк Платт Продакшнз, Уолт ...                США
# 5197       Джерри Брукхаймер Филмз, Уолт Дисней Пикчерз                США
# 3459                   Нью Лайн Синема, Блю Грасс Филмз                США
# 6832             Селадор Филмз, Нортмэн Продакшнз, Пате     Великобритания
# 2393  Лукамар Продакшнз, Марк Платт Продакшнз, Уолт ...                США
# 4398                                      Селадор Филмз     Великобритания
# 3902  Уорнер Бразерс, Нью Лайн Синема, Уэйн Райс, Ка...                США
# 5303  Нью Лайн Синема, Райс Филмз, Карц Интертейнмен...                США
# 87                                Киностудия "Мосфильм"               СССР
# 70                                Киностудия "Мосфильм"               СССР
# 43    Коламбия Пикчерз Корпорейшн, ДримУоркс ЭсКейДж...                США
# 24                                Киностудия "Мосфильм"               СССР
#
#                    director  \
# 3460  Роусон Маршалл Тёрбер
# 2394            Роб Маршалл
# 5197            Роб Маршалл
# 3459  Роусон Маршалл Тёрбер
# 6832            Нил Маршалл
# 2393            Роб Маршалл
# 4398            Нил Маршалл
# 3902          Гарри Маршалл
# 5303          Гарри Маршалл
# 87                 В.Азаров
# 70                 В.Азаров
# 43              Роб Маршалл
# 24                 В.Азаров
#
#                                                producer  \
# 3460                                   Питер Принципато
# 2394  Джон ДеЛука, Каллум МакДугалл, Роб Маршалл, Ма...
# 5197                                  Джерри Брукхаймер
# 3459                                   Питер Принципато
# 6832  Кристиан Колсон, Ивана МакКиннон, Пол Ричи, По...
# 2393  Джон ДеЛука, Каллум МакДугалл, Роб Маршалл, Ма...
# 4398                     Кристиан Колсон, Роберт Джонес
# 3902                                    Сэмюэл Дж.Браун
# 5303                Майк Карц, Гарри Маршалл, Уэйн Райс
# 87                                Киностудия "Мосфильм"
# 70                                Киностудия "Мосфильм"
# 43    Стивен Спилберг, Люси Фишер, Дуглас Уик, Джон ...
# 24                                Киностудия "Мосфильм"
#
#                       age_restriction  refundable_support  \
# 3460  «16+» - для детей старше 16 лет                -1.0
# 2394  «12+» - для детей старше 12 лет                -1.0
# 5197  «12+» - для детей старше 12 лет                -1.0
# 3459  «16+» - для детей старше 16 лет                -1.0
# 6832      «18+» - запрещено для детей                -1.0
# 2393  «12+» - для детей старше 12 лет                -1.0
# 4398  «16+» - для детей старше 16 лет                -1.0
# 3902  «16+» - для детей старше 16 лет                -1.0
# 5303  «16+» - для детей старше 16 лет                -1.0
# 87      «6+» - для детей старше 6 лет                -1.0
# 70      «6+» - для детей старше 6 лет                -1.0
# 43    «12+» - для детей старше 12 лет                -1.0
# 24      «6+» - для детей старше 6 лет                -1.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 3460                   -1.0    -1.0       неизвестно     6.3
# 2394                   -1.0    -1.0       неизвестно     5.9
# 5197                   -1.0    -1.0       неизвестно     7.3
# 3459                   -1.0    -1.0       неизвестно     6.3
# 6832                   -1.0    -1.0       неизвестно     6.8
# 2393                   -1.0    -1.0       неизвестно     5.9
# 4398                   -1.0    -1.0       неизвестно     6.6
# 3902                   -1.0    -1.0       неизвестно     6.7
# 5303                   -1.0    -1.0       неизвестно     6.9
# 87                     -1.0    -1.0       неизвестно     7.8
# 70                     -1.0    -1.0       неизвестно     7.0
# 43                     -1.0    -1.0       неизвестно       0
# 24                     -1.0    -1.0       неизвестно     7.7
#
#                          genres    box_office         country
# 3460    боевик,комедия,криминал 85,616,378.36             США
# 2394       мюзикл,фэнтези,драма  50,987,664.1             США
# 5197     фэнтези,боевик,комедия          -1.0             США
# 3459    боевик,комедия,криминал          -1.0             США
# 6832  ужасы,триллер,приключения          -1.0  Великобритания
# 2393       мюзикл,фэнтези,драма          -1.0             США
# 4398       боевик,триллер,драма          -1.0  Великобритания
# 3902          мелодрама,комедия          -1.0             США
# 5303          мелодрама,комедия          -1.0             США
# 87                драма,комедия          -1.0            СССР
# 70              триллер,военный          -1.0            СССР
# 43                   неизвестно          -1.0             США
# 24                      комедия          -1.0            СССР

# %% [markdown]
# Дубликаты в этой колонке в основном связаны с тем, что ими являются фильмы, выпущенные одним режиссером, часто очень известным.

# %% [markdown]
# Удаление пробелов и прочих знаков:

# %%
data['director'] = data['director'].str.strip().str.strip(',').str.strip('_').str.strip('.').str.strip('  ')  
print(data['director'].duplicated().sum())
# Out:
# 2161

# %% [markdown]
# ####  Колонка age_restriction

# %% [markdown]
# Поиск уникальных имен, подсчет дубликатов:

# %%
age_unique = data['age_restriction'].sort_values().unique()
print('Длина списка уникальных имен',len(age_unique))
print('Количество дубликатов в колонке: ',data['age_restriction'].duplicated().sum())
print(age_unique)
# Out:
# Длина списка уникальных имен 5
# Количество дубликатов в колонке:  6959
# ['«0+» - для любой зрительской аудитории'
#  '«12+» - для детей старше 12 лет' '«16+» - для детей старше 16 лет'
#  '«18+» - запрещено для детей' '«6+» - для детей старше 6 лет']

# %% [markdown]
# Большое количество дубликатов объясняется количеством уникальных имен в этой колонке.

# %% [markdown]
# ####  Колонка financing_source

# %%
print(data['financing_source'].unique())
print('Количество дубликатов в колонке: ',data['financing_source'].duplicated().sum())
# Out:
# ['Фонд кино' 'неизвестно' 'Министерство культуры'
#  'Министерство культуры, Фонд кино']
# Количество дубликатов в колонке:  6960

# %% [markdown]
# ### Общая проблема  категориальных колонок

# %% [markdown]
# Помимо пробелов слева и множества посторонних символов в виде тире, кавычек, точек с запятой, я заметил, что категориальные данные сильно перегружены словами и их не мешало бы раздробить на более четкие группы, чтобы они отвечали понятию категориальных данных. Особенно это касается колонок с названиями жанров, стран, директоров, а также названий фильмов.

# %% [markdown]
# ### Изучение колонок с количественными данными

# %% [markdown]
# #### Колонка box_office

# %%
#напишем вспомогательную функцию для определения границ разброса значений
def get_swipe_range(dataset):
    
    median = pd.DataFrame.median(dataset)
    mean = pd.DataFrame.mean(dataset)
    min_value =  pd.DataFrame.min(dataset)
    max_value = pd.DataFrame.max(dataset)
    quartile_1 = pd.DataFrame(dataset).quantile(0.25,numeric_only=False)
    quartile_3 = pd.DataFrame(dataset).quantile(0.75,numeric_only=False)
    # Interquartile range
    iqr = round(quartile_3-quartile_1,2)
    #Вычисление границ размаха
    left_swipe_value = round(quartile_1-1.5*iqr,2)
    right_swipe_value = round(quartile_3+1.5*iqr,2)    
    print('Границы разброса значений для колонки:',dataset.name)         
    print('Левое значение: %s' % left_swipe_value.to_string())
    print('Правое значение: %s' % right_swipe_value.to_string())

# %% [markdown]
# Создание диаграммы  размаха кассовых сборов и вывод статистики:

# %%
boxplot_data = data.query('box_office!=-1')
display(boxplot_data['box_office'].describe())
get_swipe_range(boxplot_data['box_office']) 
fig,axes = plt.subplots(figsize=(10,10))
flierprops = dict(marker='o', markerfacecolor='green', markersize=10,linestyle='none')
medianprops = dict(linestyle='-.', linewidth=2.5, color='firebrick')
boxplot_data.boxplot('box_office', grid=True, flierprops=flierprops, medianprops=medianprops)
axes.set_ylim(0,90000000)
display(boxplot_data[boxplot_data['box_office']==0].shape[0])
# Out:
# count                3,158.0
# mean     76,478,696.16121912
# std     240,353,122.82324007
# min                      0.0
# 25%                 86,239.0
# 50%             2,327,987.55
# 75%           23,979,671.025
# max         3,073,568,690.79
# Name: box_office, dtype: float64
# Границы разброса значений для колонки: box_office
# Левое значение: box_office   -35,753,909.03
# Правое значение: box_office   59,819,819.06
# 24

# %% [markdown]
# По базе данных из 3134 значений установлено, что среднее значение прибыли от проката равно  77,064 тыс. рублей, медианное значение равно 2,409 тыс.рублей. Такое большое отклонение вызвано спецификой кинобизнеса, когда одни фильмы могут иметь оглушительный кассовый успех. а другие провалиться в прокате. Например, максимальные кассовые сборы имеет лента "Холоп" (чуть более 3 млрд. рублей), а минимальные значения близки к нулю. Это видно также по величине среднеквадратичного отклонения в размере 241,178 тыс.рублей.

# %% [markdown]
# #### Колонка ratings

# %% [markdown]
# Вывод уникальных имен:

# %%
ratings_unique = data['ratings'].unique()
print(ratings_unique)
# Out:
# ['6.8' '7.5' '7.6' '6.5' '6.6' '8.3' '6.7' '6.9' '8.0' '7.9' '7.1' '7.7'
#  '5.8' '6.2' '6.1' '7.2' '7.0' 0 '6.3' '7.4' '8.2' '5.9' '6.4' '5.6' '7.3'
#  '7.8' '4.4' '5.7' '5.5' '6.0' '4.7' '5.4' '5.2' '5.3' '64%' '4.1' '2.9'
#  '5.1' '4.6' '4.8' '4.9' '3.0' '8.5' '3.2' '3.1' '2.1' '3.7' '4.5' '8.1'
#  '5.0' '3.9' '4.0' '3.8' '4.2' '4.3' '2.5' '3.4' '2.8' '8.4' '3.5' '1.5'
#  '3.3' '8.6' '1.0' '88%' '1.6' '83%' '2.6' '94%' '3.6' '90%' '8.8' '79%'
#  '1.4' '89%' '19%' '98%' '9.2' '1.2' '2.7' '1.9' '2.4' '99%' '28%' '8.7'
#  '91%' '9.1' '97%' '8.9' '62%' '9.0' '1.7' '1.1' '1.8' '1.3']

# %% [markdown]
# Эта колонка содержит значения типов string  и int. Кроме того, некоторые значения указаны в процентах. Чтобы привести все значения в тип float сначала приведу колонку в тип строки, чтобы заменить значения int на string, затем уберу % там, где он есть. Затем приведу всю колонку в тип float и для значений больше 10 проведу деление на 10:

# %%
data['ratings'] = data['ratings'].astype('string')
data.loc[data['ratings'].str.contains('%'),['ratings']] = data['ratings'].apply(lambda x:(x[:-1]))
data['ratings'] = data['ratings'].astype('float')
data.loc[data['ratings']>10,['ratings']] = data['ratings']/10
print(data['ratings'].unique())
# Out:
# [6.8 7.5 7.6 6.5 6.6 8.3 6.7 6.9 8.  7.9 7.1 7.7 5.8 6.2 6.1 7.2 7.  0.
#  6.3 7.4 8.2 5.9 6.4 5.6 7.3 7.8 4.4 5.7 5.5 6.  4.7 5.4 5.2 5.3 4.1 2.9
#  5.1 4.6 4.8 4.9 3.  8.5 3.2 3.1 2.1 3.7 4.5 8.1 5.  3.9 4.  3.8 4.2 4.3
#  2.5 3.4 2.8 8.4 3.5 1.5 3.3 8.6 1.  8.8 1.6 2.6 9.4 3.6 9.  1.4 8.9 1.9
#  9.8 9.2 1.2 2.7 2.4 9.9 8.7 9.1 9.7 1.7 1.1 1.8 1.3]

# %% [markdown]
# Вывод статистики по колонке рейтингов и строительство диаграммы размаха:

# %%
display(data['ratings'].describe())
get_swipe_range(data['ratings']) 
display(data[data['ratings']==0].shape[0])
fig,axes = plt.subplots(figsize=(10,10))
flierprops = dict(marker='o', markerfacecolor='green', markersize=10,linestyle='none')
medianprops = dict(linestyle='-.', linewidth=2.5, color='firebrick')
data.boxplot('ratings', grid=True, flierprops=flierprops, medianprops=medianprops)
plt.show()
# Out:
# count              6,964.0
# mean    5.5733486502010345
# std     2.4607478208135354
# min                    0.0
# 25%                    5.3
# 50%                    6.4
# 75%                    7.1
# max                    9.9
# Name: ratings, dtype: float64
# Границы разброса значений для колонки: ratings
# Левое значение: ratings   2.6
# Правое значение: ratings   9.8
# 960

# %% [markdown]
# Оценка возможности среза датафрейма для исследования по этой колонке:

# %%
print(data.query('2.6<=ratings<=9.8').shape[0]/data.shape[0])
# Out:
# 0.8574095347501436

# %% [markdown]
# Средний рейтинг фильмов в базе данных составляет 5.5, а медианный равен 6.4. У четверти фильмов в базе данных рейтинг больше 7.1. Благоприятный диапазон для избавления от выбросов составляет 2.6-9.8

# %%
#Вывод информации о пропусках
missing_values_tab(data)
data.info()
# Out:
# Ваш датафрейм содержит 17 колонок и 6964 строк.
#
# Он имеет  0 колонок с пропущенными значениями.
# Empty DataFrame
# Columns: [Пропущенные значения, % от всех значений, Тип данных]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6964 entries, 7456 to 1080
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  6964 non-null   object
#  1   puNumber               6964 non-null   int64
#  2   show_start_date        6964 non-null   datetime64[ns, UTC]
#  3   type                   6964 non-null   object
#  4   film_studio            6964 non-null   object
#  5   production_country     6964 non-null   object
#  6   director               6964 non-null   object
#  7   producer               6964 non-null   object
#  8   age_restriction        6964 non-null   object
#  9   refundable_support     6964 non-null   float64
#  10  nonrefundable_support  6964 non-null   float64
#  11  budget                 6964 non-null   float64
#  12  financing_source       6964 non-null   object
#  13  ratings                6964 non-null   float64
#  14  genres                 6964 non-null   object
#  15  box_office             6964 non-null   float64
#  16  country                6964 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(5), int64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# Сравнение размеров оригинального и обработанного датасетов:

# %%
print(6964/7486)
# Out:
# 0.930269837029121

# %% [markdown]
# Обработанный датасет стал на 7% меньше первоначального. По результатам его осмотра, он кажется готовым к изучению.

# %% [markdown]
# ### Добавление  новых колонок <a class="anchor" id="id_2f"></a>

# %% [markdown]
# #### Создание колонки с годом проката

# %%
data['show_year'] = data['show_start_date'].dt.year

# %% [markdown]
# #### Создание колонки с главным жанром

# %%
def main_genre(genre):    
        #разбиваем строку жанров на слова по запятой и сохраняем в список
        temp = str(genre).split(',')        
        #выбираем первое слово
        new_name = temp[0]
        return new_name

# %% [markdown]
# Применение функции к колонке:

# %%
data['main_genre'] = data['genres'].apply(main_genre)
display(data[['genres','main_genre']])
# Out:
#                          genres      main_genre
# 7456                    комедия         комедия
# 5653                спорт,драма           спорт
# 6820    фантастика,боевик,драма      фантастика
# 6549       драма,военный,боевик           драма
# 3488     фэнтези,боевик,комедия         фэнтези
# ...                         ...             ...
# 1797                 неизвестно      неизвестно
# 7009    драма,криминал,детектив           драма
# 5074    драма,военный,биография           драма
# 5037  мультфильм,фэнтези,боевик      мультфильм
# 1080    документальный,семейный  документальный
#
# [6964 rows x 2 columns]

# %% [markdown]
# #### Создание колонки с главным режиссером

# %% [markdown]
# Для создания этой колонки применю ту же функцию, что и в случае с жанрами:

# %%
data['main_director'] = data['director'].apply(main_genre)

# %% [markdown]
# Проверка:

# %%
display(data[['director','main_director']])
# Out:
#                             director    main_director
# 7456                       К.Шипенко        К.Шипенко
# 5653                    А.Мегердичев     А.Мегердичев
# 6820         Джо Руссо, Энтони Руссо        Джо Руссо
# 6549                       А.Сидоров        А.Сидоров
# 3488  Йоаким Реннинг, Эспен Сандберг   Йоаким Реннинг
# ...                              ...              ...
# 1797                         С.Юзеев          С.Юзеев
# 7009                      П.Левченко       П.Левченко
# 5074                 Мартин Скорсезе  Мартин Скорсезе
# 5037                     Дженнифер Ю      Дженнифер Ю
# 1080                  Доминик Тьелль   Доминик Тьелль
#
# [6964 rows x 2 columns]

# %%
main_director_unique = data['main_director'].unique()
#print_long_lists(main_director_unique)

# %% [markdown]
# ### Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %% [markdown]
# гос.поддержка = refundable_support + nonrefundable_support
# budget = гос.поддержка + иные источники

# %%
temp_df = data.query('refundable_support!=(-1) and  nonrefundable_support!=(-1)')
temp_df['gov_help_%'] =round( (temp_df['refundable_support'] + temp_df['nonrefundable_support'])/temp_df['budget']*100,2)
display(temp_df[['budget','refundable_support','nonrefundable_support','gov_help_%']])
data = data.join(temp_df['gov_help_%'])
display(data[['budget','refundable_support','nonrefundable_support','gov_help_%']])
# Out:
#             budget  refundable_support  nonrefundable_support  gov_help_%
# 7456 160,000,000.0        25,000,000.0           35,000,000.0        37.5
# 5653 590,192,191.0                 0.0          400,000,000.0       67.77
# 6549 563,784,717.0        60,000,000.0          120,000,000.0       31.93
# 5505 352,477,575.0        50,000,000.0           50,000,000.0       28.37
# 5708 148,585,222.0        25,000,000.0           60,000,000.0       57.21
# ...            ...                 ...                    ...         ...
# 3711  18,706,080.0                 0.0           11,520,000.0       61.58
# 2800  41,998,984.0                 0.0           25,000,000.0       59.53
# 3337  61,000,000.0                 0.0           10,000,000.0       16.39
# 7344  47,734,050.0                 0.0           30,000,000.0       62.85
# 7009  60,668,576.0                 0.0           25,000,000.0       41.21
#
# [332 rows x 4 columns]
#             budget  refundable_support  nonrefundable_support  gov_help_%
# 7456 160,000,000.0        25,000,000.0           35,000,000.0        37.5
# 5653 590,192,191.0                 0.0          400,000,000.0       67.77
# 6820          -1.0                -1.0                   -1.0         NaN
# 6549 563,784,717.0        60,000,000.0          120,000,000.0       31.93
# 3488          -1.0                -1.0                   -1.0         NaN
# ...            ...                 ...                    ...         ...
# 1797          -1.0                -1.0                   -1.0         NaN
# 7009  60,668,576.0                 0.0           25,000,000.0       41.21
# 5074          -1.0                -1.0                   -1.0         NaN
# 5037          -1.0                -1.0                   -1.0         NaN
# 1080          -1.0                -1.0                   -1.0         NaN
#
# [6964 rows x 4 columns]

# %%
#заполнение пропусков значением -1
data['gov_help_%'].fillna(-1,inplace=True)

# %% [markdown]
# ### Вывод по предобработке данных  <a class="anchor" id="id_2g"></a>

# %% [markdown]
# **Вывод.**
# В результате предобработки данных были внесены изменения в тип данных некоторых колонок, исправлены пропущенные значения, проведена работа с явными и неявными дубликатами, а также создано несколько вспомогательных колонок. Пропущенные значения в денежных колонках были исправлены на значение "-1", что позволит в будущем по необходимости включать/выключать этот флаг. В результате скорректированный датасет стал на 7% меньше оригинального.

# %% [markdown]
# ## Исследовательский анализ данных <a class="anchor" id="id_3"></a>

# %% [markdown]
# ### Создание датасета для работы

# %% [markdown]
# Создание датасета с фильмами с известными сборами, т.е где box_office>=0 а также вспомогательных колонок кассовых сборов в тысячах и миллионах рублей.

# %%
#датафрейм с фильмами, для которых известны сборы
filtered_df = data.query('box_office>=0')
#Переведем колонку box_office в тыс. руб
filtered_df['revenue_1000'] = filtered_df['box_office']/1000
#Создание колонки с млн. рублей
filtered_df['revenue_mln'] = filtered_df['box_office']/1000000

# %% [markdown]
# ### Расчет доли фильмов с указанной информацией о сборах <a class="anchor" id="id_3a"></a>

# %%
#Создание группировки по годам и кол-ву фильмов
tmp_0 = data.pivot_table(index='show_year',values='box_office',aggfunc='count').reset_index()
#Создание отсортированного списка годов проката
list_of_years = data['show_year'].sort_values().unique()
ratios = []
# Цикл для каждого года вычисляет отношение известных фильмов к общему количеству фильмов за тот год
# и помещает округленные значения в процентах в список
for year in list_of_years:    
        ratios.append( round(data[(data['show_year']==year)
               & (data['box_office']!=(-1))].shape[0]/data[data['show_year']==year].shape[0]*100,2))
# Создание Series из списка
ratio_series = pd.Series(ratios,name='% известных')
#Приклеивание series к датафрейму справа
tmp_0 = pd.concat([tmp_0,ratio_series],axis=1)
tmp_0 = tmp_0.rename(columns={'show_year':'Год проката','box_office':'Количество фильмов'})
display(tmp_0)
# Out:
#    Год проката  Количество фильмов  % известных
# 0         2010                 801        13.11
# 1         2011                 532        20.49
# 2         2012                 536        23.88
# 3         2013                 603        30.51
# 4         2014                 755        36.95
# 5         2015                 679        68.48
# 6         2016                 750        70.13
# 7         2017                 498        71.69
# 8         2018                 886        53.61
# 9         2019                 924        57.36

# %% [markdown]
# Как видно из таблицы процент фильмов с известными кассовыми сборами растет из года в год. Падение значений в 2018 и 2019 годах можно объяснить эпидемией ковид-19, когда были закрыты кинотеатры для показа.

# %% [markdown]
# ### Диаграмма количества фильмов по годам  <a class="anchor" id="id_3b"></a>

# %%
fig,axes = plt.subplots(1,2,figsize=(20,5),sharey=False)
# Диаграмма всех фильмов
data.groupby('show_year')['title'].count().plot.bar(ax=axes[0], edgecolor='black',grid=True,colormap='Accent')
#Диаграмма  фильмов с известными сборами
filtered_df.groupby('show_year')['title'].count().plot.bar(ax=axes[1], edgecolor='black',grid=True, colormap='Dark2')
axes[0].set_title('Количество всех фильмов по годам')
axes[0].set_xlabel("Год премьеры фильма")
axes[0].set_ylabel("Количество фильмов в году")
axes[1].set_title('Количество фильмов по годам c известными сборами')
axes[1].set_xlabel("Год премьеры фильма")
axes[1].set_ylabel("Количество фильмов в году")
#Нанесение надписей
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
for index in range(len(axes)):
    rects = axes[index].patches
    for rect in rects:    
            height = rect.get_height()    
            axes[index].text(rect.get_x() + rect.get_width() / 2, height + 2, round(height,1),
            ha="center", va="bottom",weight='bold',size='large',c=color[0])
plt.show()
#print(axes)

# %% [markdown]
# По прошествии десяти лет, количество фильмов в базе данных увеличился всего на 123 единицы. Но количество фильмов с известными сборами увеличилось в 5 раз, а их доля в общем количестве фильмов увеличилась с 13% до 57%, т.е более чем в 4 раза.

# %% [markdown]
# ### Диаграмма средних сборов по годам <a class="anchor" id="id_3с"></a>

# %%
a = filtered_df.query('2014<=show_year<=2019').pivot_table(index='show_year',values='revenue_1000')
a1 = filtered_df.query('2010<=show_year<=2013').pivot_table(index='show_year',values='revenue_1000')
a1_xlabels = [2010,2011,2012,2013]
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(1, 2, 2)
#Постороение столбиковой диаграммы ср. сборов за 2014-2019
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
ax1.bar(x= a.index.values,height = a['revenue_1000'],color=color,ec='black')
#Постороение столбиковой диаграммы ср. сборов за 2010-2013
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
ax2.bar(a1_xlabels, a1['revenue_1000'],color=color,ec='black',tick_label=a1_xlabels)
#Сеточка
ax1.grid(); ax2.grid()
#Оформление
ax2.set_title('Средние сборы за 2010-2013 года, тыс.руб') 
ax2.set_xlabel('Год') 
ax2.set_ylabel('Средние сборы,тыс.рублей')
ax1.set_title('Средние сборы за 2014-2019 года, тыс.руб') 
ax1.set_xlabel('Год') 
ax1.set_ylabel('Средние сборы,тыс.рублей')
# Нанесение значений
rects=ax1.patches
rects2=ax2.patches
for rect in rects:
    color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
    height = rect.get_height()    
    ax1.text(rect.get_x() + rect.get_width() / 2, height + 2, round(height,1),
        ha="center", va="bottom",weight='bold',size='large',c=color[0])
for rect in rects2:
    color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
    height = rect.get_height()
    ax2.text(rect.get_x() + rect.get_width() / 2, height, round(height,1),
        ha="center", va="bottom",weight='bold',size='large',c=color[0])
plt.show()

# %% [markdown]
# Наполняемость базы открытыми данными о сборах позволило уточнить динамику и величины средних и медианных сборов фильмов по годам.

# %% [markdown]
# ###  Диаграмма медианных сборов по годам <a class="anchor" id="id_3d"></a>

# %%
#Данные для диаграмм
a = filtered_df.query('2014<=show_year<=21019').pivot_table(index='show_year',values='revenue_1000',aggfunc='median')
a1 = filtered_df.query('2010<=show_year<=2013').pivot_table(index='show_year',values='revenue_1000',aggfunc='median')
a1_xlabels = [2010,2011,2012,2013]

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(1, 2, 2)
#Построение столбиковой диаграммы ср. сборов за 2014-2019
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
ax1.bar(x= a.index.values,height = a['revenue_1000'],color=color,ec='black')
#Построение столбиковой диаграммы ср. сборов за 2010-2013
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
ax2.bar(a1_xlabels, a1['revenue_1000'],color=color,ec='black',tick_label=a1_xlabels)
#Сеточка
ax1.grid(); ax2.grid()
#Оформление
ax2.set_title('Медианные сборы за 2010-2013 года, тыс.руб') 
ax2.set_xlabel('Год') 
ax2.set_ylabel('Медианные сборы,тыс.рублей')
ax1.set_title('Медианные сборы за 2014-2019 года, тыс.руб') 
ax1.set_xlabel('Год') 
ax1.set_ylabel('Медианные сборы,тыс.рублей')
# Нанесение значений
rects=ax1.patches
rects2=ax2.patches
for rect in rects:    
    height = rect.get_height()    
    ax1.text(rect.get_x() + rect.get_width() / 2, height + 2, round(height,1),
        ha="center", va="bottom",weight='bold',size='large')
for rect in rects2:   
    height = rect.get_height()
    ax2.text(rect.get_x() + rect.get_width() / 2, height, round(height,1),
        ha="center", va="bottom",weight='bold',size='large')
plt.show()

# %% [markdown]
# Построение сводной таблицы медианных и средних кассовых сборов:

# %%
df = filtered_df.pivot_table(index='show_year',values='revenue_1000',aggfunc=['median','mean']).round(2)
df = df.droplevel(level=1,axis=1)
df ['div']  = round(df['mean']/df['median'],1)
df = df.rename(columns={'mean':'Средние кассовые сборы,тр','median':'Медианные кассовые сборы,тр'})
df.index.name = 'Год проката'
display(df)
display(filtered_df[filtered_df['show_year'] == 2013].sort_values('box_office',ascending=False)[['title','box_office']].head())
display(filtered_df[filtered_df['show_year'] == 2014].sort_values('box_office',ascending=False)[['title','box_office']].head())
display(filtered_df[(filtered_df['show_year'] == 2014) & (filtered_df['box_office']>10000000)]['title'].count())
# Out:
#              Медианные кассовые сборы,тр  Средние кассовые сборы,тр     div
# Год проката
# 2010                                 1.7                      23.13    13.6
# 2011                                 3.0                     129.38    43.1
# 2012                                5.66                      54.34     9.6
# 2013                                3.52                     161.95    46.0
# 2014                               18.16                  26,684.42 1,469.4
# 2015                            4,920.93                  84,940.57    17.3
# 2016                            3,846.68                  91,000.57    23.7
# 2017                            9,968.34                 136,032.79    13.6
# 2018                             8,891.1                 104,565.06    11.8
# 2019                             4,627.8                  91,369.26    19.7
#                             title   box_office
# 1498                    Невидимки 19,957,031.5
# 1256              Великая красота  4,321,638.0
# 1743  Иван Царевич и Серый Волк 2  1,081,797.0
# 791            Что творят мужчины    779,027.6
# 1281                Пока еще жива    365,353.6
#                                                   title      box_office
# 1982                                        Седьмой сын 1,016,410,635.3
# 2383                                 Исход: Цари и боги   970,276,839.8
# 2410  Пятьдесят оттенков серого /По произведению Э.Л...   963,728,813.5
# 2406                         Kingsman: Секретная служба   566,924,625.9
# 2384                      Ночь в музее: Секрет гробницы   488,223,744.1
# 33

# %% [markdown]
# В результате сравнения медианных и средних показателей кассовых сборов по годам видно, что аномальным является 2014 год, где среднее больше медианного в 1469 раз, что может говорить о том, что в том году вышло много фильмов, которые собрали хорошую кассу(из 279 фильмов 33 собрали больша 100 млн) и было много фильмов с низкими сборами.

# %% [markdown]
# ### Диаграмма самых кассовых фильмов <a class="anchor" id="id_3e"></a>

# %%
barh_data =  filtered_df.groupby('title')['revenue_mln'].sum().sort_values().tail(10)
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
fig = plt.figure(figsize=(14,5))
ax = fig.add_subplot()
ax.barh( barh_data.index.values, barh_data,color=color[0])
#Оформление
ax.set_title('Десять самых кассовых фильмов в российском прокате,млн.руб',size=16) 
ax.set_xlabel('Сборы,млн.руб')
#ax.yaxis.set_tick_params(labelsize=20)
ax.tick_params(axis='both',labelsize=16)
#Надписи
rects = ax.patches
for bar in rects:    
    width = bar.get_width()    
    ax.text(width/2, bar.get_y()+0.2, str(round(width, 2)),fontsize='12', weight='bold', color='black') 
plt.show()

# %% [markdown]
# ### Диаграмма динамики кассовых сборов по годам <a class="anchor" id="id_3f"></a>

# %%
#Данные для диаграмм
a = filtered_df.query('2010<=show_year<=2013').groupby('show_year')['revenue_mln'].sum()
a1 = filtered_df.query('2014<=show_year<=2019').groupby('show_year')['revenue_mln'].sum()
a_xlabels = [2010,2011,2012,2013]

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(1, 2, 2)
#Построение столбиковой диаграммы ср. сборов за 2014-2019
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
ax1.bar(x= a.index.values,height = a,color=color,ec='black',tick_label=a_xlabels)
#Построение столбиковой диаграммы ср. сборов за 2010-2013
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
ax2.bar(a1.index.values, a1,color=color,ec='black')
#Сеточка
ax1.grid(); ax2.grid()
#Оформление
ax2.set_title('Кассовые сборы фильмов 2014-2019гг, млн.руб')  
ax2.set_xlabel('Год') 
ax2.set_ylabel('Кассовые сборы,млн.рублей')
ax1.set_title('Кассовые сборы фильмов 2010-2013гг, млн.руб') 
ax1.set_xlabel('Год') 
ax1.set_ylabel('Кассовые сборы,млн.рублей')
# Нанесение значений
rects=ax1.patches
rects2=ax2.patches
for rect in rects:    
    height = rect.get_height()    
    ax1.text(rect.get_x() + rect.get_width() / 2, height + 2, round(height,1),
        ha="center", va="bottom",weight='bold',size='large')
for rect in rects2:   
    height = rect.get_height()
    ax2.text(rect.get_x() + rect.get_width() / 2, height, round(height,1),
        ha="center", va="bottom",weight='bold',size='large')
plt.show()

# %% [markdown]
# Из диаграммы выше видно, что минимальные сборы были в 2010 году - всего 2.4 млн рублей, а максимальные сборы были в 2018 году и составили примерно 49,7 млрд рублей.

# %% [markdown]
# ### Влияние возраста аудитории <a class="anchor" id="id_3g"></a>

# %% [raw]
# Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# Вывод статистики:

# %%
tmp_data = filtered_df.query('2015<=show_year<=2019').pivot_table(
    index='age_restriction',values='revenue_1000',aggfunc ='mean')
display(tmp_data.describe().round(2))
# Out:
#        revenue_1000
# count           5.0
# mean     101,004.57
# std       74,104.99
# min        8,890.96
# 25%       51,464.16
# 50%       94,453.09
# 75%      174,193.81
# max      176,020.85

# %% [markdown]
# ### Диаграмма медианных и средних сборов по зрительским категориям за 2015-2019 годы. <a class="anchor" id="id_3h"></a>

# %%
fig,axes = plt.subplots(2,1,figsize=(10,8))
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
# Диаграмма медианных сборов
age_median_revenue = filtered_df.query('2015<=show_year<=2019').pivot_table(
    index='age_restriction',values='revenue_1000',aggfunc ='median').plot(
    kind='barh',ax=axes[0],edgecolor='black',grid=True,color = color,  
    title = 'Медианные сборы, тыс.руб', xlabel = 'Возрастная категория',legend=False)
# Диаграмма средних сборов
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
age_mean_revenue = filtered_df.query('2015<=show_year<=2019').pivot_table(
    index='age_restriction',values='revenue_mln',aggfunc ='mean').plot(
    kind='barh',ax=axes[1],edgecolor='black',grid=True,color = color,
    title = 'Средние сборы, млн.руб',  xlabel = 'Возрастная категория',legend=False)
plt.subplots_adjust(hspace=0.2)   # регулирование промежутка между графиками
# Надписи на первом графике
rects = axes[0].patches
for bar in rects:    
    width = bar.get_width()    
    axes[0].text(width+0.5, bar.get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',ha='right',va='center') 
#Надписи на втором графике
rects = axes[1].patches
for bar in rects:    
    width = bar.get_width()    
    axes[1].text(width+0.5, bar.get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',ha='right',va='center') 
plt.show()

# %% [markdown]
# Из диаграммы видно, что фильмы 6+ и 12+ пользуются большой популярностью. В обоих случаях видно, что медианные сборы сильно уступают средним сборам, что говорит о том, что в каждой категории есть фильмы, которые имели оглушительный кассовый успех.

# %% [markdown]
# ### Построение диаграммы количества выпущенных фильмов по категориям зрителей.

# %%
barh_data_1 = data.groupby('age_restriction')['box_office'].count().sort_values()
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
fig = plt.figure(figsize=(14,3))
ax = fig.add_subplot()
ax.barh( barh_data_1.index.values, barh_data_1,color=color[0])
#Оформление
ax.set_title('Количество фильмов по категориям зрителей ',size=16) 
ax.set_xlabel('Количество')
#ax.yaxis.set_tick_params(labelsize=20)
ax.tick_params(axis='both',labelsize=16)
#Надписи
rects = ax.patches
for bar in rects:    
    width = bar.get_width()    
    ax.text(width, bar.get_y()+0.2, str(round(width, 2)),fontsize='large', style='oblique',
            weight='bold', color='k',ha='left') 
plt.show()

# %% [markdown]
# ### Диаграмма кассовых сборов по категориям за 2010-2019 годы <a class="anchor" id="id_3j"></a>

# %%
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) ]
fig,axes = plt.subplots(figsize=(10,5))
bar = filtered_df.groupby('age_restriction')['revenue_mln'].sum().sort_values().plot(
    kind = 'barh', ylabel = 'Сборы', xlabel='', color = color, title = 'Кассовые сборы, в млн.руб')
rects = axes.patches
for index in range(len(rects)):    
    if index==0:
        width = rects[index].get_width()
        axes.text(width+0.5, rects[index].get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',va='center')
    else:
            width = rects[index].get_width()    
            axes.text(width+0.5, rects[index].get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',va='center',ha='right')    
plt.show()

# %% [markdown]
# Из трех вышестоящих графиков видно, что, хотя средние сборы фильмов 16+ значительно уступают средним сборам фильмов 6+ и 12+, за счет того, их количество значительно больше, они лидируют по кассовым сборам. Также можно сделать вывод, что зрительская категория  влияет на кассовые сборы фильмов. Фильмы, ориентированные на детскую и подростковую аудиторию приносят значительно больше кассовых сборов. Особенно можно выделить фильмы для категории 6+, которые обладают, если так можно выразиться, отличным КПД.

# %%
#Вывод информации о самом кассовом фильме в каждой категории
tmp  = pd.DataFrame()
for category in age_unique:
    row = filtered_df[
        filtered_df['age_restriction']==category].sort_values(
        'box_office',ascending=False).head(1)[
        ['age_restriction','title','show_year','production_country','box_office','budget','refundable_support','nonrefundable_support']]
    tmp = pd.concat([tmp,row])
display(tmp.sort_values('box_office',ascending=False))
print('\n','-'*45,'Фильмы с участием государства','-'*45)
#Вывод информации о самом кассовом фильме в каждой категории для с участием государства
tmp  = pd.DataFrame()
for category in age_unique:
    row = filtered_df[
        (filtered_df['age_restriction']==category) 
    & (filtered_df['refundable_support']!=(-1))].sort_values(
        'box_office',ascending=False).head(1)[
        ['age_restriction','title','show_year','production_country','box_office','budget','refundable_support','nonrefundable_support']]
    tmp = pd.concat([tmp,row])
display(tmp.sort_values('box_office',ascending=False))
# Out:
#                              age_restriction  \
# 7456         «12+» - для детей старше 12 лет
# 5653           «6+» - для детей старше 6 лет
# 6820         «16+» - для детей старше 16 лет
# 7258             «18+» - запрещено для детей
# 2005  «0+» - для любой зрительской аудитории
#
#                                   title  show_year production_country  \
# 7456                              Холоп       2019             Россия
# 5653                     Движение вверх       2017             Россия
# 6820                    Мстители: Финал       2019                США
# 7258                             Джокер       2019       США - Канада
# 2005  Снежная Королева 2: Перезаморозка       2014             Россия
#
#            box_office        budget  refundable_support  nonrefundable_support
# 7456 3,073,568,690.79 160,000,000.0        25,000,000.0           35,000,000.0
# 5653  2,779,686,144.0 590,192,191.0                 0.0          400,000,000.0
# 6820 2,576,613,776.83          -1.0                -1.0                   -1.0
# 7258 1,890,368,076.47          -1.0                -1.0                   -1.0
# 2005    313,489,846.5 252,489,571.0        30,000,000.0           40,000,000.0
#  --------------------------------------------- Фильмы с участием государства ---------------------------------------------
#                              age_restriction  \
# 7456         «12+» - для детей старше 12 лет
# 5653           «6+» - для детей старше 6 лет
# 2701         «16+» - для детей старше 16 лет
# 2005  «0+» - для любой зрительской аудитории
# 5449             «18+» - запрещено для детей
#
#                                   title  show_year production_country  \
# 7456                              Холоп       2019             Россия
# 5653                     Движение вверх       2017             Россия
# 2701                  Самый Лучший День       2015             Россия
# 2005  Снежная Королева 2: Перезаморозка       2014             Россия
# 5449    Про любовь. Только для взрослых       2017             Россия
#
#            box_office        budget  refundable_support  nonrefundable_support
# 7456 3,073,568,690.79 160,000,000.0        25,000,000.0           35,000,000.0
# 5653  2,779,686,144.0 590,192,191.0                 0.0          400,000,000.0
# 2701    683,029,061.4 130,619,336.0        29,000,000.0           34,000,000.0
# 2005    313,489,846.5 252,489,571.0        30,000,000.0           40,000,000.0
# 5449    113,925,353.0  83,553,412.0                 0.0           30,000,000.0

# %%
# Функция для укорачивания имени категории
def new_age (row):
    if '-' in row:  
        temp = row.split('-')        
    return temp[0]       
            
filtered_df['age_group'] = filtered_df['age_restriction'].apply(new_age)
display(filtered_df[['age_restriction','age_group']])
# Out:
#                              age_restriction age_group
# 7456         «12+» - для детей старше 12 лет    «12+»
# 5653           «6+» - для детей старше 6 лет     «6+»
# 6820         «16+» - для детей старше 16 лет    «16+»
# 6549         «12+» - для детей старше 12 лет    «12+»
# 3488         «16+» - для детей старше 16 лет    «16+»
# ...                                      ...       ...
# 3994         «16+» - для детей старше 16 лет    «16+»
# 976          «12+» - для детей старше 12 лет    «12+»
# 2442  «0+» - для любой зрительской аудитории     «0+»
# 2037         «12+» - для детей старше 12 лет    «12+»
# 4790         «16+» - для детей старше 16 лет    «16+»
#
# [3158 rows x 2 columns]

# %% [markdown]
# ### Диаграмма медианных сборов для каждой зрительской категории по годам. <a class="anchor" id="id_3k"></a>

# %%
# Лист годов
years = filtered_df['show_year'].sort_values().unique()
cols = 2 # число колонок под вложенные графики
rows = 5 # число строчек под вложенные графики
count = 0
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(20,20))
for r in range(rows):
    for c in range(cols):            
            color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
            ax = filtered_df[filtered_df['show_year']==years[count]].pivot_table(
                index='age_group',values='revenue_1000', aggfunc ='median').sort_values('revenue_1000').plot(
                kind='barh',ax=axes[r,c], edgecolor='black',  color = color, grid=False,
                title = f'Медианные сборы, тыс.руб., {years[count]} год', xlabel = '',legend=False)
            #Убирание рамок вложенных графиков
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.spines['left'].set_visible(False)  
            #Нанесение значений
            rects = axes[r,c].patches                     
            for index in range(len(rects)):
                width = rects[index].get_width()
                t = axes[r,c].text(width+0.1, rects[index].get_y()+0.2, str(round(width, 2)),
                          fontsize='medium', weight='bold', color='black',va='center',ha='left')
            count+=1
plt.subplots_adjust(hspace=0.2,wspace=0.2)
plt.show()

# %% [markdown]
# Из серии графиков видно, что фильмы для всех зрителей 0+ до 2014 года включительно лидировали по медианным сборам, но затем наступил перелом и фильмы, которые имеют более четкую ориентированность на зрительские сегменты, заняли первые места.

# %% [markdown]
# ### Диаграмма средних сборов для каждой зрительской категории по годам. <a class="anchor" id="id_3l"></a>

# %%
years = filtered_df['show_year'].sort_values().unique()
cols = 2
rows = 5
count = 0
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(20,20))
#Построение графиков, отсортированных по возрастанию
for r in range(rows):
    for c in range(cols):            
            color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
            ax = filtered_df[filtered_df['show_year']==years[count]].pivot_table(
                index='age_group',values='revenue_1000', aggfunc ='mean').sort_values('revenue_1000').plot(
                kind='barh',ax=axes[r,c], edgecolor='black',  color = color, grid=False,
                title = f'Средние сборы, тыс.руб., {years[count]} год', xlabel = '',legend=False)
            #Убирание рамок вложенных графиков           
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.spines['left'].set_visible(False)
            #Нанесение надписей
            rects = axes[r,c].patches
            for index in range(len(rects)):
                width = rects[index].get_width()
                t = axes[r,c].text(width+0.1, rects[index].get_y()+0.2, str(round(width, 2)),
                          fontsize='medium', weight='bold', color='black',va='center',ha='left')
            count+=1
plt.subplots_adjust(hspace=0.2,wspace=0.2)
plt.show()

# %% [markdown]
# Если оценивать фильмы по средним сборам, то перелом случился еще раньше - в 2013 году и фильмы для детей и подростков прочно заняли первое и второе место. Здесь эффект сегментации аудитории выражен гораздо сильнее и видно, что фильмы с широким охватом не пользуются популярностью.

# %% [markdown]
# ### Вывод по разделу 2. <a class="anchor" id="id_3m"></a>

# %% [markdown]
# В результате проведения исследовательского анализа данных мною было подсчитано количество фильмов, выпущенных в российском прокате по каждому году и зрительской категории, оценена динамика их проката. Были определены суммы кассовых сборов фильмов, их средние медианные значения по каждому году, а также по каждой зрительской категории. Также были выявлены лучшие фильмы по кассовым сборам.

# %% [markdown]
# ## Исследование фильмов, которые получили государственную поддержку <a class="anchor" id="id_4"></a>

# %% [markdown]
# ### Cоздание датасета и колонок для работы:

# %%
data2 = data.query('budget!=(-1) and box_office>=0')
#Содание колонки с тыс. рублей
data2['revenue_1000'] = data2['box_office']/1000
#Создание колонки с млн. рублей
data2['revenue_mln'] = data2['box_office']/1000000
#Колонка с укороченной зрительской категорией
data2['age_group'] = data2['age_restriction'].apply(new_age)
#Колонка с общей суммой господдержки
data2['goverment'] = data['nonrefundable_support']+data2['refundable_support']

# %% [markdown]
# Проверка на то, все ли фильмы в этом датасете сняты при участии России и имеют ту или иную форму господдержки:

# %%
print(data2[data2['production_country'].str.contains('Россия')].shape[0]/data2.shape[0])
print(data2[data2['production_country'].str.contains('Россия') & (data2['goverment']!=0)].shape[0]/data2.shape[0])
print(data2.shape[0])
# Out:
# 1.0
# 1.0
# 318

# %% [markdown]
# Все 318 фильмов сняты при участии России.

# %% [markdown]
# ### Количество выпущенных фильмов по категориям <a class="anchor" id="id_4a"></a>

# %%
barh_data_2 = data2.groupby('age_group')['box_office'].count().sort_values()
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
fig = plt.figure(figsize=(14,3))
ax = fig.add_subplot()
ax.barh( barh_data_2.index.values, barh_data_2,color=color[0])
#Оформление
ax.set_title('Количество фильмов по категориям зрителей ',size=16) 
ax.set_xlabel('Количество')
#ax.yaxis.set_tick_params(labelsize=20)
ax.tick_params(axis='both',labelsize=16)
#Надписи
rects = ax.patches
for bar in rects:    
    width = bar.get_width()    
    ax.text(width, bar.get_y()+0.2, str(round(width, 2)),fontsize='large', style='oblique',
            weight='bold', color='k',ha='left') 
plt.show()

# %% [raw]
# Государство предпочитает вкладываться в фильмы, ориентированные на подрастающее поколение.

# %% [markdown]
# ### Cборы по категориям  <a class="anchor" id="id_4b"></a>

# %%
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) ]
fig,axes = plt.subplots(figsize=(10,5))
barh1_data_2 = data2.groupby('age_group')['revenue_mln'].sum().sort_values().plot(
    kind = 'bar', ylabel = 'Сборы', xlabel='', color = color, title = 'Кассовые сборы, в млн.руб')
rects = axes.patches
for rect in rects:    
    height = rect.get_height()    
    axes.text(rect.get_x() + rect.get_width() / 2, height + 2, round(height,1),
        ha="center", va="bottom",weight='bold',size='large',c='black')
plt.show()

# %% [raw]
# И такие фильмы приносят больше всего кассовых сборов.

# %% [markdown]
# ### Медианные и средние кассовые сборы по категориям зрителей

# %%
fig,axes = plt.subplots(2,1,figsize=(10,5))
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
# Диаграмма медианных сборов
gd_median_revenue = data2.pivot_table(
    index='age_group',values='revenue_1000',aggfunc ='median').plot(
    kind='barh',ax=axes[0],edgecolor='black',color = color,  
    title = 'Медианные сборы, тыс.руб', xlabel = 'Возрастная категория',legend=False)
axes[0].spines['top'].set_visible(False);axes[0].spines['right'].set_visible(False);
axes[0].spines['left'].set_visible(False)
# Диаграмма средних сборов
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
gd_mean_revenue = data2.pivot_table(
    index='age_group',values='revenue_mln',aggfunc ='mean').plot(
    kind='barh',ax=axes[1],edgecolor='black',color = color,
    title = 'Средние сборы, млн.руб',  xlabel = 'Возрастная категория',legend=False)
axes[1].spines['top'].set_visible(False);axes[1].spines['right'].set_visible(False);
axes[1].spines['left'].set_visible(False)  
# Надписи на первом графике
rects = axes[0].patches
for index in   range(len(rects)):    
    if index==3:
        width = rects[index].get_width()
        axes[0].text(width+0.5, rects[index].get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',va='center')
    else:
        width = rects[index].get_width()    
        axes[0].text(width, rects[index].get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',ha='right',va='center') 
#Надписи на втором графике
rects = axes[1].patches
for bar in rects:    
    width = bar.get_width()    
    axes[1].text(width, bar.get_y()+0.2, str(round(width, 2)),
                 fontsize='medium', weight='bold', color='black',ha='right',va='center')
plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
print(199.5/23.3)
print(206/66.5)
# Out:
# 8.562231759656653
# 3.0977443609022557

# %% [markdown]
# Можно сделать вывод, что фильмы для зрителей 6+ более предсказуемы в плане ожидаемых кассовых сборов, так как разрыв между этими двумя показателями составляет всего 3.Фильмы для всех зрителей также имеют такое свойство, но их выпустили всего 5 штук.

# %% [markdown]
# ### Бюджет и сборы

# %%
avg_budget = data2['budget'].mean()
avg_govhelp = data2['goverment'].mean()
print('Средний бюджет фильма: ',round(avg_budget))
print('Средний размер поддержки: ',round(avg_govhelp))
# Out:
# Средний бюджет фильма:  132006722
# Средний размер поддержки:  60726944

# %% [markdown]
# В среднем, господдержка составляет чуть больше половины бюджета фильмов.

# %% [markdown]
# ### Кассовые сборы на 1 рубль господдержки <a class="anchor" id="id_4c"></a>

# %%
data2['revenue_1rub'] = data2['box_office']/data2['goverment']
cols = 1
rows = 2
count = 0
barh_data_3 = data2.groupby('title')['revenue_1rub'].sum().sort_values(ascending=True).tail(10)
barh_data_4 =  data2.groupby('title')['revenue_mln'].sum().sort_values().tail(10)
dfs = [barh_data_3,barh_data_4]
titles = ['Топ десять фильмов, показавших наибольший доход на рубль господдержки',
         'Десять самых кассовых фильмов в российском прокате,млн.руб']
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(15,7))
#Построение графиков, отсортированных по возрастанию
for r in range(rows):                
            color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
            ax = dfs[count].plot(
                kind='barh',ax=axes[r], edgecolor='black',  color = color, grid=False,
                title = titles[count], xlabel = '',legend=False)
            #Убирание рамок вложенных графиков           
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.spines['left'].set_visible(False)
            #Нанесение надписей
            rects = axes[r].patches
            for index in range(len(rects)):
                width = rects[index].get_width()
                t = axes[r].text(width+0.1, rects[index].get_y()+0.2, str(round(width, 2)),
                          fontsize='medium', weight='bold', color='black',va='center',ha='left')
            count+=1
plt.subplots_adjust(hspace=0.2,wspace=0.2)
plt.show()

# %%
barh_data_6 = data2.groupby('type')['revenue_1rub'].mean().sort_values().tail(10)
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
fig = plt.figure()
ax = fig.add_subplot()
ax.barh( barh_data_6.index.values, barh_data_6,color=color[0])
#Оформление
ax.set_title('Средние кассовые сборы на рубль гос.финансов по типу ленты',size=16) 
ax.set_xlabel('Количество')
ax.tick_params(axis='both',labelsize=16)
 #Убирание рамок вложенных графиков           
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
#Надписи
rects = ax.patches
for bar in rects:    
    width = bar.get_width()    
    ax.text(width, bar.get_y()+0.2, str(round(width, 2)),fontsize='large', style='oblique',
            weight='bold', color='k',ha='left') 
plt.show()

# %% [markdown]
# В среднем кассовые сборы от анимационных фильмов лучше, чем от художественных. Поэтому в них следует больше вкладывать refundable_support.

# %% [markdown]
# ### Студии, приносящие наибольшие сборы на рубль поддержки <a class="anchor" id="id_4d"></a>

# %% [markdown]
# Создание функции для определения главного имени и приведем их к нижнему регистру, так как это позволит увеличить число совпадений при группировке.

# %%
def main_studio(studio):    
        temp = str(studio).split('по заказу')
        tmp = temp[0]       
        tmp1 = tmp.split(',')
        tmp2 = tmp1[0]
        tmp3 = tmp2.split(';')        
        new_name = tmp3[0]
        return new_name.lower()  

data2['main_studio'] = data2['film_studio'].apply(main_studio)

# %%
display(data2.sort_values('box_office',ascending=False)[['film_studio','main_studio']])
# Out:
#                                             film_studio  \
# 7456            ООО "МЕМ-МЕДИА" по заказу АО "ВБД Груп"
# 5653              ООО "Студия "ТРИТЭ" Никиты Михалкова"
# 6549  ООО "Кинокомпания МАРС-фильм" по заказу ООО "М...
# 5505  ООО "Киностудия "Слово" по заказу ООО "Уолт Ди...
# 5708  ООО "Водород 2011", ООО "Арт Пикчерс Студия", ...
# ...                                                 ...
# 2150                                      ООО "Артлайт"
# 3504          ООО "Кинобюро" по заказу ООО "Среда и Ко"
# 2803                     ООО "КИНОДАНЦ", ООО "КИНОБАЙТ"
# 2527                ООО "Первое творческое объединение"
# 3149  НП Киностудия детских и юношеских фильмов "Иль...
#
#                                             main_studio
# 7456                                   ооо "мем-медиа"
# 5653              ооо "студия "тритэ" никиты михалкова"
# 6549                     ооо "кинокомпания марс-фильм"
# 5505                           ооо "киностудия "слово"
# 5708                                 ооо "водород 2011"
# ...                                                 ...
# 2150                                      ооо "артлайт"
# 3504                                    ооо "кинобюро"
# 2803                                     ооо "киноданц"
# 2527                ооо "первое творческое объединение"
# 3149  нп киностудия детских и юношеских фильмов "иль...
#
# [318 rows x 2 columns]

# %% [markdown]
# Создание диаграммы студий, приносящих наибольший доход на рубль поддержки:

# %%
barh_data_5 = data2.groupby('main_studio')['revenue_1rub'].sum().sort_values().tail(10)
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot()
ax.barh( barh_data_5.index.values, barh_data_5,color=color[0])
#Оформление
ax.set_title('Студии, приносящие наибольший доход на рубль поддержки',size=16) 
ax.set_xlabel('Количество')
ax.tick_params(axis='both',labelsize=16)
 #Убирание рамок вложенных графиков           
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
#Надписи
rects = ax.patches
for bar in rects:    
    width = bar.get_width()    
    ax.text(width, bar.get_y()+0.2, str(round(width, 2)),fontsize='large', style='oblique',
            weight='bold', color='k',ha='left') 
plt.show()

# %% [markdown]
# Лучше всего государственными деньгами распоряжаются в студиях: ООО "Мем-Медиа",ООО "Студия анимационного кино "Мельница",ООО "ТаББак", ООО "Водород 2011", ООО "Друг друга" и ООО "Киноданц", имеющие рентабельность на вложенный капитал больше 20%.

# %% [markdown]
# ### Кому чаще всего идут средства

# %%
display(
    data2.groupby('main_studio').count()['box_office'].sort_values(ascending=False))
# Out:
# main_studio
# ооо "таббак"                                    9
# ооо "кинокомпания "ств"                         7
# ооо "студия анимационного кино "мельница"       7
# ооо "энджой мувиз"                              6
# ооо "визарт фильм"                              5
#                                                ..
# ооо "кинопрограмма  "xxi век"                   1
# ооо "кинопрограмма xxi век"                     1
# ооо "кинопрогрупп"                              1
# ооо "киностудия "арк-фильм"                     1
# фонд поддержки развития общества "наши дети"    1
# Name: box_office, Length: 207, dtype: int64

# %%
display(data2[data2['film_studio'].str.contains('ТаББаК') | (data2['film_studio'].str.contains('Мельница'))])
# Out:
#                                     title   puNumber  \
# 5641                           Ёлки Новые  111011617
# 5659      Три богатыря и принцесса Египта  114003317
# 3105          Иван Царевич и Серый Волк 3  114004115
# 6509                       Ёлки Последние  111023918
# 2701                    Самый Лучший День  111017815
# 6472   Три богатыря и наследница престола  114008818
# 3255                  Время первых (2017)  111001317
# 7466          Иван Царевич и Серый Волк 4  114005019
# 3610                               Ёлки 5  111018016
# 3687  Урфин Джюс и его деревянные солдаты  114000817
# 1987                        Елки Лохматые  111023114
# 2699                          Он - Дракон  111017915
# 2530              Крепость. Щитом и мечом  114003015
# 7290              Урфин Джюс возвращается  114004019
# 2683                           Дабл трабл  111009215
# 3515                    Взломать блогеров  111016616
#
#                show_start_date            type  \
# 5641 2017-12-21 12:00:00+00:00  Художественный
# 5659 2017-12-21 12:00:00+00:00    Анимационный
# 3105 2015-12-24 12:00:00+00:00    Анимационный
# 6509 2018-12-10 12:00:00+00:00  Художественный
# 2701 2015-10-14 12:00:00+00:00  Художественный
# 6472 2018-12-15 12:00:00+00:00    Анимационный
# 3255 2017-02-21 12:00:00+00:00  Художественный
# 7466 2019-12-20 12:00:00+00:00    Анимационный
# 3610 2016-12-15 12:00:00+00:00  Художественный
# 3687 2017-04-06 12:00:00+00:00    Анимационный
# 1987 2014-12-10 12:00:00+00:00  Художественный
# 2699 2015-10-14 12:00:00+00:00  Художественный
# 2530 2015-10-21 12:00:00+00:00    Анимационный
# 7290 2019-10-14 12:00:00+00:00    Анимационный
# 2683 2015-05-18 12:00:00+00:00  Художественный
# 3515 2016-10-28 12:00:00+00:00  Художественный
#
#                                     film_studio production_country  \
# 5641                               ООО "ТаББаК"             Россия
# 5659  ООО "Студия анимационного кино "Мельница"             Россия
# 3105  ООО "Студия анимационного кино "Мельница"             Россия
# 6509                               ООО "ТаББаК"             Россия
# 2701                               ООО "ТаББаК"             Россия
# 6472  ООО "Студия анимационного кино "Мельница"             Россия
# 3255      ООО "ТаББаК", ООО "Студия Третий Рим"             Россия
# 7466  ООО "Студия анимационного кино "Мельница"             Россия
# 3610                               ООО "ТаББаК"             Россия
# 3687  ООО "Студия анимационного кино "Мельница"             Россия
# 1987                               ООО "ТаББаК"             Россия
# 2699                               ООО "ТаББаК"             Россия
# 2530  ООО "Студия анимационного кино "Мельница"             Россия
# 7290  ООО "Студия анимационного кино "Мельница"             Россия
# 2683       ООО "ТаББаК", ООО "Весёлая Компания"             Россия
# 3515                               ООО "ТаББаК"             Россия
#
#                                                director  \
# 5641  Д.Киселев, А.Першин (Ж.Крыжовников), А.Карпило...
# 5659                                       К.Феоктистов
# 3105                                            Д.Шмидт
# 6509  Т.Бекмамбетов, А.Першин (псевдоним Ж.Крыжовник...
# 2701                 А.Першин (псевдоним Ж.Крыжовников)
# 6472                                          К.Бронзит
# 3255                                          Д.Киселев
# 7466                              Д.Шмидт, К.Феоктистов
# 3610  Т.Бекмамбетов, И.Джендубаев, А.Котт, А.Шавкеро...
# 3687                    Д.Шмидт, Ф.Дмитриев, В.Торопчин
# 1987                                   Максим Свешников
# 2699                                       И.Джендубаев
# 2530                                         Ф.Дмитриев
# 7290                                         Ф.Дмитриев
# 2683                                         Э.Оганесян
# 3515                                        М.Свешников
#
#                                                producer  \
# 5641                       Т.Бекмамбетов, Г.Стрижевская
# 5659                             С.Сельянов, А.Боярский
# 3105                             С.Сельянов, А.Боярский
# 6509                       Т.Бекмамбетов, Г.Стрижевская
# 2701  Т.Бекмамбетов, А.Першин (псевдоним Ж.Крыжовник...
# 6472                             С.Сельянов, А.Боярский
# 3255                           Т.Бекмамбетов, Е.Миронов
# 7466                             С.Сельянов, А.Боярский
# 3610         Т.Бекмамбетов, И.Стромилова, М.Затуловская
# 3687                             С.Сельянов, А.Боярский
# 1987                 Тимур Бекмамбетов, Евгения Аронова
# 2699                                      Т.Бекмамбетов
# 2530                             С.Сельянов, А.Боярский
# 7290                             С.Сельянов, А.Боярский
# 2683                       Т.Бекмамбетов, М.Затуловская
# 3515                                      Т.Бекмамбетов
#
#                              age_restriction  refundable_support  ...  \
# 5641           «6+» - для детей старше 6 лет        50,000,000.0  ...
# 5659           «6+» - для детей старше 6 лет        50,000,000.0  ...
# 3105           «6+» - для детей старше 6 лет                 0.0  ...
# 6509           «6+» - для детей старше 6 лет        75,000,000.0  ...
# 2701         «16+» - для детей старше 16 лет        29,000,000.0  ...
# 6472           «6+» - для детей старше 6 лет       115,000,000.0  ...
# 3255           «6+» - для детей старше 6 лет        75,000,000.0  ...
# 7466           «6+» - для детей старше 6 лет       100,000,000.0  ...
# 3610           «6+» - для детей старше 6 лет                 0.0  ...
# 3687  «0+» - для любой зрительской аудитории                 0.0  ...
# 1987           «6+» - для детей старше 6 лет        26,000,000.0  ...
# 2699           «6+» - для детей старше 6 лет                 0.0  ...
# 2530           «6+» - для детей старше 6 лет                 0.0  ...
# 7290           «6+» - для детей старше 6 лет                 0.0  ...
# 2683         «12+» - для детей старше 12 лет        44,000,000.0  ...
# 3515           «6+» - для детей старше 6 лет                 0.0  ...
#
#       show_year   main_genre                       main_director  gov_help_%  \
# 5641       2017      комедия                           Д.Киселев       57.35
# 5659       2017   мультфильм                        К.Феоктистов       28.66
# 3105       2015   мультфильм                             Д.Шмидт       22.31
# 6509       2018      комедия                       Т.Бекмамбетов       55.65
# 2701       2015      комедия  А.Першин (псевдоним Ж.Крыжовников)       48.23
# 6472       2018   мультфильм                           К.Бронзит       61.99
# 3255       2017  приключения                           Д.Киселев       47.31
# 7466       2019   мультфильм                             Д.Шмидт       52.63
# 3610       2016     семейный                       Т.Бекмамбетов       69.71
# 3687       2017   мультфильм                             Д.Шмидт       21.75
# 1987       2014     семейный                    Максим Свешников        70.0
# 2699       2015      фэнтези                        И.Джендубаев       69.44
# 2530       2015   мультфильм                          Ф.Дмитриев       36.15
# 7290       2019   мультфильм                          Ф.Дмитриев       66.67
# 2683       2015      комедия                          Э.Оганесян       68.72
# 3515       2016      комедия                         М.Свешников       69.41
#
#       revenue_1000       revenue_mln age_group     goverment  \
# 5641   855,451.052        855.451052     «6+»  100,000,000.0
# 5659   759,226.773        759.226773     «6+»   50,000,000.0
# 3105   704,928.216        704.928216     «6+»   40,000,000.0
# 6509 701,507.03027      701.50703027     «6+»  100,000,000.0
# 2701  683,029.0614 683.0290613999999    «16+»   63,000,000.0
# 6472 577,368.85325      577.36885325     «6+»  115,000,000.0
# 3255    544,332.26         544.33226     «6+»  250,000,000.0
# 7466   501,069.235        501.069235     «6+»  100,000,000.0
# 3610  308,401.4827       308.4014827     «6+»  150,000,000.0
# 3687   206,478.186        206.478186     «0+»   75,000,000.0
# 1987  121,225.6338       121.2256338     «6+»   56,000,000.0
# 2699  110,171.4485       110.1714485     «6+»  250,000,000.0
# 2530   72,749.2165        72.7492165     «6+»   50,000,000.0
# 7290  68,549.52347       68.54952347     «6+»  200,000,000.0
# 2683   19,654.5263        19.6545263    «12+»   44,000,000.0
# 3515     7,323.648          7.323648     «6+»   25,000,000.0
#
#            revenue_1rub                                main_studio
# 5641         8.55451052                               ооо "таббак"
# 5659        15.18453546  ооо "студия анимационного кино "мельница"
# 3105         17.6232054  ооо "студия анимационного кино "мельница"
# 6509       7.0150703027                               ооо "таббак"
# 2701 10.841731133333333                               ооо "таббак"
# 6472  5.020598723913044  ооо "студия анимационного кино "мельница"
# 3255         2.17732904                               ооо "таббак"
# 7466         5.01069235  ооо "студия анимационного кино "мельница"
# 3610 2.0560098846666666                               ооо "таббак"
# 3687         2.75304248  ооо "студия анимационного кино "мельница"
# 1987 2.1647434607142855                               ооо "таббак"
# 2699        0.440685794                               ооо "таббак"
# 2530         1.45498433  ооо "студия анимационного кино "мельница"
# 7290      0.34274761735  ооо "студия анимационного кино "мельница"
# 2683 0.4466937795454546                               ооо "таббак"
# 3515         0.29294592                               ооо "таббак"
#
# [16 rows x 27 columns]

# %%
df_1 = data2.groupby('main_studio')['revenue_1rub'].sum().sort_values()
display (df_1[df_1.index.str.contains('"ств"') 
              | df_1.index.str.contains('визарт') 
              | df_1.index.str.contains('энджой')])
# Out:
# main_studio
# ооо "кинокомпания "ств"   3.6588890595481476
# ооо "визарт фильм"         9.175895889252978
# ооо "энджой мувиз"               10.96300875
# Name: revenue_1rub, dtype: float64

# %% [markdown]
# Чаще всего получателями поддержки были: ООО "Мем-Медиа",ООО "Студия анимационного кино "Мельница",ООО "Кинокомпания "СТВ",ООО "ВИЗАРТ ФИЛЬМ",ООО "Энджой мувиз". Но ООО "Кинокомпания "СТВ" имеет маленький показатель дохода на рубль гос.финансов (3.65 рубля).

# %% [markdown]
# ### Количество выпущенных фильмов по виду поддержки <a class="anchor" id="id_4e"></a>

# %%
fig,axes = plt.subplots(1,3,figsize=(20,5),sharey=False)
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])] #генератор цвета
data2[data2['production_country'].str.contains('Россия')].groupby('show_year')['title'].count().plot.bar(
    ax=axes[0], edgecolor='black',grid=True, color=color)

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
data2[data2['production_country'].str.contains('Россия')].query('nonrefundable_support==0').groupby('show_year')['title'].count().plot.bar(
    ax=axes[1], edgecolor='black',grid=True, color=color)

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
data2[data2['production_country'].str.contains('Россия')].query('refundable_support==0').groupby('show_year')['title'].count().plot.bar(
    ax=axes[2], edgecolor='black',grid=True, color=color)

axes[0].set_title('Количество фильмов при участии России(то есть с господдержкой)')
axes[0].set_xlabel("Год премьеры фильма")
axes[0].set_ylabel("Количество фильмов в году")
axes[1].set_title('Количество фильмов только с refundable_support')
axes[1].set_xlabel("Год премьеры фильма")
axes[1].set_ylabel("Количество фильмов в году")
axes[2].set_title('Количество фильмов только с nonrefundable_support')
axes[2].set_xlabel("Год премьеры фильма")
axes[2].set_ylabel("Количество фильмов в году")
#Нанесение надписей
for index in range(len(axes)):
    rects = axes[index].patches
    for rect in rects:    
            height = rect.get_height()    
            axes[index].text(rect.get_x() + rect.get_width() / 2, height, round(height,1),
            ha="center", va="bottom",weight='bold',size='large',c='black')
plt.show()

# %% [raw]
# Как видно из диаграммы, государство особо и не ожидает, что вложенные средства вернуться обратно.

# %%
#Данные
data2['goverment_mln'] = data2['goverment']/1000000
plot_data_2 = data2.pivot_table(index = 'type',values = ['revenue_mln','goverment_mln'],aggfunc='mean')
plot_data_3 = data2.pivot_table(index = 'type',values = ['revenue_mln','goverment_mln'],aggfunc='sum')

fig, axes = plt.subplots(1,2, figsize=(20,7))
#график 1
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
axes[0].bar( plot_data_2.index.values, plot_data_2['revenue_mln'],color=color[0])
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
axes[0].bar( plot_data_2.index.values, plot_data_2['goverment_mln'],color=color[0])
## Оформление
axes[0].set_title('Средние доходы и средние расходы господдержки по типам фильмов,млн',size=12) 
axes[0].tick_params(axis='both',labelsize=16)           
axes[0].spines['top'].set_visible(False);ax.spines['right'].set_visible(False)
## надписи 1
rects = axes[0].patches
for rect in rects:    
    height = rect.get_height()    
    axes[0].text(rect.get_x() + rect.get_width() / 2, height, round(height,1),
        ha="center", weight='bold',size='large',c='black')
#График 2
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
axes[1].bar( plot_data_3.index.values, plot_data_3['revenue_mln'],color=color[0])
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]
axes[1].bar( plot_data_3.index.values, plot_data_3['goverment_mln'],color=color[0])
## Оформление 2
axes[1].set_title('Сумма кассовых сборов и расходы господдержки по типам фильмов,млн',size=12) 
axes[1].tick_params(axis='both',labelsize=16)           
axes[1].spines['top'].set_visible(False);ax.spines['right'].set_visible(False)
## надписи 2
rects = axes[1].patches
for rect in rects:    
    height = rect.get_height()    
    axes[1].text(rect.get_x() + rect.get_width() / 2,height,  round(height,1),
        ha="center", weight='bold',size='large',c='black')
plt.show()

# %% [raw]
# Анимационные фильмы в 1.5 раза более выгодны с точки зрения соотношения доходов и вложенных средств господдержки. Поэтому, если бы государство заинтересовалось возвратом своих средств (refundables), то желательно больше вкладываться в анимационные фильмы.

# %% [markdown]
# ### Рейтинг фильмов

# %% [markdown]
# Вывод статистики:

# %%
print(data2['ratings'].describe().round(1))
# Out:
# count   318.0
# mean      5.7
# std       1.7
# min       0.0
# 25%       5.2
# 50%       6.2
# 75%       6.7
# max       9.4
# Name: ratings, dtype: float64

# %%
#Средний рейтинг
data2['ratings'].mean()
# Out:
# 5.736477987421383

# %% [markdown]
# Средний рейтинг российских фильмов в базе данных на настоящий момент составляет 5.7.

# %% [markdown]
# ### Корреляция количественных данных <a class="anchor" id="id_4f"></a>

# %%
#Матрица корреляции
corr =  data2[['ratings','budget','box_office','goverment','refundable_support',
           'nonrefundable_support']].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
ax = sns.heatmap(corr, annot = True, fmt='.2g', cmap= 'coolwarm', linewidths=.5, mask=mask)
ax.set_xlim(0,5)
ax.set_ylim(6,1)
# Out:
# (6.0, 1.0)

# %% [markdown]
# Из матрицы корреляции видно, что nonrefundable_suppport коррелирует сильно больше с размером господдержки, чем refundable_support, значит она чаще встречается и ее размер больше. Бюджет фильма имеет высокую положительную корреляцию с господдержкой. А вот кассовые сборы слабо коррелируют с размером бюджета фильмов. Рейтинги также очень слабо коррелируют с другими количественными показателями.

# %%
fig, ax = plt.subplots(1, figsize=(10,6))
kde_ratings = sns.kdeplot(data2.ratings, data2.budget/1000000, cmap='Blues',
           shade=True, shade_lowest=False)
plt.yticks(kde_ratings.get_yticks(), kde_ratings.get_yticks())
plt.ylabel('Бюджет, млн.рублей', fontsize=12)
plt.scatter(data2.ratings, data2.budget/1000000, color='orangered')
plt.ylim(0,1000)
plt.show()

# %%
display(data2[data2['budget']==data2['budget'].max()][['title','ratings','budget','box_office','goverment','refundable_support',
           'nonrefundable_support']])
# Out:
#                      title  ratings          budget     box_office  \
# 7114  Тайна Печати Дракона      5.8 2,305,074,303.0 333,597,059.59
#
#          goverment  refundable_support  nonrefundable_support
# 7114 270,000,000.0       180,000,000.0           90,000,000.0

# %% [markdown]
# Из кде графика видно, что бюджет основной массы фильмов составляет где-то 100 млн. рублей и его размер слабо коррелирует с рейтингом фильма.

# %% [markdown]
# ### Вывод по разделу 3. <a class="anchor" id="id_4g"></a>

# %% [markdown]
# В результате исследования отчественных фильмов я посчитал, сколько выходило фильмов с разным типом гос.поддержки по годам, сколько выходило фильмов по каждой категории зрителей. Были рассчитаны показатели кассовых сборов и их медианных и средних значений, доходности по типам лент, анимационным и художественным, и сделаны соответствующие выводы. Были исследованы зависимости между количественными показателями на примере матрицы корреляции и кде графика. Также были определены главные получатели средств господдержки и посчитаны показатели эффективности их применения.

# %% [markdown]
# ## Вывод по проекту <a class="anchor" id="id_5"></a>

# %% [markdown]
# В результате изучения объединенного датасета я могу сделать следующие выводы:
# 1. С течением времени доля фильмов с известной информацией растет и в 2019 году составила 57%.
# 2. В 2019 году в  прокат поступило 924 фильма. Средние сборы достигли своего максимума в 2017 году и составили 136   млн.рублей, затем начали снижаться до 91,3 млн. рублей в 2019 году из-за внешних факторов. Медианные сборы также были максимальными в 2017 году и составили почти 10 млн.рублей.
# 3.Самыми кассовыми фильмами в российском прокате стали отечественные ленты "Холоп" и "Движение вверх".
# 4. Фильмы 6+ и 12+ пользуются большой популярностью.,больше всего в прокате было лент для детей категории 16+ (2578) и 12+ (1510), затем идут фильмы для взрослых (1478). По кассовым сборам также первые три места занимают ленты для детей 16+, 12+ и 6+ категорий.
# 5. Фильмы для всех зрителей 0+ до 2014 года включительно лидировали по медианным сборам, но замтем наступил перелом и фильмы, которые имеют более четкую ориентированность на зрительские сегменты, заняли первые места.
# 6. Средний рейтинг фильмов в базе данных равен 5.6.
# 7. Государство больше поддерживает выпуск фильмов ориентированных на подрастающее поколение. Помощь была оказана в производстве фильмов 16+ (120 фильмов), 12+ (100 фильмов) и 6+ (65 фильмов) из 318 фильмов. Фильмы этих категорий приносят больше всего сборов.
# 8. Самыми частыми получателями гос.финансирования являются студии "ТаББаК"(9 фильмов),"Мельница"(7), "Кинокомпания"СТВ"(7).
# 9. Лучше всего государственными деньгами распоряжаются в студиях: ООО "Мем-Медиа",ООО "Студия анимационного кино "Мельница",ООО "ТаББак", ООО "Водород 2011", ООО "Друг друга" и ООО "Киноданц", имеющие рентабельность на вложенный капитал больше 20%.
# 10. В анимационные фильмы можно вкладывать больше возвратных средств, так как в среднем они приносят большие сборы, чем художественные ленты.
# 11.Бюджет фильма имеет высокую положительную корреляцию с господдержкой. А вот кассовые сборы слабо коррелируют с размером бюджета фильмов. Рейтинги также очень слабо коррелируют с другими количественными показателями.
